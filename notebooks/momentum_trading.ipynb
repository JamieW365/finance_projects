# %% [markdown]
# # Momentum Trading

# %% [markdown]
# ### The Strategy
# - ##### Check the past 12 month performance of all index stocks
# - ##### At the start of each month we re-invest into the 5 top performers i.e. those with the most momentum
# - ##### We hold invested stocks for the month before re-investing into the top performers again at the start of the next month
# ### Accounting for Survivorship Bias
# - #### Ensure that stocks are added / removed in line with historical data

# %% [markdown]
# ## Imports

# %%
import yfinance as yf
import numpy as np
import pandas as pd
from datetime import datetime

# %% [markdown]
# ## Load Data

# %%
start = "2014-01-01"
end = datetime.today().strftime('%Y-%m-%d')
start, end
# Out:
# ('2014-01-01', '2025-04-18')

# %%
# Get up to date S&P500 stock information from it's wikipedia page
wiki = pd.read_html("https://en.wikipedia.org/wiki/List_of_S%26P_500_companies")

# %%
# Retrieve the current S&P500 stock list
current = wiki[0].copy()
current.sort_values('Date added', ascending=False).head()
# Out:
#     Symbol               Security             GICS Sector  \
# 151   DASH               DoorDash  Consumer Discretionary
# 446    TKO     TKO Group Holdings  Communication Services
# 492    WSM  Williams-Sonoma, Inc.  Consumer Discretionary
# 182    EXE          Expand Energy                  Energy
# 495   WDAY          Workday, Inc.  Information Technology
#
#                       GICS Sub-Industry      Headquarters Location  \
# 151       Specialized Consumer Services  San Francisco, California
# 446              Movies & Entertainment    New York City, New York
# 492               Homefurnishing Retail  San Francisco, California
# 182  Oil & Gas Exploration & Production    Oklahoma City, Oklahoma
# 495                Application Software     Pleasanton, California
#
#      Date added      CIK Founded
# 151  2025-03-24  1792789    2012
# 446  2025-03-24  1973266    2023
# 492  2025-03-24   719955    1956
# 182  2025-03-24   895126    1989
# 495  2024-12-23  1327811    2005

# %%
current.set_index(pd.to_datetime(current['Date added']), inplace=True)
current.drop('Date added', axis=1, inplace=True)
current.sort_index(inplace=True)
current
# Out:
#            Symbol               Security             GICS Sector  \
# Date added
# 1957-03-04    MMM                     3M             Industrials
# 1957-03-04    BMY   Bristol Myers Squibb             Health Care
# 1957-03-04    HSY  Hershey Company (The)        Consumer Staples
# 1957-03-04    HIG         Hartford (The)              Financials
# 1957-03-04    HAL            Halliburton                  Energy
# ...           ...                    ...                     ...
# 2024-12-23   WDAY          Workday, Inc.  Information Technology
# 2025-03-24    TKO     TKO Group Holdings  Communication Services
# 2025-03-24   DASH               DoorDash  Consumer Discretionary
# 2025-03-24    WSM  Williams-Sonoma, Inc.  Consumer Discretionary
# 2025-03-24    EXE          Expand Energy                  Energy
#
#                              GICS Sub-Industry      Headquarters Location  \
# Date added
# 1957-03-04            Industrial Conglomerates      Saint Paul, Minnesota
# 1957-03-04                     Pharmaceuticals    New York City, New York
# 1957-03-04              Packaged Foods & Meats      Hershey, Pennsylvania
# 1957-03-04       Property & Casualty Insurance      Hartford, Connecticut
# 1957-03-04      Oil & Gas Equipment & Services             Houston, Texas
# ...                                        ...                        ...
# 2024-12-23                Application Software     Pleasanton, California
# 2025-03-24              Movies & Entertainment    New York City, New York
# 2025-03-24       Specialized Consumer Services  San Francisco, California
# 2025-03-24               Homefurnishing Retail  San Francisco, California
# 2025-03-24  Oil & Gas Exploration & Production    Oklahoma City, Oklahoma
#
#                 CIK      Founded
# Date added
# 1957-03-04    66740         1902
# 1957-03-04    14272  1989 (1887)
# 1957-03-04    47111         1894
# 1957-03-04   874766         1810
# 1957-03-04    45012         1919
# ...             ...          ...
# 2024-12-23  1327811         2005
# 2025-03-24  1973266         2023
# 2025-03-24  1792789         2012
# 2025-03-24   719955         1956
# 2025-03-24   895126         1989
#
# [503 rows x 7 columns]

# %%
# Add current stocks to the list of complete stocks we need to load from yfinance
stocks = current.Symbol.to_list()
stocks
# Out:
# ['MMM',
#  'BMY',
#  'HSY',
#  'HIG',
#  'HAL',
#  'GIS',
#  'GD',
#  'GE',
#  'F',
#  'XOM',
#  'ADM',
#  'EXC',
#  'ETR',
#  'IBM',
#  'EIX',
#  'DTE',
#  'DE',
#  'CVS',
#  'CSX',
#  'ED',
#  'COP',
#  'CL',
#  'KO',
#  'CMS',
#  'CVX',
#  'CAT',
#  'CPB',
#  'ETN',
#  'IP',
#  'HON',
#  'PFE',
#  'XEL',
#  'ABT',
#  'UNP',
#  'SO',
#  'SLB',
#  'SPGI',
#  'RTX',
#  'PEG',
#  'PG',
#  'PPG',
#  'PEP',
#  'OXY',
#  'NOC',
#  'BA',
#  'MSI',
#  'KMB',
#  'MRK',
#  'MO',
#  'LMT',
#  'NSC',
#  'AEP',
#  'KR',
#  'SHW',
#  'EMR',
#  'CMI',
#  'CLX',
#  'NEM',
#  'MCD',
#  'LLY',
#  'BAX',
#  'BDX',
#  'JNJ',
#  'GPC',
#  'HPQ',
#  'WMB',
#  'JPM',
#  'IFF',
#  'NEE',
#  'DIS',
#  'CI',
#  'TAP',
#  'BAC',
#  'DUK',
#  'WFC',
#  'AXP',
#  'INTC',
#  'TGT',
#  'TXT',
#  'WY',
#  'WBA',
#  'AIG',
#  'PCAR',
#  'FDX',
#  'ADP',
#  'MAS',
#  'GWW',
#  'WMT',
#  'SNA',
#  'SWK',
#  'BF.B',
#  'AAPL',
#  'CAG',
#  'VZ',
#  'T',
#  'LOW',
#  'PHM',
#  'HES',
#  'HAS',
#  'BALL',
#  'APD',
#  'NUE',
#  'RVTY',
#  'CNP',
#  'TJX',
#  'DOV',
#  'PH',
#  'ITW',
#  'MDT',
#  'SYY',
#  'MMC',
#  'AVY',
#  'HD',
#  'PNC',
#  'C',
#  'NKE',
#  'ECL',
#  'GL',
#  'ORCL',
#  'K',
#  'ADSK',
#  'AEE',
#  'AMGN',
#  'LIN',
#  'IPG',
#  'MS',
#  'COST',
#  'CSCO',
#  'EMN',
#  'KEY',
#  'MSFT',
#  'UNH',
#  'LUV',
#  'MU',
#  'PARA',
#  'BSX',
#  'GLW',
#  'AMAT',
#  'BK',
#  'L',
#  'DRI',
#  'ALL',
#  'FITB',
#  'AON',
#  'AZO',
#  'ADBE',
#  'CAH',
#  'SCHW',
#  'EFX',
#  'APA',
#  'PGR',
#  'HBAN',
#  'KLAC',
#  'YUM',
#  'FE',
#  'TFC',
#  'CINF',
#  'OMC',
#  'NTRS',
#  'BEN',
#  'MAR',
#  'MCO',
#  'COF',
#  'RF',
#  'WM',
#  'PAYX',
#  'AES',
#  'DHR',
#  'CCL',
#  'MCK',
#  'AFL',
#  'NTAP',
#  'BBY',
#  'VMC',
#  'QCOM',
#  'PNW',
#  'ADI',
#  'USB',
#  'ROK',
#  'A',
#  'SBUX',
#  'DVN',
#  'EOG',
#  'NI',
#  'INTU',
#  'MET',
#  'SYK',
#  'CTAS',
#  'TXN',
#  'FI',
#  'ZBH',
#  'COR',
#  'PPL',
#  'NVDA',
#  'EQR',
#  'WAT',
#  'SPG',
#  'UPS',
#  'PRU',
#  'PFG',
#  'GS',
#  'EBAY',
#  'EA',
#  'ELV',
#  'TRV',
#  'CMCSA',
#  'DGX',
#  'VLO',
#  'STT',
#  'MKC',
#  'GEN',
#  'PLD',
#  'BIIB',
#  'MTB',
#  'VTRS',
#  'GILD',
#  'TMO',
#  'TPR',
#  'LH',
#  'DHI',
#  'STZ',
#  'TSN',
#  'PSA',
#  'AMP',
#  'LEN',
#  'AMZN',
#  'EL',
#  'VRSN',
#  'BXP',
#  'GOOG',
#  'KIM',
#  'JNPR',
#  'CME',
#  'FIS',
#  'CBRE',
#  'CTSH',
#  'AVB',
#  'RL',
#  'CHRW',
#  'HST',
#  'AIZ',
#  'DFS',
#  'AKAM',
#  'MCHP',
#  'ICE',
#  'EXPE',
#  'EXPD',
#  'J',
#  'AMT',
#  'DOC',
#  'PM',
#  'ISRG',
#  'CTRA',
#  'MA',
#  'DVA',
#  'IVZ',
#  'CF',
#  'FAST',
#  'CRM',
#  'LHX',
#  'APH',
#  'NDAQ',
#  'WEC',
#  'SJM',
#  'WYNN',
#  'RSG',
#  'IRM',
#  'WELL',
#  'VTR',
#  'HRL',
#  'ORLY',
#  'WDC',
#  'PWR',
#  'ES',
#  'BKNG',
#  'ROST',
#  'V',
#  'ROP',
#  'NRG',
#  'BRK.B',
#  'OKE',
#  'KMX',
#  'CB',
#  'JCI',
#  'TT',
#  'FFIV',
#  'NFLX',
#  'EW',
#  'BLK',
#  'CMG',
#  'MPC',
#  'FCX',
#  'ACN',
#  'MOS',
#  'TEL',
#  'XYL',
#  'DLTR',
#  'CCI',
#  'PSX',
#  'KMI',
#  'MNST',
#  'LRCX',
#  'STX',
#  'LYB',
#  'PNR',
#  'MDLZ',
#  'DG',
#  'HUM',
#  'GRMN',
#  'APTV',
#  'ABBV',
#  'REGN',
#  'GM',
#  'ZTS',
#  'NWSA',
#  'DAL',
#  'AME',
#  'VRTX',
#  'ALLE',
#  'META',
#  'MHK',
#  'TSCO',
#  'ESS',
#  'GOOGL',
#  'AVGO',
#  'MLM',
#  'URI',
#  'UHS',
#  'RCL',
#  'HCA',
#  'SWKS',
#  'HSIC',
#  'EQIX',
#  'O',
#  'JBHT',
#  'KHC',
#  'PYPL',
#  'UAL',
#  'NWS',
#  'VRSK',
#  'HPE',
#  'SYF',
#  'CHD',
#  'WTW',
#  'EXR',
#  'CFG',
#  'FRT',
#  'AWK',
#  'UDR',
#  'HOLX',
#  'CNC',
#  'ULTA',
#  'GPN',
#  'DLR',
#  'LKQ',
#  'AJG',
#  'TDG',
#  'FTV',
#  'ALB',
#  'LNT',
#  'MTD',
#  'CHTR',
#  'COO',
#  'HWM',
#  'D',
#  'MAA',
#  'IDXX',
#  'INCY',
#  'CBOE',
#  'REG',
#  'SNPS',
#  'SRE',
#  'RJF',
#  'ARE',
#  'AMD',
#  'IT',
#  'HLT',
#  'EG',
#  'ALGN',
#  'ANSS',
#  'BKR',
#  'AOS',
#  'RMD',
#  'MGM',
#  'PKG',
#  'IQV',
#  'SBAC',
#  'CDNS',
#  'NCLH',
#  'HII',
#  'TTWO',
#  'MSCI',
#  'EVRG',
#  'BR',
#  'CPAY',
#  'CPRT',
#  'ANET',
#  'ROL',
#  'FTNT',
#  'KEYS',
#  'JKHY',
#  'FANG',
#  'LW',
#  'ATO',
#  'WAB',
#  'FOXA',
#  'FOX',
#  'DOW',
#  'CTVA',
#  'DD',
#  'AMCR',
#  'MKTX',
#  'TMUS',
#  'TROW',
#  'LDOS',
#  'IEX',
#  'CDW',
#  'NVR',
#  'LVS',
#  'NOW',
#  'WRB',
#  'ODFL',
#  'ZBRA',
#  'STE',
#  'LYV',
#  'PAYC',
#  'IR',
#  'OTIS',
#  'CARR',
#  'DPZ',
#  'DXCM',
#  'WST',
#  'TDY',
#  'TYL',
#  'TER',
#  'POOL',
#  'TSLA',
#  'ENPH',
#  'TRMB',
#  'MPWR',
#  'GNRC',
#  'CZR',
#  'NXPI',
#  'PTC',
#  'CRL',
#  'MRNA',
#  'TECH',
#  'BRO',
#  'MTCH',
#  'DAY',
#  'EPAM',
#  'FDS',
#  'CEG',
#  'NDSN',
#  'MOH',
#  'CPT',
#  'WBD',
#  'VICI',
#  'KDP',
#  'ON',
#  'CSGP',
#  'INVH',
#  'PCG',
#  'EQT',
#  'TRGP',
#  'ACGL',
#  'FSLR',
#  'STLD',
#  'GEHC',
#  'BG',
#  'PODD',
#  'FICO',
#  'AXON',
#  'PANW',
#  'KVUE',
#  'BX',
#  'ABNB',
#  'VLTO',
#  'HUBB',
#  'LULU',
#  'JBL',
#  'UBER',
#  'BLDR',
#  'SMCI',
#  'DECK',
#  'SOLV',
#  'GEV',
#  'VST',
#  'KKR',
#  'CRWD',
#  'GDDY',
#  'SW',
#  'ERIE',
#  'DELL',
#  'PLTR',
#  'TPL',
#  'LII',
#  'APO',
#  'WDAY',
#  'TKO',
#  'DASH',
#  'WSM',
#  'EXE']

# %%
# Stocks that were added after our start point will need to be filtered to account for survivorship bias
added = current[current.index >= start].copy()
added
# Out:
#            Symbol                   Security             GICS Sector  \
# Date added
# 2014-01-24   TSCO             Tractor Supply  Consumer Discretionary
# 2014-04-02    ESS       Essex Property Trust             Real Estate
# 2014-04-03  GOOGL    Alphabet Inc. (Class A)  Communication Services
# 2014-05-08   AVGO                   Broadcom  Information Technology
# 2014-07-02    MLM  Martin Marietta Materials               Materials
# ...           ...                        ...                     ...
# 2024-12-23   WDAY              Workday, Inc.  Information Technology
# 2025-03-24    TKO         TKO Group Holdings  Communication Services
# 2025-03-24   DASH                   DoorDash  Consumer Discretionary
# 2025-03-24    WSM      Williams-Sonoma, Inc.  Consumer Discretionary
# 2025-03-24    EXE              Expand Energy                  Energy
#
#                              GICS Sub-Industry      Headquarters Location  \
# Date added
# 2014-01-24              Other Specialty Retail       Brentwood, Tennessee
# 2014-04-02      Multi-Family Residential REITs      San Mateo, California
# 2014-04-03        Interactive Media & Services  Mountain View, California
# 2014-05-08                      Semiconductors      Palo Alto, California
# 2014-07-02              Construction Materials    Raleigh, North Carolina
# ...                                        ...                        ...
# 2024-12-23                Application Software     Pleasanton, California
# 2025-03-24              Movies & Entertainment    New York City, New York
# 2025-03-24       Specialized Consumer Services  San Francisco, California
# 2025-03-24               Homefurnishing Retail  San Francisco, California
# 2025-03-24  Oil & Gas Exploration & Production    Oklahoma City, Oklahoma
#
#                 CIK Founded
# Date added
# 2014-01-24   916365    1938
# 2014-04-02   920522    1971
# 2014-04-03  1652044    1998
# 2014-05-08  1730168    1961
# 2014-07-02   916076    1993
# ...             ...     ...
# 2024-12-23  1327811    2005
# 2025-03-24  1973266    2023
# 2025-03-24  1792789    2012
# 2025-03-24   719955    1956
# 2025-03-24   895126    1989
#
# [182 rows x 7 columns]

# %%
# Retrieve a list of stocks that are not currently in the S&P500 stock list
removed = wiki[1][['Date', 'Removed']].copy()
removed.head()
# Out:
#                 Date Removed
#                 Date  Ticker         Security
# 0     March 24, 2025     BWA       BorgWarner
# 1     March 24, 2025     TFX         Teleflex
# 2     March 24, 2025      CE         Celanese
# 3     March 24, 2025     FMC  FMC Corporation
# 4  December 23, 2024    QRVO            Qorvo

# %%
# Stocks that were removed after our start point will need to be included until their removal date in order to account for survivorship bias
removed.set_index(pd.to_datetime(removed.Date.Date, format="mixed"), inplace=True)
removed.sort_index(inplace=True)
removed
# Out:
#                           Date Removed
#                           Date  Ticker             Security
# Date
# 1976-07-01        July 1, 1976     AYE     Allegheny Energy
# 1976-07-01        July 1, 1976     HNG  Houston Natural Gas
# 1994-09-30  September 30, 1994     MCK             McKesson
# 1997-06-17       June 17, 1997     USL               USLife
# 1998-12-11   December 11, 1998     GRN           General Re
# ...                        ...     ...                  ...
# 2024-12-23   December 23, 2024    QRVO                Qorvo
# 2025-03-24      March 24, 2025     FMC      FMC Corporation
# 2025-03-24      March 24, 2025      CE             Celanese
# 2025-03-24      March 24, 2025     TFX             Teleflex
# 2025-03-24      March 24, 2025     BWA           BorgWarner
#
# [371 rows x 3 columns]

# %%
removed = removed[removed.index >= start].Removed
removed
# Out:
#            Ticker                  Security
# Date
# 2014-01-24   LIFE         Life Technologies
# 2014-03-21    WPX                WPX Energy
# 2014-04-02    CLF  Cliffs Natural Resources
# 2014-04-03    NaN                       NaN
# 2014-05-01    SLM           SLM Corporation
# ...           ...                       ...
# 2024-12-23   QRVO                     Qorvo
# 2025-03-24    FMC           FMC Corporation
# 2025-03-24     CE                  Celanese
# 2025-03-24    TFX                  Teleflex
# 2025-03-24    BWA                BorgWarner
#
# [251 rows x 2 columns]

# %%
# I will drop values we don't have ticker information for
removed[removed.Ticker.isna()]
# Out:
#            Ticker Security
# Date
# 2014-04-03    NaN      NaN
# 2014-08-06    NaN      NaN
# 2015-09-18    NaN      NaN
# 2015-09-18    NaN      NaN
# 2015-09-18    NaN      NaN
# 2016-04-08    NaN      NaN
# 2020-04-03    NaN      NaN
# 2020-04-03    NaN      NaN
# 2020-10-09    NaN      NaN
# 2021-06-03    NaN      NaN
# 2022-02-02    NaN      NaN
# 2022-12-15    NaN      NaN
# 2023-01-04    NaN      NaN
# 2023-10-02    NaN      NaN
# 2024-04-01    NaN      NaN
# 2024-04-02    NaN      NaN
# 2024-09-30    NaN      NaN

# %%
removed.dropna(inplace=True)
removed
# Out:
#            Ticker                  Security
# Date
# 2014-01-24   LIFE         Life Technologies
# 2014-03-21    WPX                WPX Energy
# 2014-04-02    CLF  Cliffs Natural Resources
# 2014-05-01    SLM           SLM Corporation
# 2014-05-01   BEAM    Suntory Global Spirits
# ...           ...                       ...
# 2024-12-23   QRVO                     Qorvo
# 2025-03-24    FMC           FMC Corporation
# 2025-03-24     CE                  Celanese
# 2025-03-24    TFX                  Teleflex
# 2025-03-24    BWA                BorgWarner
#
# [234 rows x 2 columns]

# %%
removed.isna().any().any()
# Out:
# np.False_

# %%
# We will also need to retrieve the removed stocks from yfinance
stocks.extend(removed.Ticker.to_list())
len(stocks)
# Out:
# 737

# %%
len(set(stocks))
# Out:
# 727

# %% [markdown]
# ## Download Stock Data From Yahoo Finance

# %%
# Load all relevent stocks from yfinance
df = yf.download(stocks, start=start, end=end)['Close']
# Out:
# YF.download() has changed argument auto_adjust default to True
# [*********************100%***********************]  727 of 727 completed
#
# 105 Failed downloads:
# ['ENDP', 'RDC', 'MON', 'XL', 'APC', 'XLNX', 'DISCA', 'WPX', 'RTN', 'DWDP', 'LIFE', 'CHK', 'RHT', 'BBBY', 'QEP', 'FBHS', 'DISCK', 'DISH', 'CTXS', 'CERN', 'ALXN', 'FLIR', 'ETFC', 'ATVI', 'BRK.B', 'TIF', 'TWTR', 'DRE', 'LLL', 'LM', 'ADS', 'ESV', 'CXO', 'WIN', 'ABMD', 'WCG', 'FRC', 'NLSN', 'AGN', 'XEC', 'MXIM', 'PXD', 'ARNC', 'DO', 'AVP', 'PBCT', 'SWN', 'DNR', 'GPS', 'FRX', 'YHOO', 'TSS', 'FTR', 'VIAB', 'DTV', 'SIVB', 'LSI', 'HFC', 'NBL', 'MNK', 'KSU', 'VAR', 'CELG']: YFTzMissingError('possibly delisted; no timezone found')
# ['TWC', 'SIAL', 'HSP', 'WYN', 'BF.B', 'RAI', 'JOY', 'MJN', 'LVLT', 'FDO', 'BRCM', 'WFM', 'LLTC', 'CVC', 'BXLT', 'LO', 'GGP', 'HCBK', 'STJ', 'TYC', 'GMCR', 'DPS', 'POM', 'CMCSK', 'SPLS', 'KRFT', 'CAM', 'CFN', 'CPGX', 'ARG', 'SNI', 'SWY', 'BCR']: YFPricesMissingError('possibly delisted; no price data found  (1d 2014-01-01 -> 2025-04-18)')
# ['CSRA', 'HOT', 'SCG', 'ANDV', 'TWX', 'AET', 'BMS']: ValueError('Length mismatch: Expected axis has 2 elements, new values have 1 elements')
# ['MRO', 'CTLT']: YFPricesMissingError('possibly delisted; no price data found  (1d 2014-01-01 -> 2025-04-18) (Yahoo error = "No data found, symbol may be delisted")')

# %%
df
# Out:
# Ticker               A         AA        AAL         AAP        AAPL  \
# Date
# 2014-01-02   36.601475  23.611731  23.907925   97.235039   17.215374
# 2014-01-03   37.063805  23.701426  25.020359  100.017242   16.837219
# 2014-01-06   36.881493  23.611731  25.482298   99.060333   16.929037
# 2014-01-07   37.408924  23.634157  25.369173  100.283081   16.807964
# 2014-01-08   38.021004  24.284430  26.047945   99.503357   16.914400
# ...                ...        ...        ...         ...         ...
# 2025-04-11  102.709999  24.750000   9.670000   32.259998  198.149994
# 2025-04-14  105.190002  25.010000   9.580000   32.880001  202.520004
# 2025-04-15  103.120003  24.680000   9.850000   32.389999  202.139999
# 2025-04-16  102.699997  25.070000   9.420000   30.879999  194.270004
# 2025-04-17  102.480003  23.320000   9.460000   31.870001  196.979996
#
# Ticker            ABBV  ABMD        ABNB         ABT  ACE  ...         XOM  \
# Date                                                       ...
# 2014-01-02   32.678307   NaN         NaN   30.601080  NaN  ...   62.183239
# 2014-01-03   32.879463   NaN         NaN   30.929258  NaN  ...   62.033611
# 2014-01-06   31.678713   NaN         NaN   31.337496  NaN  ...   62.127140
# 2014-01-07   31.741589   NaN         NaN   31.097363  NaN  ...   63.006100
# 2014-01-08   31.659853   NaN         NaN   31.377506  NaN  ...   62.800369
# ...                ...   ...         ...         ...  ...  ...         ...
# 2025-04-11  173.447098   NaN  114.540001  126.294975  NaN  ...  103.139999
# 2025-04-14  177.460007   NaN  113.220001  127.369995  NaN  ...  103.389999
# 2025-04-15  176.800003   NaN  114.639999  126.220001  NaN  ...  103.099998
# 2025-04-16  171.679993   NaN  112.639999  129.699997  NaN  ...  104.190002
# 2025-04-17  172.990005   NaN  112.699997  130.979996  NaN  ...  106.919998
#
# Ticker           XRAY        XRX         XYL  YHOO         YUM         ZBH  \
# Date
# 2014-01-02  42.567898  16.481977   29.585558   NaN   43.553596   81.806671
# 2014-01-03  42.772049  16.592693   29.854053   NaN   43.826210   82.161438
# 2014-01-06  42.514668  16.731073   29.802088   NaN   43.791401   82.693573
# 2014-01-07  43.171455  16.869465   29.888699   NaN   44.406219   84.343185
# 2014-01-08  43.251331  16.717236   29.871380   NaN   44.388817   86.409645
# ...               ...        ...         ...   ...         ...         ...
# 2025-04-11  12.770000   3.960000  109.059998   NaN  145.000000  102.349998
# 2025-04-14  13.080000   3.880000  109.699997   NaN  146.000000  101.970001
# 2025-04-15  12.550000   3.850000  109.139999   NaN  144.690002   97.269997
# 2025-04-16  12.650000   3.770000  109.190002   NaN  142.570007   96.940002
# 2025-04-17  12.830000   3.950000  110.419998   NaN  143.309998   97.919998
#
# Ticker            ZBRA       ZION         ZTS
# Date
# 2014-01-02   53.180000  22.804527   29.740776
# 2014-01-03   53.580002  22.966040   29.455870
# 2014-01-06   53.400002  22.804527   29.391531
# 2014-01-07   53.950001  22.873747   29.501823
# 2014-01-08   53.910000  23.073717   29.170954
# ...                ...        ...         ...
# 2025-04-11  225.440002  42.000000  149.440002
# 2025-04-14  231.770004  42.900002  150.830002
# 2025-04-15  228.110001  43.790001  149.220001
# 2025-04-16  224.759995  43.360001  146.759995
# 2025-04-17  226.729996  44.279999  148.669998
#
# [2841 rows x 727 columns]

# %%
df.columns[df.isna().all()]
# Out:
# Index(['ABMD', 'ADS', 'AET', 'AGN', 'ALXN', 'ANDV', 'APC', 'ARG', 'ARNC',
#        'ATVI',
#        ...
#        'VIAB', 'WCG', 'WFM', 'WIN', 'WPX', 'WYN', 'XEC', 'XL', 'XLNX', 'YHOO'],
#       dtype='object', name='Ticker', length=105)

# %%
df['ACE'][df['ACE'].notna()]
# Out:
# Date
# 2018-08-28     1.46
# 2018-08-29     1.46
# 2018-08-30     1.46
# 2018-08-31     1.43
# 2018-09-04     1.43
#               ...
# 2019-06-03     1.31
# 2019-06-04     1.33
# 2019-06-06     1.38
# 2019-06-07     1.31
# 2020-01-24    33.00
# Name: ACE, Length: 195, dtype: float64

# %%
# Save the overall dataset for easy access
df.to_csv('data/sp500_historic.csv')

# %%
# Load from csv if YFinance is down
df = pd.read_csv('data/sp500_historic.csv', index_col=0, date_format = pd.to_datetime)
df.index = pd.to_datetime(df.index)
df
# Out:
#                      A         AA        AAL         AAP        AAPL  \
# Date
# 2014-01-02   36.601475  23.611731  23.907925   97.235039   17.215374
# 2014-01-03   37.063805  23.701426  25.020359  100.017242   16.837219
# 2014-01-06   36.881493  23.611731  25.482298   99.060333   16.929037
# 2014-01-07   37.408924  23.634157  25.369173  100.283081   16.807964
# 2014-01-08   38.021004  24.284430  26.047945   99.503357   16.914400
# ...                ...        ...        ...         ...         ...
# 2025-04-11  102.709999  24.750000   9.670000   32.259998  198.149994
# 2025-04-14  105.190002  25.010000   9.580000   32.880001  202.520004
# 2025-04-15  103.120003  24.680000   9.850000   32.389999  202.139999
# 2025-04-16  102.699997  25.070000   9.420000   30.879999  194.270004
# 2025-04-17  102.480003  23.320000   9.460000   31.870001  196.979996
#
#                   ABBV  ABMD        ABNB         ABT  ACE  ...         XOM  \
# Date                                                       ...
# 2014-01-02   32.678307   NaN         NaN   30.601080  NaN  ...   62.183239
# 2014-01-03   32.879463   NaN         NaN   30.929258  NaN  ...   62.033611
# 2014-01-06   31.678713   NaN         NaN   31.337496  NaN  ...   62.127140
# 2014-01-07   31.741589   NaN         NaN   31.097363  NaN  ...   63.006100
# 2014-01-08   31.659853   NaN         NaN   31.377506  NaN  ...   62.800369
# ...                ...   ...         ...         ...  ...  ...         ...
# 2025-04-11  173.447098   NaN  114.540001  126.294975  NaN  ...  103.139999
# 2025-04-14  177.460007   NaN  113.220001  127.369995  NaN  ...  103.389999
# 2025-04-15  176.800003   NaN  114.639999  126.220001  NaN  ...  103.099998
# 2025-04-16  171.679993   NaN  112.639999  129.699997  NaN  ...  104.190002
# 2025-04-17  172.990005   NaN  112.699997  130.979996  NaN  ...  106.919998
#
#                  XRAY        XRX         XYL  YHOO         YUM         ZBH  \
# Date
# 2014-01-02  42.567898  16.481977   29.585558   NaN   43.553596   81.806671
# 2014-01-03  42.772049  16.592693   29.854053   NaN   43.826210   82.161438
# 2014-01-06  42.514668  16.731073   29.802088   NaN   43.791401   82.693573
# 2014-01-07  43.171455  16.869465   29.888699   NaN   44.406219   84.343185
# 2014-01-08  43.251331  16.717236   29.871380   NaN   44.388817   86.409645
# ...               ...        ...         ...   ...         ...         ...
# 2025-04-11  12.770000   3.960000  109.059998   NaN  145.000000  102.349998
# 2025-04-14  13.080000   3.880000  109.699997   NaN  146.000000  101.970001
# 2025-04-15  12.550000   3.850000  109.139999   NaN  144.690002   97.269997
# 2025-04-16  12.650000   3.770000  109.190002   NaN  142.570007   96.940002
# 2025-04-17  12.830000   3.950000  110.419998   NaN  143.309998   97.919998
#
#                   ZBRA       ZION         ZTS
# Date
# 2014-01-02   53.180000  22.804527   29.740776
# 2014-01-03   53.580002  22.966040   29.455870
# 2014-01-06   53.400002  22.804527   29.391531
# 2014-01-07   53.950001  22.873747   29.501823
# 2014-01-08   53.910000  23.073717   29.170954
# ...                ...        ...         ...
# 2025-04-11  225.440002  42.000000  149.440002
# 2025-04-14  231.770004  42.900002  150.830002
# 2025-04-15  228.110001  43.790001  149.220001
# 2025-04-16  224.759995  43.360001  146.759995
# 2025-04-17  226.729996  44.279999  148.669998
#
# [2841 rows x 727 columns]

# %%
df.isna().all().any()
# Out:
# np.True_

# %%
# Dropping any stocks where we have completely null data
df.drop(df.columns[df.isna().all()], axis=1, inplace=True)
df.shape
# Out:
# (2841, 622)

# %% [markdown]
# ## Accounting for Survivorship Bias

# %% [markdown]
# ### Test nulling data for a single removed stock

# %%
removed
# Out:
#            Ticker                  Security
# Date
# 2014-01-24   LIFE         Life Technologies
# 2014-03-21    WPX                WPX Energy
# 2014-04-02    CLF  Cliffs Natural Resources
# 2014-05-01    SLM           SLM Corporation
# 2014-05-01   BEAM    Suntory Global Spirits
# ...           ...                       ...
# 2024-12-23   QRVO                     Qorvo
# 2025-03-24    FMC           FMC Corporation
# 2025-03-24     CE                  Celanese
# 2025-03-24    TFX                  Teleflex
# 2025-03-24    BWA                BorgWarner
#
# [234 rows x 2 columns]

# %%
removed[removed.Ticker == 'QRVO']
# Out:
#            Ticker Security
# Date
# 2024-12-23   QRVO    Qorvo

# %%
removed[removed.Ticker == 'QRVO'].index[0]
# Out:
# Timestamp('2024-12-23 00:00:00')

# %%
df['QRVO']
# Out:
# Date
# 2014-01-02          NaN
# 2014-01-03          NaN
# 2014-01-06          NaN
# 2014-01-07          NaN
# 2014-01-08          NaN
#                 ...
# 2025-04-11    56.270000
# 2025-04-14    58.930000
# 2025-04-15    57.810001
# 2025-04-16    56.820000
# 2025-04-17    57.630001
# Name: QRVO, Length: 2841, dtype: float64

# %%
pd.date_range(start, removed[removed.Ticker == 'QRVO'].index[0])
# Out:
# DatetimeIndex(['2014-01-01', '2014-01-02', '2014-01-03', '2014-01-04',
#                '2014-01-05', '2014-01-06', '2014-01-07', '2014-01-08',
#                '2014-01-09', '2014-01-10',
#                ...
#                '2024-12-14', '2024-12-15', '2024-12-16', '2024-12-17',
#                '2024-12-18', '2024-12-19', '2024-12-20', '2024-12-21',
#                '2024-12-22', '2024-12-23'],
#               dtype='datetime64[ns]', length=4010, freq='D')

# %%
df['QRVO'] = df['QRVO'].reindex(pd.date_range(start, removed[removed.Ticker == 'QRVO'].index[0]))
df['QRVO']
# Out:
# Date
# 2014-01-02   NaN
# 2014-01-03   NaN
# 2014-01-06   NaN
# 2014-01-07   NaN
# 2014-01-08   NaN
#               ..
# 2025-04-11   NaN
# 2025-04-14   NaN
# 2025-04-15   NaN
# 2025-04-16   NaN
# 2025-04-17   NaN
# Name: QRVO, Length: 2841, dtype: float64

# %%
removed[removed.Ticker == 'QRVO'].index[0]
# Out:
# Timestamp('2024-12-23 00:00:00')

# %%
# Everything before the removal date is populated
df['QRVO'].loc[:removed[removed.Ticker == 'QRVO'].index[0]]
# Out:
# Date
# 2014-01-02          NaN
# 2014-01-03          NaN
# 2014-01-06          NaN
# 2014-01-07          NaN
# 2014-01-08          NaN
#                 ...
# 2024-12-17    70.949997
# 2024-12-18    68.500000
# 2024-12-19    68.800003
# 2024-12-20    70.849998
# 2024-12-23    71.540001
# Name: QRVO, Length: 2763, dtype: float64

# %%
# Everything after the removal date has been nulled
df['QRVO'].loc[removed[removed.Ticker == 'QRVO'].index[0]:]
# Out:
# Date
# 2024-12-23    71.540001
# 2024-12-24          NaN
# 2024-12-26          NaN
# 2024-12-27          NaN
# 2024-12-30          NaN
#                 ...
# 2025-04-11          NaN
# 2025-04-14          NaN
# 2025-04-15          NaN
# 2025-04-16          NaN
# 2025-04-17          NaN
# Name: QRVO, Length: 79, dtype: float64

# %% [markdown]
# ### Test nulling data for a single added stock

# %%
added
# Out:
#            Symbol                   Security             GICS Sector  \
# Date added
# 2014-01-24   TSCO             Tractor Supply  Consumer Discretionary
# 2014-04-02    ESS       Essex Property Trust             Real Estate
# 2014-04-03  GOOGL    Alphabet Inc. (Class A)  Communication Services
# 2014-05-08   AVGO                   Broadcom  Information Technology
# 2014-07-02    MLM  Martin Marietta Materials               Materials
# ...           ...                        ...                     ...
# 2024-12-23   WDAY              Workday, Inc.  Information Technology
# 2025-03-24    TKO         TKO Group Holdings  Communication Services
# 2025-03-24   DASH                   DoorDash  Consumer Discretionary
# 2025-03-24    WSM      Williams-Sonoma, Inc.  Consumer Discretionary
# 2025-03-24    EXE              Expand Energy                  Energy
#
#                              GICS Sub-Industry      Headquarters Location  \
# Date added
# 2014-01-24              Other Specialty Retail       Brentwood, Tennessee
# 2014-04-02      Multi-Family Residential REITs      San Mateo, California
# 2014-04-03        Interactive Media & Services  Mountain View, California
# 2014-05-08                      Semiconductors      Palo Alto, California
# 2014-07-02              Construction Materials    Raleigh, North Carolina
# ...                                        ...                        ...
# 2024-12-23                Application Software     Pleasanton, California
# 2025-03-24              Movies & Entertainment    New York City, New York
# 2025-03-24       Specialized Consumer Services  San Francisco, California
# 2025-03-24               Homefurnishing Retail  San Francisco, California
# 2025-03-24  Oil & Gas Exploration & Production    Oklahoma City, Oklahoma
#
#                 CIK Founded
# Date added
# 2014-01-24   916365    1938
# 2014-04-02   920522    1971
# 2014-04-03  1652044    1998
# 2014-05-08  1730168    1961
# 2014-07-02   916076    1993
# ...             ...     ...
# 2024-12-23  1327811    2005
# 2025-03-24  1973266    2023
# 2025-03-24  1792789    2012
# 2025-03-24   719955    1956
# 2025-03-24   895126    1989
#
# [182 rows x 7 columns]

# %%
df['AOS']
# Out:
# Date
# 2014-01-02    22.410557
# 2014-01-03    22.406353
# 2014-01-06    22.389540
# 2014-01-07    22.170979
# 2014-01-08    21.918806
#                 ...
# 2025-04-11    64.500000
# 2025-04-14    65.199997
# 2025-04-15    63.849998
# 2025-04-16    62.860001
# 2025-04-17    63.139999
# Name: AOS, Length: 2841, dtype: float64

# %%
df['AOS'] = df['AOS'].reindex(pd.date_range(added[added.Symbol=='AOS'].index[0], end))
df['AOS']
# Out:
# Date
# 2014-01-02          NaN
# 2014-01-03          NaN
# 2014-01-06          NaN
# 2014-01-07          NaN
# 2014-01-08          NaN
#                 ...
# 2025-04-11    64.500000
# 2025-04-14    65.199997
# 2025-04-15    63.849998
# 2025-04-16    62.860001
# 2025-04-17    63.139999
# Name: AOS, Length: 2841, dtype: float64

# %%
# Everything before the added date is null
df['AOS'].loc[:added[added.Symbol=='AOS'].index[0]]
# Out:
# Date
# 2014-01-02          NaN
# 2014-01-03          NaN
# 2014-01-06          NaN
# 2014-01-07          NaN
# 2014-01-08          NaN
#                 ...
# 2017-07-20          NaN
# 2017-07-21          NaN
# 2017-07-24          NaN
# 2017-07-25          NaN
# 2017-07-26    47.457069
# Name: AOS, Length: 898, dtype: float64

# %%
# Everything after the added date is populated
df['AOS'].loc[added[added.Symbol=='AOS'].index[0]:]
# Out:
# Date
# 2017-07-26    47.457069
# 2017-07-27    47.334152
# 2017-07-28    47.667801
# 2017-07-31    47.018066
# 2017-08-01    47.184883
#                 ...
# 2025-04-11    64.500000
# 2025-04-14    65.199997
# 2025-04-15    63.849998
# 2025-04-16    62.860001
# 2025-04-17    63.139999
# Name: AOS, Length: 1944, dtype: float64

# %% [markdown]
# ## Creating functions to account for

# %%
def pricefilter_removed(ticker):
    if ticker in df.columns:
        df[ticker] = df[ticker].reindex(pd.date_range(start, removed[removed.Ticker==ticker].index[0], freq='B'))

def pricefilter_added(ticker):
    if ticker in df.columns:
        df[ticker] = df[ticker].reindex(pd.date_range(added[added.Symbol==ticker].index[0], end, freq='B'))

# %%
for ticker in removed.Ticker:
    pricefilter_removed(ticker)

# %%
for ticker in added.Symbol:
    pricefilter_added(ticker)

# %%
df
# Out:
#                      A         AA        AAL         AAP        AAPL  \
# Date
# 2014-01-02   36.601475  23.611731  23.907925   97.235039   17.215374
# 2014-01-03   37.063805  23.701426  25.020359  100.017242   16.837219
# 2014-01-06   36.881493  23.611731  25.482298   99.060333   16.929037
# 2014-01-07   37.408924  23.634157  25.369173  100.283081   16.807964
# 2014-01-08   38.021004  24.284430  26.047945   99.503357   16.914400
# ...                ...        ...        ...         ...         ...
# 2025-04-11  102.709999        NaN        NaN         NaN  198.149994
# 2025-04-14  105.190002        NaN        NaN         NaN  202.520004
# 2025-04-15  103.120003        NaN        NaN         NaN  202.139999
# 2025-04-16  102.699997        NaN        NaN         NaN  194.270004
# 2025-04-17  102.480003        NaN        NaN         NaN  196.979996
#
#                   ABBV  ABMD        ABNB         ABT  ACE  ...         XOM  \
# Date                                                       ...
# 2014-01-02   32.678307   NaN         NaN   30.601080  NaN  ...   62.183239
# 2014-01-03   32.879463   NaN         NaN   30.929258  NaN  ...   62.033611
# 2014-01-06   31.678713   NaN         NaN   31.337496  NaN  ...   62.127140
# 2014-01-07   31.741589   NaN         NaN   31.097363  NaN  ...   63.006100
# 2014-01-08   31.659853   NaN         NaN   31.377506  NaN  ...   62.800369
# ...                ...   ...         ...         ...  ...  ...         ...
# 2025-04-11  173.447098   NaN  114.540001  126.294975  NaN  ...  103.139999
# 2025-04-14  177.460007   NaN  113.220001  127.369995  NaN  ...  103.389999
# 2025-04-15  176.800003   NaN  114.639999  126.220001  NaN  ...  103.099998
# 2025-04-16  171.679993   NaN  112.639999  129.699997  NaN  ...  104.190002
# 2025-04-17  172.990005   NaN  112.699997  130.979996  NaN  ...  106.919998
#
#                  XRAY        XRX         XYL  YHOO         YUM         ZBH  \
# Date
# 2014-01-02  42.567898  16.481977   29.585558   NaN   43.553596   81.806671
# 2014-01-03  42.772049  16.592693   29.854053   NaN   43.826210   82.161438
# 2014-01-06  42.514668  16.731073   29.802088   NaN   43.791401   82.693573
# 2014-01-07  43.171455  16.869465   29.888699   NaN   44.406219   84.343185
# 2014-01-08  43.251331  16.717236   29.871380   NaN   44.388817   86.409645
# ...               ...        ...         ...   ...         ...         ...
# 2025-04-11        NaN        NaN  109.059998   NaN  145.000000  102.349998
# 2025-04-14        NaN        NaN  109.699997   NaN  146.000000  101.970001
# 2025-04-15        NaN        NaN  109.139999   NaN  144.690002   97.269997
# 2025-04-16        NaN        NaN  109.190002   NaN  142.570007   96.940002
# 2025-04-17        NaN        NaN  110.419998   NaN  143.309998   97.919998
#
#                   ZBRA       ZION         ZTS
# Date
# 2014-01-02         NaN  22.804527   29.740776
# 2014-01-03         NaN  22.966040   29.455870
# 2014-01-06         NaN  22.804527   29.391531
# 2014-01-07         NaN  22.873747   29.501823
# 2014-01-08         NaN  23.073717   29.170954
# ...                ...        ...         ...
# 2025-04-11  225.440002        NaN  149.440002
# 2025-04-14  231.770004        NaN  150.830002
# 2025-04-15  228.110001        NaN  149.220001
# 2025-04-16  224.759995        NaN  146.759995
# 2025-04-17  226.729996        NaN  148.669998
#
# [2841 rows x 727 columns]

# %% [markdown]
# ## Calculate Monthly and 12 Month Rolling Returns

# %%
# Daily percentage changes
ret = df.pct_change(fill_method=None) + 1

# First row will be null so we can drop it
ret.dropna(how='all', inplace=True)
ret
# Out:
#                    A        AA       AAL       AAP      AAPL      ABBV  ABMD  \
# Date
# 2014-01-03  1.012631  1.003799  1.046530  1.028613  0.978034  1.006156   NaN
# 2014-01-06  0.995081  0.996216  1.018463  0.990433  1.005453  0.963480   NaN
# 2014-01-07  1.014301  1.000950  0.995561  1.012343  0.992848  1.001985   NaN
# 2014-01-08  1.016362  1.027514  1.026756  0.992225  1.006332  0.997425   NaN
# 2014-01-09  1.000343  0.987073  1.064785  1.011131  0.987231  1.017077   NaN
# ...              ...       ...       ...       ...       ...       ...   ...
# 2025-04-11  1.027614       NaN       NaN       NaN  1.040594  1.004879   NaN
# 2025-04-14  1.024146       NaN       NaN       NaN  1.022054  1.023136   NaN
# 2025-04-15  0.980321       NaN       NaN       NaN  0.998124  0.996281   NaN
# 2025-04-16  0.995927       NaN       NaN       NaN  0.961067  0.971041   NaN
# 2025-04-17  0.997858       NaN       NaN       NaN  1.013950  1.007631   NaN
#
#                 ABNB       ABT  ACE  ...       XOM      XRAY       XRX  \
# Date                                 ...
# 2014-01-03       NaN  1.010724  NaN  ...  0.997594  1.004796  1.006717
# 2014-01-06       NaN  1.013199  NaN  ...  1.001508  0.993982  1.008340
# 2014-01-07       NaN  0.992337  NaN  ...  1.014148  1.015449  1.008272
# 2014-01-08       NaN  1.009009  NaN  ...  0.996735  1.001850  0.990976
# 2014-01-09       NaN  1.001786  NaN  ...  0.990272  1.003694  0.997517
# ...              ...       ...  ...  ...       ...       ...       ...
# 2025-04-11  1.005531  1.019116  NaN  ...  1.032122       NaN       NaN
# 2025-04-14  0.988476  1.008512  NaN  ...  1.002424       NaN       NaN
# 2025-04-15  1.012542  0.990971  NaN  ...  0.997195       NaN       NaN
# 2025-04-16  0.982554  1.027571  NaN  ...  1.010572       NaN       NaN
# 2025-04-17  1.000533  1.009869  NaN  ...  1.026202       NaN       NaN
#
#                  XYL  YHOO       YUM       ZBH      ZBRA      ZION       ZTS
# Date
# 2014-01-03  1.009075   NaN  1.006259  1.004337       NaN  1.007082  0.990420
# 2014-01-06  0.998259   NaN  0.999206  1.006477       NaN  0.992967  0.997816
# 2014-01-07  1.002906   NaN  1.014040  1.019948       NaN  1.003035  1.003753
# 2014-01-08  0.999421   NaN  0.999608  1.024501       NaN  1.008742  0.988785
# 2014-01-09  1.004059   NaN  0.980661  0.990147       NaN  1.007333  1.006932
# ...              ...   ...       ...       ...       ...       ...       ...
# 2025-04-11  1.012816   NaN  0.996564  1.000880  1.009267       NaN  1.016599
# 2025-04-14  1.005868   NaN  1.006897  0.996287  1.028078       NaN  1.009301
# 2025-04-15  0.994895   NaN  0.991027  0.953908  0.984208       NaN  0.989326
# 2025-04-16  1.000458   NaN  0.985348  0.996607  0.985314       NaN  0.983514
# 2025-04-17  1.011265   NaN  1.005190  1.010109  1.008765       NaN  1.013014
#
# [2840 rows x 727 columns]

# %%
# Aggregating returns across the each month
# This will tell us our return if we had remained invested in any stock throughout the month
mth_ret = (ret).resample('ME').prod(min_count=1)
mth_ret
# Out:
#                    A        AA       AAL       AAP      AAPL      ABBV  ABMD  \
# Date
# 2014-01-31  1.034513  1.093068  1.322950  1.046201  0.905031  0.954597   NaN
# 2014-02-28  0.979020  1.022662  1.100745  1.109311  1.057512  1.034125   NaN
# 2014-03-31  0.982259  1.096252  0.991064  0.993721  1.019952  1.009626   NaN
# 2014-04-30  0.968720  1.046620  0.958197  0.958814  1.099396  1.022297   NaN
# 2014-05-31  1.053664  1.012674  1.145138  1.023745  1.078710  1.043203   NaN
# ...              ...       ...       ...       ...       ...       ...   ...
# 2024-12-31  0.975490       NaN       NaN       NaN  1.055155  0.971410   NaN
# 2025-01-31  1.127885       NaN       NaN       NaN  0.942417  1.044649   NaN
# 2025-02-28  0.844245       NaN       NaN       NaN  1.025872  1.136650   NaN
# 2025-03-31  0.914478       NaN       NaN       NaN  0.918500  1.002344   NaN
# 2025-04-30  0.877908       NaN       NaN       NaN  0.886778  0.833279   NaN
#
#                 ABNB       ABT  ACE  ...       XOM      XRAY       XRX  \
# Date                                 ...
# 2014-01-31       NaN  0.964294  NaN  ...  0.923910  0.962052  0.910999
# 2014-02-28       NaN  1.085106  NaN  ...  1.051995  0.983528  1.012903
# 2014-03-31       NaN  0.968075  NaN  ...  1.014647  1.016016  1.034157
# 2014-04-30       NaN  1.011947  NaN  ...  1.048423  0.969375  1.069911
# 2014-05-31       NaN  1.032782  NaN  ...  0.988307  1.059601  1.021506
# ...              ...       ...  ...  ...       ...       ...       ...
# 2024-12-31  0.965469  0.952345  NaN  ...  0.911919       NaN       NaN
# 2025-01-31  0.998174  1.136958  NaN  ...  0.993121       NaN       NaN
# 2025-02-28  1.058702  1.078793  NaN  ...  1.051444       NaN       NaN
# 2025-03-31  0.860229  0.961162  NaN  ...  1.068266       NaN       NaN
# 2025-04-30  0.943412  0.991984  NaN  ...  0.899016       NaN       NaN
#
#                  XYL  YHOO       YUM       ZBH      ZBRA      ZION       ZTS
# Date
# 2014-01-31  0.976581   NaN  0.898802  1.018755       NaN  0.969645  0.940354
# 2014-02-28  1.183560   NaN  1.103202  0.998617       NaN  1.086624  1.021739
# 2014-03-31  0.925540   NaN  1.017684  1.010276       NaN  0.992949  0.932946
# 2014-04-30  1.032126   NaN  1.026199  1.023473       NaN  0.933506  1.048180
# 2014-05-31  0.995739   NaN  1.004156  1.077996       NaN  0.989989  1.014541
# ...              ...   ...       ...       ...       ...       ...       ...
# 2024-12-31  0.915345   NaN  0.970276  0.944405  0.948943       NaN  0.929700
# 2025-01-31  1.069126   NaN  0.972719  1.036448  1.014810       NaN  1.052088
# 2025-02-28  1.058497   NaN  1.203900  0.952868  0.803822       NaN  0.978584
# 2025-03-31  0.912675   NaN  1.006331  1.087255  0.896874       NaN  0.984513
# 2025-04-30  0.924326   NaN  0.910714  0.865171  0.802414       NaN  0.902946
#
# [136 rows x 727 columns]

# %%
# Rolling 12 month returns
# At the beggining of each month we will re-invest into the 5 stocks that have performed most strongly over the past 12 months
rolling = mth_ret.rolling(12).apply(np.prod)
rolling
# Out:
#                    A  AA  AAL  AAP      AAPL      ABBV  ABMD      ABNB  \
# Date
# 2014-01-31       NaN NaN  NaN  NaN       NaN       NaN   NaN       NaN
# 2014-02-28       NaN NaN  NaN  NaN       NaN       NaN   NaN       NaN
# 2014-03-31       NaN NaN  NaN  NaN       NaN       NaN   NaN       NaN
# 2014-04-30       NaN NaN  NaN  NaN       NaN       NaN   NaN       NaN
# 2014-05-31       NaN NaN  NaN  NaN       NaN       NaN   NaN       NaN
# ...              ...  ..  ...  ...       ...       ...   ...       ...
# 2024-12-31  0.972971 NaN  NaN  NaN  1.307053  1.188590   NaN  0.965256
# 2025-01-31  1.172724 NaN  NaN  NaN  1.286096  1.159362   NaN  0.910018
# 2025-02-28  0.937737 NaN  NaN  NaN  1.344298  1.230585   NaN  0.881882
# 2025-03-31  0.809509 NaN  NaN  NaN  1.301486  1.192489   NaN  0.724176
# 2025-04-30  0.753376 NaN  NaN  NaN  1.161922  1.102277   NaN  0.710727
#
#                  ABT  ACE  ...       XOM  XRAY  XRX       XYL  YHOO       YUM  \
# Date                       ...
# 2014-01-31       NaN  NaN  ...       NaN   NaN  NaN       NaN   NaN       NaN
# 2014-02-28       NaN  NaN  ...       NaN   NaN  NaN       NaN   NaN       NaN
# 2014-03-31       NaN  NaN  ...       NaN   NaN  NaN       NaN   NaN       NaN
# 2014-04-30       NaN  NaN  ...       NaN   NaN  NaN       NaN   NaN       NaN
# 2014-05-31       NaN  NaN  ...       NaN   NaN  NaN       NaN   NaN       NaN
# ...              ...  ...  ...       ...   ...  ...       ...   ...       ...
# 2024-12-31  1.048126  NaN  ...  1.112616   NaN  NaN  1.025712   NaN  1.047221
# 2025-01-31  1.153664  NaN  ...  1.074547   NaN  NaN  1.115341   NaN  1.027856
# 2025-02-28  1.186973  NaN  ...  1.101108   NaN  NaN  1.041786   NaN  1.151839
# 2025-03-31  1.190861  NaN  ...  1.057677   NaN  NaN  0.934700   NaN  1.157209
# 2025-04-30  1.260788  NaN  ...  0.934548   NaN  NaN  0.854316   NaN  1.034488
#
#                  ZBH      ZBRA  ZION       ZTS
# Date
# 2014-01-31       NaN       NaN   NaN       NaN
# 2014-02-28       NaN       NaN   NaN       NaN
# 2014-03-31       NaN       NaN   NaN       NaN
# 2014-04-30       NaN       NaN   NaN       NaN
# 2014-05-31       NaN       NaN   NaN       NaN
# ...              ...       ...   ...       ...
# 2024-12-31  0.875422  1.413017   NaN  0.833681
# 2025-01-31  0.879156  1.636151   NaN  0.919667
# 2025-02-28  0.846072  1.127272   NaN  0.852234
# 2025-03-31  0.865159  0.937367   NaN  0.983429
# 2025-04-30  0.821320  0.720785   NaN  0.940896
#
# [136 rows x 727 columns]

# %%
rolling.dropna(how='all', axis=0, inplace=True)
rolling.dropna(how='all', axis=1, inplace=True)
rolling
# Out:
#                    A        AA       AAL       AAP      AAPL      ABBV  \
# Date
# 2014-12-31  1.025400  1.512353  2.125430  1.454013  1.426284  1.299609
# 2015-01-31  0.916681  1.371319  1.470280  1.387359  1.672752  1.264954
# 2015-02-28  1.046393  1.269536  1.306241  1.218636  1.741187  1.226252
# 2015-03-31  1.051218  1.011647  1.452297  1.185334  1.653571  1.175214
# 2015-04-30  1.080462  1.003991  1.389562  1.180999  1.512775  1.280294
# ...              ...       ...       ...       ...       ...       ...
# 2024-12-31  0.972971       NaN       NaN       NaN  1.307053  1.188590
# 2025-01-31  1.172724       NaN       NaN       NaN  1.286096  1.159362
# 2025-02-28  0.937737       NaN       NaN       NaN  1.344298  1.230585
# 2025-03-31  0.809509       NaN       NaN       NaN  1.301486  1.192489
# 2025-04-30  0.753376       NaN       NaN       NaN  1.161922  1.102277
#
#                 ABNB       ABT      ACGL       ACN  ...       XEL       XOM  \
# Date                                                ...
# 2014-12-31       NaN  1.203978       NaN  1.129180  ...  1.355785  0.953096
# 2015-01-31       NaN  1.247919       NaN  1.079049  ...  1.347955  0.975464
# 2015-02-28       NaN  1.217103       NaN  1.107966  ...  1.209412  0.946200
# 2015-03-31       NaN  1.229639       NaN  1.205510  ...  1.189980  0.895257
# 2015-04-30       NaN  1.223710       NaN  1.183145  ...  1.104290  0.877717
# ...              ...       ...       ...       ...  ...       ...       ...
# 2024-12-31  0.965256  1.048126  1.307643  1.018623  ...  1.123209  1.112616
# 2025-01-31  0.910018  1.153664  1.187381  1.070999  ...  1.165554  1.074547
# 2025-02-28  0.881882  1.186973  1.115511  0.941389  ...  1.420952  1.101108
# 2025-03-31  0.724176  1.190861  1.094185  0.911407  ...  1.364394  1.057677
# 2025-04-30  0.710727  1.260788  1.040732  0.946272  ...  1.352176  0.934548
#
#                 XRAY       XRX       XYL       YUM       ZBH      ZBRA  \
# Date
# 2014-12-31  1.116846  1.187226  1.130046  0.990258  1.240207       NaN
# 2015-01-31  1.090291  1.238334  1.036476  1.099341  1.203207       NaN
# 2015-02-28  1.174581  1.267117  0.920462  1.118237  1.293976       NaN
# 2015-03-31  1.111377  1.159763  0.975570  1.066429  1.252591       NaN
# 2015-04-30  1.148967  0.970099  0.999185  1.140754  1.143884       NaN
# ...              ...       ...       ...       ...       ...       ...
# 2024-12-31       NaN       NaN  1.025712  1.047221  0.875422  1.413017
# 2025-01-31       NaN       NaN  1.115341  1.027856  0.879156  1.636151
# 2025-02-28       NaN       NaN  1.041786  1.151839  0.846072  1.127272
# 2025-03-31       NaN       NaN  0.934700  1.157209  0.865159  0.937367
# 2025-04-30       NaN       NaN  0.854316  1.034488  0.821320  0.720785
#
#                 ZION       ZTS
# Date
# 2014-12-31  0.966856  1.341522
# 2015-01-31  0.837989  1.419331
# 2015-02-28  0.861973  1.498365
# 2015-03-31  0.876535  1.613026
# 2015-04-30  0.985573  1.479367
# ...              ...       ...
# 2024-12-31       NaN  0.833681
# 2025-01-31       NaN  0.919667
# 2025-02-28       NaN  0.852234
# 2025-03-31       NaN  0.983429
# 2025-04-30       NaN  0.940896
#
# [125 rows x 569 columns]

# %% [markdown]
# ## Identifying our stocks for investing

# %%
# These were the top 5 performing stocks for the previous 12 months
# The algorithm should invest into these stocks for following month as they have the most momentum
top = rolling.iloc[0].nlargest(5)
top
# Out:
# LUV    2.258265
# AAL    2.125430
# EA     2.059570
# EW     1.932342
# COV    1.888889
# Name: 2014-12-31 00:00:00, dtype: float64

# %%
# We can extract the date from the series using .name
top.name
# Out:
# Timestamp('2014-12-31 00:00:00')

# %%
# We can see how our investments would have performed over the following month had we invested in them
# iloc[1] is the index for the month following that which was extracted on the 12 month rolling data
invested = mth_ret[top.name:].iloc[1][top.index]
invested
# Out:
# LUV    1.067580
# AAL    0.915159
# EA     1.166738
# EW     0.984063
# COV    1.000000
# Name: 2015-01-31 00:00:00, dtype: float64

# %%
# This would be our investment return if we were to invest equally into each stock
invested.mean()
# Out:
# np.float64(1.0267081389043908)

# %%
def top_performers(date):
    top = rolling.loc[date].nlargest(5)
    invested = mth_ret[top.name:].iloc[1][top.index]

    print(top)
    print(invested)

    return invested.mean()

# %%
top
# Out:
# LUV    2.258265
# AAL    2.125430
# EA     2.059570
# EW     1.932342
# COV    1.888889
# Name: 2014-12-31 00:00:00, dtype: float64

# %%
df_test = pd.DataFrame()
df_test

# %%
df_test.loc[invested.name, invested.index] = invested
df_test

# %%
top_performers(rolling.iloc[0].name)
# Out:
# LUV    2.258265
# AAL    2.125430
# EA     2.059570
# EW     1.932342
# COV    1.888889
# Name: 2014-12-31 00:00:00, dtype: float64
# LUV    1.067580
# AAL    0.915159
# EA     1.166738
# EW     0.984063
# COV    1.000000
# Name: 2015-01-31 00:00:00, dtype: float64
# np.float64(1.0267081389043908)

# %%
init_inv = 100
curr_inv = init_inv
df_stocks = pd.DataFrame()
df_stocks.index = ['prev', 'curr']
trade_fee = 0.01

df_test = pd.DataFrame()

for date in rolling.index[:10]: #rolling.index[:-1]:
    
    top = rolling.loc[date].nlargest(5)
    invested = mth_ret[top.name:].iloc[1][top.index]

    # curr_stocks.loc['curr'][top.sort_values(ascending=False).index.tolist()] = 20

    # if prev_stocks != None:
    #     print('Previously invested in :', prev_stocks)
    #     print('Current investment', curr_inv)
    # else:
    #     print('Initial investment', init_inv)

    # print('Investing equally into momentum stocks :', curr_stocks)
    # print(curr_inv / 5)

    # print('\n')

    # prev_stocks = curr_stocks

    df_test.loc[invested.name, invested.index.tolist()] = invested.values.tolist()

    # print('\n')
    # print(date, '\n')
    # print(top, '\n')
    # print(invested, '\n')


df_test.replace(b'', np.nan, inplace=True)
df_test = df_test.astype(float)
df_test
# Out:
# /tmp/ipykernel_24068/1768512094.py:37: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_test.replace(b'', np.nan, inplace=True)
#                  LUV       AAL        EA        EW  COV        KR      MNST  \
# 2015-01-31  1.067580  0.915159  1.166738  0.984063  1.0       NaN       NaN
# 2015-02-28  0.957061       NaN  1.042289  1.061189  NaN  1.033079       NaN
# 2015-03-31  1.025906       NaN  1.028681  1.070967  NaN       NaN  0.980726
# 2015-04-30  0.915576       NaN  0.987589  0.889021  NaN  0.898905  0.990679
# 2015-05-31       NaN       NaN  1.080392       NaN  NaN       NaN  0.928306
# 2015-06-30       NaN       NaN  1.059592       NaN  NaN       NaN  1.052954
# 2015-07-31       NaN       NaN  1.075940       NaN  NaN       NaN  1.145725
# 2015-08-31       NaN       NaN  0.924528       NaN  NaN       NaN  0.901726
# 2015-09-30       NaN       NaN  1.024187       NaN  NaN       NaN       NaN
# 2015-10-31       NaN       NaN  1.063764       NaN  NaN       NaN       NaN
#
#                  HBI      VRTX       COR      AVGO       HUM      COTY  \
# 2015-01-31       NaN       NaN       NaN       NaN       NaN       NaN
# 2015-02-28       NaN       NaN       NaN       NaN       NaN       NaN
# 2015-03-31  1.050964       NaN       NaN       NaN       NaN       NaN
# 2015-04-30       NaN       NaN       NaN       NaN       NaN       NaN
# 2015-05-31       NaN  1.040639  0.987282  1.266855       NaN       NaN
# 2015-06-30       NaN  0.962507       NaN  0.900287  0.892436       NaN
# 2015-07-31       NaN       NaN       NaN  0.941398       NaN  0.836096
# 2015-08-31       NaN       NaN       NaN  1.006633       NaN       NaN
# 2015-09-30       NaN       NaN       NaN       NaN       NaN  0.901517
# 2015-10-31       NaN       NaN       NaN       NaN       NaN  1.069845
#
#                 REGN      NFLX       AYI       ALK      PENN     ORLY
# 2015-01-31       NaN       NaN       NaN       NaN       NaN      NaN
# 2015-02-28       NaN       NaN       NaN       NaN       NaN      NaN
# 2015-03-31       NaN       NaN       NaN       NaN       NaN      NaN
# 2015-04-30       NaN       NaN       NaN       NaN       NaN      NaN
# 2015-05-31       NaN       NaN       NaN       NaN       NaN      NaN
# 2015-06-30       NaN       NaN       NaN       NaN       NaN      NaN
# 2015-07-31  1.085331       NaN       NaN       NaN       NaN      NaN
# 2015-08-31       NaN  1.006299  0.968587       NaN       NaN      NaN
# 2015-09-30       NaN  0.897679       NaN  1.061314  0.924009      NaN
# 2015-10-31       NaN  1.049584       NaN  0.959723       NaN  1.10504

# %%
df_invested_stocks = pd.DataFrame()
df_invested_stocks['invested_amount'] = 0
df_invested_stocks
# Out:
# Empty DataFrame
# Columns: [invested_amount]
# Index: []

# %%
init_contrib = 100
periodic_contrib = 0 # Build this in and work out how to rebalance stocks using it otherwise will be very imbalanced if stocks are held for a long time
old_stocks = []
df_invested_stocks = pd.DataFrame()
df_invested_stocks['Invested'] = 0
df_invested_stocks
trade_fee = 0.01 # 1% trade commission fee on all transactions
# Rebalance stocks if enough of a % swing from top to bottom grows throughout the investments
# Investigate Rebalancing strategies
stoploss = None # BUILD IN STOP LOSSESSSSSSSSSSS

for date in rolling.index[:-1]:
    
    bankroll = 0
    fees_total = 0
    df_monthly_summary = pd.DataFrame()
    df_monthly_transactions = pd.DataFrame()
    df_monthly_transactions[['Transaction', 'Market Price', 'Trade Fee', 'Fee Price', 'Final Price']] = None

    top = rolling.loc[date].nlargest(5)
    # If the stock was removed from the S&P for whatever reason, then assume that it kept it's value, for backtesting purposes
    invested = mth_ret[top.name:].iloc[1].loc[df_invested_stocks.index].fillna(1)
    momentum_stocks = top.index.tolist()



    print('\n')
    print(f'Periodic Momentum Stocks To Date {date.date()} : {momentum_stocks}')
    print()
    print('Current Investment £ :', df_invested_stocks['Invested'].sum())

    if len(df_invested_stocks) == 0:
        print('Additional Contribution : ', init_contrib)
        bankroll += init_contrib
    else:
        print('Additional Contribution : ', periodic_contrib)


        df_monthly_summary['Initial'] = df_invested_stocks['Invested'].copy()
        df_monthly_summary['Return %'] = invested.copy()
        df_monthly_summary['Current'] = df_monthly_summary['Initial'] * df_monthly_summary['Return %']
        df_monthly_summary['PnL'] = df_monthly_summary['Current'] - df_monthly_summary['Initial']


        df_monthly_summary.loc['Total', 'Initial'] = df_monthly_summary['Initial'].sum()
        df_monthly_summary.loc['Total', 'Current'] = df_monthly_summary['Current'].sum()
        df_monthly_summary.loc['Total', 'PnL'] = df_monthly_summary['PnL'].sum()
        df_monthly_summary.loc['Total', 'Return %'] = df_monthly_summary.loc['Total', 'Current'] / df_monthly_summary.loc['Total', 'Initial']

        print()
        print('Period Portfilio Summary :')
        print(df_monthly_summary)

        df_invested_stocks = df_invested_stocks.mul(invested.values, axis=0)
        old_stocks = df_invested_stocks.index.to_list()

    owned = list(set(momentum_stocks).intersection(set(old_stocks)))
    selling = list(set(old_stocks) - set(momentum_stocks))
    buying = list(set(momentum_stocks) - set(old_stocks))

    if len(owned) != 0:
        print()
        print('Already Invested In :', owned)

    if len(selling) != 0:
        print()
        print('Stocks To Remove :', selling)

        for stock in selling:
            
            sell_price = df_invested_stocks.loc[stock, 'Invested']
            sell_fee = sell_price * trade_fee
            sell_final = sell_price - sell_fee
            fees_total += sell_fee
            bankroll += sell_final

            df_monthly_transactions.loc[stock] = 'Sell', sell_price, trade_fee, sell_fee, sell_final

            df_invested_stocks.drop(stock, inplace=True)

    if len(buying) != 0:
        print()
        print(f'Investing {bankroll} Equally Into :', buying)

        num_buying = len(buying)
        amt_buying = bankroll / num_buying
        amt_fee = amt_buying * trade_fee
        fees_total = num_buying * amt_fee
        amt_inv = amt_buying - amt_fee

        for stock in buying:
            df_monthly_transactions.loc[stock] = 'Buy', amt_buying, trade_fee, amt_fee, amt_inv

            df_invested_stocks.loc[stock] = amt_inv


    print()
    print('Period Transaction Summary :')
    print(df_monthly_transactions)

    print()
    print('Rebalancing Stocks')
    print()

    print()
    print('Portfolio For Next Period :')

    print('\n')
# Out:
# Periodic Momentum Stocks To Date 2014-12-31 : ['LUV', 'AAL', 'EA', 'EW', 'COV']
#
# Current Investment £ : 0
# Additional Contribution :  100
#
# Investing 100 Equally Into : ['EW', 'LUV', 'AAL', 'EA', 'COV']
#
# Period Transaction Summary :
#     Transaction  Market Price  Trade Fee  Fee Price  Final Price
# EW          Buy          20.0       0.01        0.2         19.8
# LUV         Buy          20.0       0.01        0.2         19.8
# AAL         Buy          20.0       0.01        0.2         19.8
# EA          Buy          20.0       0.01        0.2         19.8
# COV         Buy          20.0       0.01        0.2         19.8
#
# Rebalancing Stocks
#
#
# Portfolio For Next Period :
#      Invested
# EW       19.8
# LUV      19.8
# AAL      19.8
# EA       19.8
# COV      19.8
# Description
#        Invested
# count       5.0
# mean       19.8
# std         0.0
# min        19.8
# 25%        19.8
# 50%        19.8
# 75%        19.8
# max        19.8
#
#
#
#
# Periodic Momentum Stocks To Date 2015-01-31 : ['LUV', 'EA', 'KR', 'EW', 'COV']
#
# Current Investment £ : 99.0
# Additional Contribution :  0
#
# Period Portfilio Summary :
#        Initial  Return %    Current       PnL
# EW        19.8  1.061189  21.011536  1.211536
# LUV       19.8  0.957061  18.949800 -0.850200
# AAL       19.8  0.977935  19.363112 -0.436888
# EA        19.8  1.042289  20.637330  0.837330
# COV       19.8  1.000000  19.800000  0.000000
# Total     99.0  1.007695  99.761779  0.761779
#
# Already Invested In : ['LUV', 'EW', 'EA', 'COV']
#
# Stocks To Remove : ['AAL']
#
# Investing 19.16948135104709 Equally Into : ['KR']
#
# Period Transaction Summary :
#     Transaction  Market Price  Trade Fee  Fee Price  Final Price
# AAL        Sell     19.363112       0.01   0.193631    19.169481
# KR          Buy     19.169481       0.01   0.191695    18.977787
#
# Rebalancing Stocks
#
#
# Portfolio For Next Period :
#       Invested
# EW   21.011536
# LUV  18.949800
# EA   20.637330
# COV  19.800000
# KR   18.977787
# Description
#         Invested
# count   5.000000
# mean   19.875291
# std     0.940674
# min    18.949800
# 25%    18.977787
# 50%    19.800000
# 75%    20.637330
# max    21.011536
#
#
#
#
# Periodic Momentum Stocks To Date 2015-02-28 : ['EA', 'LUV', 'MNST', 'EW', 'HBI']
#
# Current Investment £ : 99.37645263812963
# Additional Contribution :  0
#
# Period Portfilio Summary :
#          Initial  Return %     Current       PnL
# EW     21.011536  1.070967   22.502657  1.491121
# LUV    18.949800  1.025906   19.440723  0.490923
# EA     20.637330  1.028681   21.229234  0.591905
# COV    19.800000  1.000000   19.800000  0.000000
# KR     18.977787  1.077442   20.447464  1.469677
# Total  99.376453  1.040690  103.420078  4.043626
#
# Already Invested In : ['LUV', 'EW', 'EA']
#
# Stocks To Remove : ['KR', 'COV']
#
# Investing 39.8449890053346 Equally Into : ['HBI', 'MNST']
#
# Period Transaction Summary :
#      Transaction  Market Price  Trade Fee  Fee Price  Final Price
# KR          Sell     20.447464       0.01   0.204475    20.242989
# COV         Sell     19.800000       0.01   0.198000    19.602000
# HBI          Buy     19.922495       0.01   0.199225    19.723270
# MNST         Buy     19.922495       0.01   0.199225    19.723270
#
# Rebalancing Stocks
#
#
# Portfolio For Next Period :
#        Invested
# EW    22.502657
# LUV   19.440723
# EA    21.229234
# HBI   19.723270
# MNST  19.723270
# Description
#         Invested
# count   5.000000
# mean   20.523831
# std     1.310369
# min    19.440723
# 25%    19.723270
# 50%    19.723270
# 75%    21.229234
# max    22.502657
#
#
#
#
# Periodic Momentum Stocks To Date 2015-03-31 : ['EA', 'MNST', 'EW', 'LUV', 'KR']
#
# Current Investment £ : 102.61915396131565
# Additional Contribution :  0
#
# Period Portfilio Summary :
#           Initial  Return %    Current       PnL
# EW      22.502657  0.889021  20.005346 -2.497312
# LUV     19.440723  0.915576  17.799450 -1.641273
# EA      21.229234  0.987589  20.965767 -0.263467
# HBI     19.723270  0.927484  18.293022 -1.430248
# MNST    19.723270  0.990679  19.539433 -0.183837
# Total  102.619154  0.941374  96.603017 -6.016137
#
# Already Invested In : ['LUV', 'EW', 'EA', 'MNST']
#
# Stocks To Remove : ['HBI']
#
# Investing 18.110091658635806 Equally Into : ['KR']
#
# Period Transaction Summary :
#     Transaction  Market Price  Trade Fee  Fee Price  Final Price
# HBI        Sell     18.293022       0.01   0.182930    18.110092
# KR          Buy     18.110092       0.01   0.181101    17.928991
#
# Rebalancing Stocks
#
#
# Portfolio For Next Period :
#        Invested
# EW    20.005346
# LUV   17.799450
# EA    20.965767
# MNST  19.539433
# KR    17.928991
# Description
#         Invested
# count   5.000000
# mean   19.247797
# std     1.364488
# min    17.799450
# 25%    17.928991
# 50%    19.539433
# 75%    20.005346
# max    20.965767
#
#
#
#
# Periodic Momentum Stocks To Date 2015-04-30 : ['EA', 'MNST', 'VRTX', 'COR', 'AVGO']
#
# Current Investment £ : 96.23898613839606
# Additional Contribution :  0
#
# Period Portfilio Summary :
#          Initial  Return %    Current       PnL
# EW     20.005346  1.032136  20.648233  0.642888
# LUV    17.799450  0.913461  16.259112 -1.540339
# EA     20.965767  1.080392  22.651257  1.685490
# MNST   19.539433  0.928306  18.138567 -1.400866
# KR     17.928991  1.059197  18.990334  1.061343
# Total  96.238986  1.004660  96.687502  0.448516
#
# Already Invested In : ['EA', 'MNST']
#
# Stocks To Remove : ['EW', 'LUV', 'KR']
#
# Investing 55.33870229459852 Equally Into : ['AVGO', 'COR', 'VRTX']
#
# Period Transaction Summary :
#      Transaction  Market Price  Trade Fee  Fee Price  Final Price
# EW          Sell     20.648233       0.01   0.206482    20.441751
# LUV         Sell     16.259112       0.01   0.162591    16.096520
# KR          Sell     18.990334       0.01   0.189903    18.800431
# AVGO         Buy     18.446234       0.01   0.184462    18.261772
# COR          Buy     18.446234       0.01   0.184462    18.261772
# VRTX         Buy     18.446234       0.01   0.184462    18.261772
#
# Rebalancing Stocks
#
#
# Portfolio For Next Period :
#        Invested
# EA    22.651257
# MNST  18.138567
# AVGO  18.261772
# COR   18.261772
# VRTX  18.261772
# Description
#         Invested
# count   5.000000
# mean   19.115028
# std     1.977532
# min    18.138567
# 25%    18.261772
# 50%    18.261772
# 75%    18.261772
# max    22.651257
#
#
#
#
# Periodic Momentum Stocks To Date 2015-05-31 : ['AVGO', 'MNST', 'EA', 'VRTX', 'HUM']
#
# Current Investment £ : 95.57513867410178
# Additional Contribution :  0
#
# Period Portfilio Summary :
#          Initial  Return %    Current       PnL
# EA     22.651257  1.059592  24.001089  1.349832
# MNST   18.138567  1.052954  19.099078  0.960511
# AVGO   18.261772  0.900287  16.440841 -1.820931
# COR    18.261772  0.944741  17.252636 -1.009136
# VRTX   18.261772  0.962507  17.577081 -0.684690
# Total  95.575139  0.987398  94.370725 -1.204413
#
# Already Invested In : ['AVGO', 'EA', 'VRTX', 'MNST']
#
# Stocks To Remove : ['COR']
#
# Investing 17.08010967807815 Equally Into : ['HUM']
#
# Period Transaction Summary :
#     Transaction  Market Price  Trade Fee  Fee Price  Final Price
# COR        Sell     17.252636       0.01   0.172526    17.080110
# HUM         Buy     17.080110       0.01   0.170801    16.909309
#
# Rebalancing Stocks
#
#
# Portfolio For Next Period :
#        Invested
# EA    24.001089
# MNST  19.099078
# AVGO  16.440841
# VRTX  17.577081
# HUM   16.909309
# Description
#         Invested
# count   5.000000
# mean   18.805480
# std     3.073130
# min    16.440841
# 25%    16.909309
# 50%    17.577081
# 75%    19.099078
# max    24.001089
#
#
#
#
# Periodic Momentum Stocks To Date 2015-06-30 : ['COTY', 'MNST', 'AVGO', 'EA', 'REGN']
#
# Current Investment £ : 94.02739782777323
# Additional Contribution :  0
#
# Period Portfilio Summary :
#          Initial  Return %    Current       PnL
# EA     24.001089  1.075940  25.823733  1.822644
# MNST   19.099078  1.145725  21.882283  2.783205
# AVGO   16.440841  0.941398  15.477369 -0.963472
# VRTX   17.577081  1.093294  19.216925  1.639844
# HUM    16.909309  0.951955  16.096900 -0.812409
# Total  94.027398  1.047537  98.497211  4.469813
#
# Already Invested In : ['AVGO', 'EA', 'MNST']
#
# Stocks To Remove : ['HUM', 'VRTX']
#
# Investing 34.9606868211582 Equally Into : ['REGN', 'COTY']
#
# Period Transaction Summary :
#      Transaction  Market Price  Trade Fee  Fee Price  Final Price
# HUM         Sell     16.096900       0.01   0.160969    15.935931
# VRTX        Sell     19.216925       0.01   0.192169    19.024756
# REGN         Buy     17.480343       0.01   0.174803    17.305540
# COTY         Buy     17.480343       0.01   0.174803    17.305540
#
# Rebalancing Stocks
#
#
# Portfolio For Next Period :
#        Invested
# EA    25.823733
# MNST  21.882283
# AVGO  15.477369
# REGN  17.305540
# COTY  17.305540
# Description
#         Invested
# count   5.000000
# mean   19.558893
# std     4.226713
# min    15.477369
# 25%    17.305540
# 50%    17.305540
# 75%    21.882283
# max    25.823733
#
#
#
#
# Periodic Momentum Stocks To Date 2015-07-31 : ['MNST', 'EA', 'NFLX', 'AYI', 'AVGO']
#
# Current Investment £ : 97.794465564102
# Additional Contribution :  0
#
# Period Portfilio Summary :
#          Initial  Return %    Current       PnL
# EA     25.823733  0.924528  23.874773 -1.948960
# MNST   21.882283  0.901726  19.731820 -2.150463
# AVGO   15.477369  1.006633  15.580028  0.102659
# REGN   17.305540  0.927465  16.050274 -1.255266
# COTY   17.305540  1.133932  19.623308  2.317768
# Total  97.794466  0.969996  94.860204 -2.934262
#
# Already Invested In : ['AVGO', 'EA', 'MNST']
#
# Stocks To Remove : ['REGN', 'COTY']
#
# Investing 35.316846227033636 Equally Into : ['NFLX', 'AYI']
#
# Period Transaction Summary :
#      Transaction  Market Price  Trade Fee  Fee Price  Final Price
# REGN        Sell     16.050274       0.01   0.160503    15.889771
# COTY        Sell     19.623308       0.01   0.196233    19.427075
# NFLX         Buy     17.658423       0.01   0.176584    17.481839
# AYI          Buy     17.658423       0.01   0.176584    17.481839
#
# Rebalancing Stocks
#
#
# Portfolio For Next Period :
#        Invested
# EA    23.874773
# MNST  19.731820
# AVGO  15.580028
# NFLX  17.481839
# AYI   17.481839
# Description
#         Invested
# count   5.000000
# mean   18.830060
# std     3.180425
# min    15.580028
# 25%    17.481839
# 50%    17.481839
# 75%    19.731820
# max    23.874773
#
#
#
#
# Periodic Momentum Stocks To Date 2015-08-31 : ['COTY', 'EA', 'NFLX', 'ALK', 'PENN']
#
# Current Investment £ : 94.15029942304588
# Additional Contribution :  0
#
# Period Portfilio Summary :
#          Initial  Return %    Current       PnL
# EA     23.874773  1.024187  24.452239  0.577465
# MNST   19.731820  0.976022  19.258688 -0.473132
# AVGO   15.580028  0.995490  15.509769 -0.070259
# NFLX   17.481839  0.897679  15.693078 -1.788761
# AYI    17.481839  0.901011  15.751327 -1.730512
# Total  94.150299  0.962983  90.665101 -3.485198
#
# Already Invested In : ['EA', 'NFLX']
#
# Stocks To Remove : ['AVGO', 'AYI', 'MNST']
#
# Investing 50.01458653984291 Equally Into : ['ALK', 'PENN', 'COTY']
#
# Period Transaction Summary :
#      Transaction  Market Price  Trade Fee  Fee Price  Final Price
# AVGO        Sell     15.509769       0.01   0.155098    15.354672
# AYI         Sell     15.751327       0.01   0.157513    15.593814
# MNST        Sell     19.258688       0.01   0.192587    19.066101
# ALK          Buy     16.671529       0.01   0.166715    16.504814
# PENN         Buy     16.671529       0.01   0.166715    16.504814
# COTY         Buy     16.671529       0.01   0.166715    16.504814
#
# Rebalancing Stocks
#
#
# Portfolio For Next Period :
#        Invested
# EA    24.452239
# NFLX  15.693078
# ALK   16.504814
# PENN  16.504814
# COTY  16.504814
# Description
#         Invested
# count   5.000000
# mean   17.931951
# std     3.661860
# min    15.693078
# 25%    16.504814
# 50%    16.504814
# 75%    16.504814
# max    24.452239
#
#
#
#
# Periodic Momentum Stocks To Date 2015-09-30 : ['EA', 'ALK', 'ORLY', 'COTY', 'NFLX']
#
# Current Investment £ : 89.65975721895366
# Additional Contribution :  0
#
# Period Portfilio Summary :
#          Initial  Return %    Current       PnL
# EA     24.452239  1.063764  26.011410  1.559171
# NFLX   15.693078  1.049584  16.471196  0.778118
# ALK    16.504814  0.959723  15.840051 -0.664762
# PENN   16.504814  1.064362  17.567102  1.062288
# COTY   16.504814  1.069845  17.657590  1.152777
# Total  89.659757  1.043359  93.547349  3.887592
#
# Already Invested In : ['ALK', 'COTY', 'EA', 'NFLX']
#
# Stocks To Remove : ['PENN']
#
# Investing 17.39143077939775 Equally Into : ['ORLY']
#
# Period Transaction Summary :
#      Transaction  Market Price  Trade Fee  Fee Price  Final Price
# PENN        Sell     17.567102       0.01   0.175671    17.391431
# ORLY         Buy     17.391431       0.01   0.173914    17.217516
#
# Rebalancing Stocks
#
#
# Portfolio For Next Period :
#        Invested
# EA    26.011410
# NFLX  16.471196
# ALK   15.840051
# COTY  17.657590
# ORLY  17.217516
# Description
#         Invested
# count   5.000000
# mean   18.639553
# std     4.179405
# min    15.840051
# 25%    16.471196
# 50%    17.217516
# 75%    17.657590
# max    26.011410
#
#
#
#
# Periodic Momentum Stocks To Date 2015-10-31 : ['AMZN', 'NFLX', 'COTY', 'EA', 'SBUX']
#
# Current Investment £ : 93.19776401025547
# Additional Contribution :  0
#
# Period Portfilio Summary :
#          Initial  Return %    Current       PnL
# EA     26.011410  0.940613  24.466679 -1.544731
# NFLX   16.471196  1.137941  18.743243  2.272047
# ALK    15.840051  1.048374  16.606295  0.766243
# COTY   17.657590  0.959585  16.943964 -0.713626
# ORLY   17.217516  0.955151  16.445326 -0.772190
# Total  93.197764  1.000083  93.205507  0.007743
#
# Already Invested In : ['COTY', 'NFLX', 'EA']
#
# Stocks To Remove : ['ALK', 'ORLY']
#
# Investing 32.721104577232744 Equally Into : ['SBUX', 'AMZN']
#
# Period Transaction Summary :
#      Transaction  Market Price  Trade Fee  Fee Price  Final Price
# ALK         Sell     16.606295       0.01   0.166063    16.440232
# ORLY        Sell     16.445326       0.01   0.164453    16.280873
# SBUX         Buy     16.360552       0.01   0.163606    16.196947
# AMZN         Buy     16.360552       0.01   0.163606    16.196947
#
# Rebalancing Stocks
#
#
# Portfolio For Next Period :
#        Invested
# EA    24.466679
# NFLX  18.743243
# COTY  16.943964
# SBUX  16.196947
# AMZN  16.196947
# Description
#         Invested
# count   5.000000
# mean   18.509556
# std     3.488887
# min    16.196947
# 25%    16.196947
# 50%    16.943964
# 75%    18.743243
# max    24.466679
#
#
#
#
# Periodic Momentum Stocks To Date 2015-11-30 : ['NFLX', 'AMZN', 'AYI', 'EVHC', 'VMC']
#
# Current Investment £ : 92.54778021695745
# Additional Contribution :  0
#
# Period Portfilio Summary :
#          Initial  Return %    Current       PnL
# EA     24.466679  1.013719  24.802335  0.335656
# NFLX   18.743243  0.927430  17.383054 -1.360189
# COTY   16.943964  0.922606  15.632607 -1.311357
# SBUX   16.196947  0.977847  15.838129 -0.358818
# AMZN   16.196947  1.016682  16.467138  0.270191
# Total  92.547780  0.973803  90.123263 -2.424517
#
# Already Invested In : ['NFLX', 'AMZN']
#
# Stocks To Remove : ['COTY', 'SBUX', 'EA']
#
# Investing 55.71034029600802 Equally Into : ['VMC', 'AYI', 'EVHC']
#
# Period Transaction Summary :
#      Transaction  Market Price  Trade Fee  Fee Price  Final Price
# COTY        Sell     15.632607       0.01   0.156326    15.476281
# SBUX        Sell     15.838129       0.01   0.158381    15.679747
# EA          Sell     24.802335       0.01   0.248023    24.554312
# VMC          Buy     18.570113       0.01   0.185701    18.384412
# AYI          Buy     18.570113       0.01   0.185701    18.384412
# EVHC         Buy     18.570113       0.01   0.185701    18.384412
#
# Rebalancing Stocks
#
#
# Portfolio For Next Period :
#        Invested
# NFLX  17.383054
# AMZN  16.467138
# VMC   18.384412
# AYI   18.384412
# EVHC  18.384412
# Description
#         Invested
# count   5.000000
# mean   17.800686
# std     0.862406
# min    16.467138
# 25%    17.383054
# 50%    18.384412
# 75%    18.384412
# max    18.384412
#
#
#
#
# Periodic Momentum Stocks To Date 2015-12-31 : ['NFLX', 'AMZN', 'AYI', 'NVDA', 'HRL']
#
# Current Investment £ : 89.00342884367419
# Additional Contribution :  0
#
# Period Portfilio Summary :
#          Initial  Return %    Current        PnL
# NFLX   17.383054  0.802938  13.957507  -3.425547
# AMZN   16.467138  0.868485  14.301455  -2.165683
# VMC    18.384412  0.928714  17.073869  -1.310544
# AYI    18.384412  0.866370  15.927697  -2.456715
# EVHC   18.384412  0.963026  17.704673  -0.679739
# Total  89.003429  0.887215  78.965202 -10.038227
#
# Already Invested In : ['NFLX', 'AYI', 'AMZN']
#
# Stocks To Remove : ['VMC', 'EVHC']
#
# Investing 34.43075666028845 Equally Into : ['NVDA', 'HRL']
#
# Period Transaction Summary :
#      Transaction  Market Price  Trade Fee  Fee Price  Final Price
# VMC         Sell     17.073869       0.01   0.170739    16.903130
# EVHC        Sell     17.704673       0.01   0.177047    17.527627
# NVDA         Buy     17.215378       0.01   0.172154    17.043225
# HRL          Buy     17.215378       0.01   0.172154    17.043225
#
# Rebalancing Stocks
#
#
# Portfolio For Next Period :
#        Invested
# NFLX  13.957507
# AMZN  14.301455
# AYI   15.927697
# NVDA  17.043225
# HRL   17.043225
# Description
#         Invested
# count   5.000000
# mean   15.654622
# std     1.469886
# min    13.957507
# 25%    14.301455
# 50%    15.927697
# 75%    17.043225
# max    17.043225
#
#
#
#
# Periodic Momentum Stocks To Date 2016-01-31 : ['AMZN', 'HRL', 'NVDA', 'META', 'NFLX']
#
# Current Investment £ : 78.27310851776134
# Additional Contribution :  0
#
# Period Portfilio Summary :
#          Initial  Return %    Current       PnL
# NFLX   13.957507  1.017095  14.196111  0.238604
# AMZN   14.301455  0.941261  13.461397 -0.840059
# AYI    15.927697  1.034580  16.478472  0.550775
# NVDA   17.043225  1.074574  18.314207  1.270982
# HRL    17.043225  1.057331  18.020327  0.977102
# Total  78.273109  1.028074  80.470513  2.197404
#
# Already Invested In : ['HRL', 'NFLX', 'NVDA', 'AMZN']
#
# Stocks To Remove : ['AYI']
#
# Investing 16.313687402934885 Equally Into : ['META']
#
# Period Transaction Summary :
#      Transaction  Market Price  Trade Fee  Fee Price  Final Price
# AYI         Sell     16.478472       0.01   0.164785    16.313687
# META         Buy     16.313687       0.01   0.163137    16.150551
#
# Rebalancing Stocks
#
#
# Portfolio For Next Period :
#        Invested
# NFLX  14.196111
# AMZN  13.461397
# NVDA  18.314207
# HRL   18.020327
# META  16.150551
# Description
#         Invested
# count   5.000000
# mean   16.028518
# std     2.188287
# min    13.461397
# 25%    14.196111
# 50%    16.150551
# 75%    18.020327
# max    18.314207
#
#
#
#
# Periodic Momentum Stocks To Date 2016-02-29 : ['TSN', 'HRL', 'AMZN', 'NVDA', 'NFLX']
#
# Current Investment £ : 80.14259138070413
# Additional Contribution :  0
#
# Period Portfilio Summary :
#          Initial  Return %    Current       PnL
# NFLX   14.196111  1.094422  15.536542  1.340431
# AMZN   13.461397  1.074423  14.463229  1.001833
# NVDA   18.314207  1.136160  20.807877  2.493671
# HRL    18.020327  1.017173  18.329784  0.309458
# META   16.150551  1.067153  17.235109  1.084559
# Total  80.142591  1.077736  86.372543  6.229951
#
# Already Invested In : ['HRL', 'NFLX', 'NVDA', 'AMZN']
#
# Stocks To Remove : ['META']
#
# Investing 17.06275834630704 Equally Into : ['TSN']
#
# Period Transaction Summary :
#      Transaction  Market Price  Trade Fee  Fee Price  Final Price
# META        Sell     17.235109       0.01   0.172351    17.062758
# TSN          Buy     17.062758       0.01   0.170628    16.892131
#
# Rebalancing Stocks
#
#
# Portfolio For Next Period :
#        Invested
# NFLX  15.536542
# AMZN  14.463229
# NVDA  20.807877
# HRL   18.329784
# TSN   16.892131
# Description
#         Invested
# count   5.000000
# mean   17.205913
# std     2.482177
# min    14.463229
# 25%    15.536542
# 50%    16.892131
# 75%    18.329784
# max    20.807877
#
#
#
#
# Periodic Momentum Stocks To Date 2016-03-31 : ['TSN', 'NVDA', 'NFLX', 'AMZN', 'MAT']
#
# Current Investment £ : 86.02956401779133
# Additional Contribution :  0
#
# Period Portfilio Summary :
#          Initial  Return %    Current       PnL
# NFLX   15.536542  0.880661  13.682430 -1.854112
# AMZN   14.463229  1.111094  16.070011  1.606782
# NVDA   20.807877  0.997193  20.749474 -0.058403
# HRL    18.329784  0.894794  16.401380 -1.928404
# TSN    16.892131  0.987399  16.679267 -0.212864
# Total  86.029564  0.971556  83.582563 -2.447001
#
# Already Invested In : ['TSN', 'NFLX', 'NVDA', 'AMZN']
#
# Stocks To Remove : ['HRL']
#
# Investing 16.237366550989393 Equally Into : ['MAT']
#
# Period Transaction Summary :
#     Transaction  Market Price  Trade Fee  Fee Price  Final Price
# HRL        Sell     16.401380       0.01   0.164014    16.237367
# MAT         Buy     16.237367       0.01   0.162374    16.074993
#
# Rebalancing Stocks
#
#
# Portfolio For Next Period :
#        Invested
# NFLX  13.682430
# AMZN  16.070011
# NVDA  20.749474
# TSN   16.679267
# MAT   16.074993
# Description
#         Invested
# count   5.000000
# mean   16.651235
# std     2.563202
# min    13.682430
# 25%    16.070011
# 50%    16.074993
# 75%    16.679267
# max    20.749474
#
#
#
#
# Periodic Momentum Stocks To Date 2016-04-30 : ['TSN', 'EW', 'NKTR', 'NVDA', 'AMZN']
#
# Current Investment £ : 83.2561753933507
# Additional Contribution :  0
#
# Period Portfilio Summary :
#          Initial  Return %    Current        PnL
# NFLX   13.682430  1.139287  15.588214   1.905784
# AMZN   16.070011  1.095817  17.609793   1.539782
# NVDA   20.749474  1.318360  27.355281   6.605807
# TSN    16.679267  0.971243  16.199617  -0.479650
# MAT    16.074993  1.038161  16.688424   0.613431
# Total  83.256175  1.122335  93.441329  10.185154
#
# Already Invested In : ['TSN', 'NVDA', 'AMZN']
#
# Stocks To Remove : ['MAT', 'NFLX']
#
# Investing 31.953871446699786 Equally Into : ['NKTR', 'EW']
#
# Period Transaction Summary :
#      Transaction  Market Price  Trade Fee  Fee Price  Final Price
# MAT         Sell     16.688424       0.01   0.166884    16.521540
# NFLX        Sell     15.588214       0.01   0.155882    15.432332
# NKTR         Buy     15.976936       0.01   0.159769    15.817166
# EW           Buy     15.976936       0.01   0.159769    15.817166
#
# Rebalancing Stocks
#
#
# Portfolio For Next Period :
#        Invested
# AMZN  17.609793
# NVDA  27.355281
# TSN   16.199617
# NKTR  15.817166
# EW    15.817166
# Description
#         Invested
# count   5.000000
# mean   18.559805
# std     4.971859
# min    15.817166
# 25%    15.817166
# 50%    16.199617
# 75%    17.609793
# max    27.355281
#
#
#
#
# Periodic Momentum Stocks To Date 2016-05-31 : ['NVDA', 'DXC', 'AMZN', 'TSN', 'EW']
#
# Current Investment £ : 92.79902436257447
# Additional Contribution :  0
#
# Period Portfilio Summary :
#          Initial  Return %    Current       PnL
# AMZN   17.609793  0.990080  17.435105 -0.174688
# NVDA   27.355281  1.006207  27.525077  0.169795
# TSN    16.199617  1.047194  16.964135  0.764518
# NKTR   15.817166  0.921632  14.577609 -1.239558
# EW     15.817166  1.012487  16.014680  0.197514
# Total  92.799024  0.996957  92.516605 -0.282419
#
# Already Invested In : ['EW', 'TSN', 'NVDA', 'AMZN']
#
# Stocks To Remove : ['NKTR']
#
# Investing 14.431832480806793 Equally Into : ['DXC']
#
# Period Transaction Summary :
#      Transaction  Market Price  Trade Fee  Fee Price  Final Price
# NKTR        Sell     14.577609       0.01   0.145776    14.431832
# DXC          Buy     14.431832       0.01   0.144318    14.287514
#
# Rebalancing Stocks
#
#
# Portfolio For Next Period :
#        Invested
# AMZN  17.435105
# NVDA  27.525077
# TSN   16.964135
# EW    16.014680
# DXC   14.287514
# Description
#         Invested
# count   5.000000
# mean   18.445302
# std     5.216603
# min    14.287514
# 25%    16.014680
# 50%    16.964135
# 75%    17.435105
# max    27.525077
#
#
#
#
# Periodic Momentum Stocks To Date 2016-06-30 : ['NVDA', 'DXC', 'NEM', 'AMZN', 'O']
#
# Current Investment £ : 92.22651107045155
# Additional Contribution :  0
#
# Period Portfilio Summary :
#          Initial  Return %     Current        PnL
# AMZN   17.435105  1.060353   18.487371   1.052266
# NVDA   27.525077  1.214635   33.432924   5.907848
# TSN    16.964135  1.101962   18.693824   1.729689
# EW     16.014680  1.148300   18.389664   2.374984
# DXC    14.287514  0.963344   13.763787  -0.523727
# Total  92.226511  1.114295  102.767570  10.541059
#
# Already Invested In : ['NVDA', 'DXC', 'AMZN']
#
# Stocks To Remove : ['EW', 'TSN']
#
# Investing 36.71265309593369 Equally Into : ['O', 'NEM']
#
# Period Transaction Summary :
#     Transaction  Market Price  Trade Fee  Fee Price  Final Price
# EW         Sell     18.389664       0.01   0.183897    18.205767
# TSN        Sell     18.693824       0.01   0.186938    18.506886
# O           Buy     18.356327       0.01   0.183563    18.172763
# NEM         Buy     18.356327       0.01   0.183563    18.172763
#
# Rebalancing Stocks
#
#
# Portfolio For Next Period :
#        Invested
# AMZN  18.487371
# NVDA  33.432924
# DXC   13.763787
# O     18.172763
# NEM   18.172763
# Description
#         Invested
# count   5.000000
# mean   20.405922
# std     7.541147
# min    13.763787
# 25%    18.172763
# 50%    18.172763
# 75%    18.487371
# max    33.432924
#
#
#
#
# Periodic Momentum Stocks To Date 2016-07-31 : ['NVDA', 'NEM', 'DHR', 'DXC', 'TSN']
#
# Current Investment £ : 102.0296085356068
# Additional Contribution :  0
#
# Period Portfilio Summary :
#           Initial  Return %     Current       PnL
# AMZN    18.487371  1.013640   18.739535  0.252165
# NVDA    33.432924  1.076235   35.981686  2.548762
# DXC     13.763787  0.986478   13.577675 -0.186112
# O       18.172763  0.922494   16.764260 -1.408503
# NEM     18.172763  0.869091   15.793784 -2.378979
# Total  102.029609  0.988507  100.856942 -1.172667
#
# Already Invested In : ['NVDA', 'DXC', 'NEM']
#
# Stocks To Remove : ['O', 'AMZN']
#
# Investing 35.14875742076016 Equally Into : ['TSN', 'DHR']
#
# Period Transaction Summary :
#      Transaction  Market Price  Trade Fee  Fee Price  Final Price
# O           Sell     16.764260       0.01   0.167643    16.596618
# AMZN        Sell     18.739535       0.01   0.187395    18.552140
# TSN          Buy     17.574379       0.01   0.175744    17.398635
# DHR          Buy     17.574379       0.01   0.175744    17.398635
#
# Rebalancing Stocks
#
#
# Portfolio For Next Period :
#        Invested
# NVDA  35.981686
# DXC   13.577675
# NEM   15.793784
# TSN   17.398635
# DHR   17.398635
# Description
#         Invested
# count   5.000000
# mean   20.030083
# std     9.053763
# min    13.577675
# 25%    15.793784
# 50%    17.398635
# 75%    17.398635
# max    35.981686
#
#
#
#
# Periodic Momentum Stocks To Date 2016-08-31 : ['NVDA', 'NEM', 'DHR', 'AMAT', 'DXC']
#
# Current Investment £ : 100.15041606374052
# Additional Contribution :  0
#
# Period Portfilio Summary :
#           Initial  Return %     Current       PnL
# NVDA    35.981686  1.117053   40.193445  4.211759
# DXC     13.577675  1.109906   15.069949  1.492273
# NEM     15.793784  1.028095   16.237511  0.443726
# TSN     17.398635  0.988090   17.191425 -0.207210
# DHR     17.398635  0.964457   16.780228 -0.618407
# Total  100.150416  1.053141  105.472558  5.322142
#
# Already Invested In : ['NVDA', 'DXC', 'NEM', 'DHR']
#
# Stocks To Remove : ['TSN']
#
# Investing 17.019510779323276 Equally Into : ['AMAT']
#
# Period Transaction Summary :
#      Transaction  Market Price  Trade Fee  Fee Price  Final Price
# TSN         Sell     17.191425       0.01   0.171914    17.019511
# AMAT         Buy     17.019511       0.01   0.170195    16.849316
#
# Rebalancing Stocks
#
#
# Portfolio For Next Period :
#        Invested
# NVDA  40.193445
# DXC   15.069949
# NEM   16.237511
# DHR   16.780228
# AMAT  16.849316
# Description
#         Invested
# count   5.000000
# mean   21.026090
# std    10.738557
# min    15.069949
# 25%    16.237511
# 50%    16.780228
# 75%    16.849316
# max    40.193445
#
#
#
#
# Periodic Momentum Stocks To Date 2016-09-30 : ['NVDA', 'NEM', 'AMAT', 'DXC', 'DHR']
#
# Current Investment £ : 105.1304487699831
# Additional Contribution :  0
#
# Period Portfilio Summary :
#           Initial  Return %     Current       PnL
# NVDA    40.193445  1.038529   41.742055  1.548610
# DXC     15.069949  1.042904   15.716506  0.646558
# NEM     16.237511  0.942734   15.307649 -0.929861
# DHR     16.780228  1.002041   16.814479  0.034251
# AMAT    16.849316  0.964511   16.251344 -0.597972
# Total  105.130449  1.006673  105.832034  0.701586
#
# Already Invested In : ['NVDA', 'DXC', 'NEM', 'AMAT', 'DHR']
#
# Period Transaction Summary :
# Empty DataFrame
# Columns: [Transaction, Market Price, Trade Fee, Fee Price, Final Price]
# Index: []
#
# Rebalancing Stocks
#
#
# Portfolio For Next Period :
#        Invested
# NVDA  41.742055
# DXC   15.716506
# NEM   15.307649
# DHR   16.814479
# AMAT  16.251344
# Description
#         Invested
# count   5.000000
# mean   21.166407
# std    11.516085
# min    15.307649
# 25%    15.716506
# 50%    16.251344
# 75%    16.814479
# max    41.742055
#
#
#
#
# Periodic Momentum Stocks To Date 2016-10-31 : ['NVDA', 'DXC', 'NEM', 'AMAT', 'DHR']
#
# Current Investment £ : 105.83203430655513
# Additional Contribution :  0
#
# Period Portfilio Summary :
#           Initial  Return %     Current        PnL
# NVDA    41.742055  1.297611   54.164948  12.422893
# DXC     15.716506  1.113498   17.500304   1.783797
# NEM     15.307649  0.875810   13.406589  -1.901060
# DHR     16.814479  0.995162   16.733136  -0.081344
# AMAT    16.251344  1.110834   18.052540   1.801196
# Total  105.832034  1.132526  119.857517  14.025483
#
# Already Invested In : ['NVDA', 'DXC', 'NEM', 'AMAT', 'DHR']
#
# Period Transaction Summary :
# Empty DataFrame
# Columns: [Transaction, Market Price, Trade Fee, Fee Price, Final Price]
# Index: []
#
# Rebalancing Stocks
#
#
# Portfolio For Next Period :
#        Invested
# NVDA  54.164948
# DXC   17.500304
# NEM   13.406589
# DHR   16.733136
# AMAT  18.052540
# Description
#         Invested
# count   5.000000
# mean   23.971503
# std    16.974732
# min    13.406589
# 25%    16.733136
# 50%    17.500304
# 75%    18.052540
# max    54.164948
#
#
#
#
# Periodic Momentum Stocks To Date 2016-11-30 : ['NVDA', 'OKE', 'DXC', 'FCX', 'NEM']
#
# Current Investment £ : 119.85751703922094
# Additional Contribution :  0
#
# Period Portfilio Summary :
#           Initial  Return %     Current       PnL
# NVDA    54.164948  1.157701   62.706806  8.541857
# DXC     17.500304  0.982345   17.191344 -0.308959
# NEM     13.406589  1.051818   14.101285  0.694696
# DHR     16.733136  0.997360   16.688957 -0.044179
# AMAT    18.052540  1.002174   18.091783  0.039243
# Total  119.857517  1.074444  128.780176  8.922659
#
# Already Invested In : ['NVDA', 'DXC', 'NEM']
#
# Stocks To Remove : ['DHR', 'AMAT']
#
# Investing 34.432932776042726 Equally Into : ['OKE', 'FCX']
#
# Period Transaction Summary :
#      Transaction  Market Price  Trade Fee  Fee Price  Final Price
# DHR         Sell     16.688957       0.01   0.166890    16.522068
# AMAT        Sell     18.091783       0.01   0.180918    17.910865
# OKE          Buy     17.216466       0.01   0.172165    17.044302
# FCX          Buy     17.216466       0.01   0.172165    17.044302
#
# Rebalancing Stocks
#
#
# Portfolio For Next Period :
#        Invested
# NVDA  62.706806
# DXC   17.191344
# NEM   14.101285
# OKE   17.044302
# FCX   17.044302
# Description
#         Invested
# count   5.000000
# mean   25.617608
# std    20.774018
# min    14.101285
# 25%    17.044302
# 50%    17.044302
# 75%    17.191344
# max    62.706806
#
#
#
#
# Periodic Momentum Stocks To Date 2016-12-31 : ['NVDA', 'OKE', 'FCX', 'NEM', 'DXC']
#
# Current Investment £ : 128.08803898325266
# Additional Contribution :  0
#
# Period Portfilio Summary :
#           Initial  Return %     Current       PnL
# NVDA    62.706806  1.022859   64.140252  1.433446
# DXC     17.191344  1.046786   17.995653  0.804308
# NEM     14.101285  1.064866   15.015978  0.914692
# OKE     17.044302  0.970684   16.544626 -0.499676
# FCX     17.044302  1.262320   21.515358  4.471056
# Total  128.088039  1.055617  135.211866  7.123827
#
# Already Invested In : ['OKE', 'NVDA', 'DXC', 'NEM', 'FCX']
#
# Period Transaction Summary :
# Empty DataFrame
# Columns: [Transaction, Market Price, Trade Fee, Fee Price, Final Price]
# Index: []
#
# Rebalancing Stocks
#
#
# Portfolio For Next Period :
#        Invested
# NVDA  64.140252
# DXC   17.995653
# NEM   15.015978
# OKE   16.544626
# FCX   21.515358
# Description
#         Invested
# count   5.000000
# mean   27.042373
# std    20.877503
# min    15.015978
# 25%    16.544626
# 50%    17.995653
# 75%    21.515358
# max    64.140252
#
#
#
#
# Periodic Momentum Stocks To Date 2017-01-31 : ['NVDA', 'FCX', 'URI', 'OKE', 'MU']
#
# Current Investment £ : 135.2118663121372
# Additional Contribution :  0
#
# Period Portfilio Summary :
#           Initial  Return %     Current       PnL
# NVDA    64.140252  0.930647   59.691959 -4.448293
# DXC     17.995653  1.102251   19.835723  1.840071
# NEM     15.015978  0.943771   14.171645 -0.844333
# OKE     16.544626  0.980766   16.226407 -0.318219
# FCX     21.515358  0.804805   17.315667 -4.199691
# Total  135.211866  0.941052  127.241401 -7.970465
#
# Already Invested In : ['OKE', 'NVDA', 'FCX']
#
# Stocks To Remove : ['DXC', 'NEM']
#
# Investing 33.66729476883107 Equally Into : ['URI', 'MU']
#
# Period Transaction Summary :
#     Transaction  Market Price  Trade Fee  Fee Price  Final Price
# DXC        Sell     19.835723       0.01   0.198357    19.637366
# NEM        Sell     14.171645       0.01   0.141716    14.029929
# URI         Buy     16.833647       0.01   0.168336    16.665311
# MU          Buy     16.833647       0.01   0.168336    16.665311
#
# Rebalancing Stocks
#
#
# Portfolio For Next Period :
#        Invested
# NVDA  59.691959
# OKE   16.226407
# FCX   17.315667
# URI   16.665311
# MU    16.665311
# Description
#         Invested
# count   5.000000
# mean   25.312931
# std    19.222392
# min    16.226407
# 25%    16.665311
# 50%    16.665311
# 75%    17.315667
# max    59.691959
#
#
#
#
# Periodic Momentum Stocks To Date 2017-02-28 : ['NVDA', 'URI', 'DXC', 'OKE', 'DVN']
#
# Current Investment £ : 126.56465435820871
# Additional Contribution :  0
#
# Period Portfilio Summary :
#           Initial  Return %     Current       PnL
# NVDA    59.691959  1.073413   64.074125  4.382166
# OKE     16.226407  1.025717   16.643699  0.417292
# FCX     17.315667  0.997015   17.263977 -0.051689
# URI     16.665311  0.976724   16.277414 -0.387897
# MU      16.665311  1.232935   20.547246  3.881936
# Total  126.564654  1.065119  134.806462  8.241807
#
# Already Invested In : ['OKE', 'URI', 'NVDA']
#
# Stocks To Remove : ['FCX', 'MU']
#
# Investing 37.43311156858154 Equally Into : ['DXC', 'DVN']
#
# Period Transaction Summary :
#     Transaction  Market Price  Trade Fee  Fee Price  Final Price
# FCX        Sell     17.263977       0.01   0.172640    17.091338
# MU         Sell     20.547246       0.01   0.205472    20.341774
# DXC         Buy     18.716556       0.01   0.187166    18.529390
# DVN         Buy     18.716556       0.01   0.187166    18.529390
#
# Rebalancing Stocks
#
#
# Portfolio For Next Period :
#        Invested
# NVDA  64.074125
# OKE   16.643699
# URI   16.277414
# DXC   18.529390
# DVN   18.529390
# Description
#         Invested
# count   5.000000
# mean   26.810804
# std    20.856900
# min    16.277414
# 25%    16.643699
# 50%    18.529390
# 75%    18.529390
# max    64.074125
#
#
#
#
# Periodic Momentum Stocks To Date 2017-03-31 : ['NVDA', 'MU', 'DXC', 'URI', 'OKE']
#
# Current Investment £ : 134.054018214859
# Additional Contribution :  0
#
# Period Portfilio Summary :
#           Initial  Return %     Current       PnL
# NVDA    64.074125  0.957496   61.350706 -2.723419
# OKE     16.643699  0.959784   15.974363 -0.669336
# URI     16.277414  0.876929   14.274138 -2.003276
# DXC     18.529390  1.091726   20.229015  1.699625
# DVN     18.529390  0.946549   17.538967 -0.990423
# Total  134.054018  0.965038  129.367188 -4.686830
#
# Already Invested In : ['OKE', 'URI', 'DXC', 'NVDA']
#
# Stocks To Remove : ['DVN']
#
# Investing 17.363577209400905 Equally Into : ['MU']
#
# Period Transaction Summary :
#     Transaction  Market Price  Trade Fee  Fee Price  Final Price
# DVN        Sell     17.538967       0.01   0.175390    17.363577
# MU          Buy     17.363577       0.01   0.173636    17.189941
#
# Rebalancing Stocks
#
#
# Portfolio For Next Period :
#        Invested
# NVDA  61.350706
# OKE   15.974363
# URI   14.274138
# DXC   20.229015
# MU    17.189941
# Description
#         Invested
# count   5.000000
# mean   25.803633
# std    19.990061
# min    14.274138
# 25%    15.974363
# 50%    17.189941
# 75%    20.229015
# max    61.350706
#
#
#
#
# Periodic Momentum Stocks To Date 2017-04-30 : ['NVDA', 'MU', 'DXC', 'WDC', 'STX']
#
# Current Investment £ : 129.01816281623303
# Additional Contribution :  0
#
# Period Portfilio Summary :
#           Initial  Return %     Current        PnL
# NVDA    61.350706  1.385446   84.998110  23.647404
# OKE     15.974363  0.944307   15.084702  -0.889661
# URI     14.274138  0.991519   14.153084  -0.121054
# DXC     20.229015  1.028935   20.814349   0.585334
# MU      17.189941  1.112035   19.115815   1.925873
# Total  129.018163  1.194917  154.166059  25.147896
#
# Already Invested In : ['NVDA', 'DXC', 'MU']
#
# Stocks To Remove : ['OKE', 'URI']
#
# Investing 28.945408115818932 Equally Into : ['WDC', 'STX']
#
# Period Transaction Summary :
#     Transaction  Market Price  Trade Fee  Fee Price  Final Price
# OKE        Sell     15.084702       0.01   0.150847    14.933855
# URI        Sell     14.153084       0.01   0.141531    14.011553
# WDC         Buy     14.472704       0.01   0.144727    14.327977
# STX         Buy     14.472704       0.01   0.144727    14.327977
#
# Rebalancing Stocks
#
#
# Portfolio For Next Period :
#        Invested
# NVDA  84.998110
# DXC   20.814349
# MU    19.115815
# WDC   14.327977
# STX   14.327977
# Description
#         Invested
# count   5.000000
# mean   30.716845
# std    30.480687
# min    14.327977
# 25%    14.327977
# 50%    19.115815
# 75%    20.814349
# max    84.998110
#
#
#
#
# Periodic Momentum Stocks To Date 2017-05-31 : ['NVDA', 'MU', 'CSX', 'STX', 'WDC']
#
# Current Investment £ : 153.58422689146258
# Additional Contribution :  0
#
# Period Portfilio Summary :
#           Initial  Return %     Current       PnL
# NVDA    84.998110  1.001455   85.121743  0.123633
# DXC     20.814349  0.992025   20.648356 -0.165993
# MU      19.115815  0.970426   18.550478 -0.565337
# WDC     14.327977  0.989173   14.172852 -0.155125
# STX     14.327977  0.902908   12.936841 -1.391136
# Total  153.584227  0.985975  151.430269 -2.153958
#
# Already Invested In : ['WDC', 'NVDA', 'MU', 'STX']
#
# Stocks To Remove : ['DXC']
#
# Investing 20.441872232719714 Equally Into : ['CSX']
#
# Period Transaction Summary :
#     Transaction  Market Price  Trade Fee  Fee Price  Final Price
# DXC        Sell     20.648356       0.01   0.206484    20.441872
# CSX         Buy     20.441872       0.01   0.204419    20.237454
#
# Rebalancing Stocks
#
#
# Portfolio For Next Period :
#        Invested
# NVDA  85.121743
# MU    18.550478
# WDC   14.172852
# STX   12.936841
# CSX   20.237454
# Description
#         Invested
# count   5.000000
# mean   30.203873
# std    30.847397
# min    12.936841
# 25%    14.172852
# 50%    18.550478
# 75%    20.237454
# max    85.121743
#
#
#
#
# Periodic Momentum Stocks To Date 2017-06-30 : ['NVDA', 'MU', 'CSX', 'WDC', 'BBY']
#
# Current Investment £ : 151.0193667087678
# Additional Contribution :  0
#
# Period Portfilio Summary :
#           Initial  Return %     Current        PnL
# NVDA    85.121743  1.124170   95.691308  10.569565
# MU      18.550478  0.941728   17.469505  -1.080973
# WDC     14.172852  0.960722   13.616174  -0.556677
# STX     12.936841  0.850580   11.003824  -1.933016
# CSX     20.237454  0.904326   18.301248  -1.936206
# Total  151.019367  1.033523  156.082059   5.062692
#
# Already Invested In : ['WDC', 'NVDA', 'MU', 'CSX']
#
# Stocks To Remove : ['STX']
#
# Investing 10.89378623070521 Equally Into : ['BBY']
#
# Period Transaction Summary :
#     Transaction  Market Price  Trade Fee  Fee Price  Final Price
# STX        Sell     11.003824       0.01   0.110038    10.893786
# BBY         Buy     10.893786       0.01   0.108938    10.784848
#
# Rebalancing Stocks
#
#
# Portfolio For Next Period :
#        Invested
# NVDA  95.691308
# MU    17.469505
# WDC   13.616174
# CSX   18.301248
# BBY   10.784848
# Description
#         Invested
# count   5.000000
# mean   31.172617
# std    36.193917
# min    10.784848
# 25%    13.616174
# 50%    17.469505
# 75%    18.301248
# max    95.691308
#
#
#
#
# Periodic Momentum Stocks To Date 2017-07-31 : ['NVDA', 'MU', 'NFLX', 'BA', 'ADSK']
#
# Current Investment £ : 155.863082660678
# Additional Contribution :  0
#
# Period Portfilio Summary :
#           Initial  Return %     Current       PnL
# NVDA    95.691308  1.043561   99.859756  4.168449
# MU      17.469505  1.136913   19.861307  2.391803
# WDC     13.616174  1.037007   14.120063  0.503889
# CSX     18.301248  1.021558   18.695784  0.394536
# BBY     10.784848  0.930065   10.030608 -0.754240
# Total  155.863083  1.043015  162.567518  6.704436
#
# Already Invested In : ['NVDA', 'MU']
#
# Stocks To Remove : ['WDC', 'BBY', 'CSX']
#
# Investing 42.41799038238207 Equally Into : ['NFLX', 'ADSK', 'BA']
#
# Period Transaction Summary :
#      Transaction  Market Price  Trade Fee  Fee Price  Final Price
# WDC         Sell     14.120063       0.01   0.141201    13.978863
# BBY         Sell     10.030608       0.01   0.100306     9.930302
# CSX         Sell     18.695784       0.01   0.186958    18.508826
# NFLX         Buy     14.139330       0.01   0.141393    13.997937
# ADSK         Buy     14.139330       0.01   0.141393    13.997937
# BA           Buy     14.139330       0.01   0.141393    13.997937
#
# Rebalancing Stocks
#
#
# Portfolio For Next Period :
#        Invested
# NVDA  99.859756
# MU    19.861307
# NFLX  13.997937
# ADSK  13.997937
# BA    13.997937
# Description
#         Invested
# count   5.000000
# mean   32.342975
# std    37.828326
# min    13.997937
# 25%    13.997937
# 50%    13.997937
# 75%    19.861307
# max    99.859756
#
#
#
#
# Periodic Momentum Stocks To Date 2017-08-31 : ['NVDA', 'NRG', 'IPGP', 'WDC', 'MU']
#
# Current Investment £ : 161.7148739731167
# Additional Contribution :  0
#
# Period Portfilio Summary :
#           Initial  Return %     Current        PnL
# NVDA    99.859756  1.055064  105.358432   5.498676
# MU      19.861307  1.230216   24.433697   4.572389
# NFLX    13.997937  1.038006   14.529940   0.532003
# ADSK    13.997937  0.980779   13.728887  -0.269050
# BA      13.997937  1.060711   14.847766   0.849830
# Total  161.714874  1.069158  172.898722  11.183848
#
# Already Invested In : ['NVDA', 'MU']
#
# Stocks To Remove : ['NFLX', 'ADSK', 'BA']
#
# Investing 42.67552771886611 Equally Into : ['WDC', 'NRG', 'IPGP']
#
# Period Transaction Summary :
#      Transaction  Market Price  Trade Fee  Fee Price  Final Price
# NFLX        Sell     14.529940       0.01   0.145299    14.384641
# ADSK        Sell     13.728887       0.01   0.137289    13.591598
# BA          Sell     14.847766       0.01   0.148478    14.699289
# WDC          Buy     14.225176       0.01   0.142252    14.082924
# NRG          Buy     14.225176       0.01   0.142252    14.082924
# IPGP         Buy     14.225176       0.01   0.142252    14.082924
#
# Rebalancing Stocks
#
#
# Portfolio For Next Period :
#         Invested
# NVDA  105.358432
# MU     24.433697
# WDC    14.082924
# NRG    14.082924
# IPGP   14.082924
# Description
#          Invested
# count    5.000000
# mean    34.408180
# std     39.914836
# min     14.082924
# 25%     14.082924
# 50%     14.082924
# 75%     24.433697
# max    105.358432
#
#
#
#
# Periodic Momentum Stocks To Date 2017-09-30 : ['NVDA', 'NRG', 'IPGP', 'MU', 'BA']
#
# Current Investment £ : 172.04090083921074
# Additional Contribution :  0
#
# Period Portfilio Summary :
#           Initial  Return %     Current        PnL
# NVDA   105.358432  1.156850  121.883857  16.525425
# MU      24.433697  1.126621   27.527519   3.093823
# WDC     14.082924  1.033218   14.550725   0.467801
# NRG     14.082924  0.978117   13.774752  -0.308172
# IPGP    14.082924  1.150492   16.202288   2.119364
# Total  172.040901  1.127285  193.939142  21.898241
#
# Already Invested In : ['NRG', 'NVDA', 'MU', 'IPGP']
#
# Stocks To Remove : ['WDC']
#
# Investing 14.405218016484524 Equally Into : ['BA']
#
# Period Transaction Summary :
#     Transaction  Market Price  Trade Fee  Fee Price  Final Price
# WDC        Sell     14.550725       0.01   0.145507    14.405218
# BA          Buy     14.405218       0.01   0.144052    14.261166
#
# Rebalancing Stocks
#
#
# Portfolio For Next Period :
#         Invested
# NVDA  121.883857
# MU     27.527519
# NRG    13.774752
# IPGP   16.202288
# BA     14.261166
# Description
#          Invested
# count    5.000000
# mean    38.729916
# std     46.821591
# min     13.774752
# 25%     14.261166
# 50%     16.202288
# 75%     27.527519
# max    121.883857
#
#
#
#
# Periodic Momentum Stocks To Date 2017-10-31 : ['NVDA', 'MU', 'SEDG', 'NRG', 'IPGP']
#
# Current Investment £ : 193.64958243745497
# Additional Contribution :  0
#
# Period Portfilio Summary :
#           Initial  Return %     Current       PnL
# NVDA   121.883857  0.971179  118.371003 -3.512854
# MU      27.527519  0.956669   26.334718 -1.192802
# NRG     13.774752  1.106000   15.234876  1.460124
# IPGP    16.202288  1.075478   17.425202  1.222914
# BA      14.261166  1.078719   15.383795  1.122629
# Total  193.649582  0.995352  192.749594 -0.899988
#
# Already Invested In : ['NRG', 'NVDA', 'MU', 'IPGP']
#
# Stocks To Remove : ['BA']
#
# Investing 15.229957334028569 Equally Into : ['SEDG']
#
# Period Transaction Summary :
#      Transaction  Market Price  Trade Fee  Fee Price  Final Price
# BA          Sell     15.383795       0.01   0.153838    15.229957
# SEDG         Buy     15.229957       0.01   0.152300    15.077658
#
# Rebalancing Stocks
#
#
# Portfolio For Next Period :
#         Invested
# NVDA  118.371003
# MU     26.334718
# NRG    15.234876
# IPGP   17.425202
# SEDG   15.077658
# Description
#          Invested
# count    5.000000
# mean    38.488691
# std     44.892621
# min     15.077658
# 25%     15.234876
# 50%     17.425202
# 75%     26.334718
# max    118.371003
#
#
#
#
# Periodic Momentum Stocks To Date 2017-11-30 : ['NKTR', 'SEDG', 'NRG', 'IPGP', 'NVDA']
#
# Current Investment £ : 192.44345651559445
# Additional Contribution :  0
#
# Period Portfilio Summary :
#           Initial  Return %     Current       PnL
# NVDA   118.371003  0.964078  114.118828 -4.252175
# MU      26.334718  0.970040   25.545734 -0.788984
# NRG     15.234876  1.030018   15.692198  0.457323
# IPGP    17.425202  0.935147   16.295129 -1.130073
# SEDG    15.077658  1.031593   15.554011  0.476354
# Total  192.443457  0.972784  187.205901 -5.237556
#
# Already Invested In : ['SEDG', 'NRG', 'NVDA', 'IPGP']
#
# Stocks To Remove : ['MU']
#
# Investing 25.290276360683844 Equally Into : ['NKTR']
#
# Period Transaction Summary :
#      Transaction  Market Price  Trade Fee  Fee Price  Final Price
# MU          Sell     25.545734       0.01   0.255457    25.290276
# NKTR         Buy     25.290276       0.01   0.252903    25.037374
#
# Rebalancing Stocks
#
#
# Portfolio For Next Period :
#         Invested
# NVDA  114.118828
# NRG    15.692198
# IPGP   16.295129
# SEDG   15.554011
# NKTR   25.037374
# Description
#          Invested
# count    5.000000
# mean    37.339508
# std     43.105934
# min     15.554011
# 25%     15.692198
# 50%     16.295129
# 75%     25.037374
# max    114.118828
#
#
#
#
# Periodic Momentum Stocks To Date 2017-12-31 : ['NKTR', 'SEDG', 'NRG', 'PENN', 'IPGP']
#
# Current Investment £ : 186.69754076278667
# Additional Contribution :  0
#
# Period Portfilio Summary :
#           Initial  Return %     Current        PnL
# NVDA   114.118828  1.270284  144.963305  30.844477
# NRG     15.692198  0.914324   14.347749  -1.344449
# IPGP    16.295129  1.176622   19.173202   2.878072
# SEDG    15.554011  0.956059   14.870547  -0.683464
# NKTR    25.037374  1.400033   35.053161  10.015787
# Total  186.697541  1.223412  228.407965  41.710424
#
# Already Invested In : ['NKTR', 'NRG', 'IPGP', 'SEDG']
#
# Stocks To Remove : ['NVDA']
#
# Investing 143.5136721818061 Equally Into : ['PENN']
#
# Period Transaction Summary :
#      Transaction  Market Price  Trade Fee  Fee Price  Final Price
# NVDA        Sell    144.963305       0.01   1.449633   143.513672
# PENN         Buy    143.513672       0.01   1.435137   142.078535
#
# Rebalancing Stocks
#
#
# Portfolio For Next Period :
#         Invested
# NRG    14.347749
# IPGP   19.173202
# SEDG   14.870547
# NKTR   35.053161
# PENN  142.078535
# Description
#          Invested
# count    5.000000
# mean    45.104639
# std     54.857759
# min     14.347749
# 25%     14.870547
# 50%     19.173202
# 75%     35.053161
# max    142.078535
#
#
#
#
# Periodic Momentum Stocks To Date 2018-01-31 : ['NKTR', 'SEDG', 'PENN', 'NVDA', 'BA']
#
# Current Investment £ : 225.5231949765809
# Additional Contribution :  0
#
# Period Portfilio Summary :
#           Initial  Return %     Current        PnL
# NRG     14.347749  0.994233   14.265007  -0.082743
# IPGP    19.173202  0.974955   18.693016  -0.480186
# SEDG    14.870547  1.394150   20.731778   5.861231
# NKTR    35.053161  1.035283   36.289936   1.236775
# PENN   142.078535  0.833908  118.480412 -23.598124
# Total  225.523195  0.924340  208.460148 -17.063047
#
# Already Invested In : ['NKTR', 'PENN', 'SEDG']
#
# Stocks To Remove : ['NRG', 'IPGP']
#
# Investing 32.62844256447959 Equally Into : ['NVDA', 'BA']
#
# Period Transaction Summary :
#      Transaction  Market Price  Trade Fee  Fee Price  Final Price
# NRG         Sell     14.265007       0.01   0.142650    14.122357
# IPGP        Sell     18.693016       0.01   0.186930    18.506086
# NVDA         Buy     16.314221       0.01   0.163142    16.151079
# BA           Buy     16.314221       0.01   0.163142    16.151079
#
# Rebalancing Stocks
#
#
# Portfolio For Next Period :
#         Invested
# SEDG   20.731778
# NKTR   36.289936
# PENN  118.480412
# ...
# Period Portfilio Summary :
#           Initial  Return %     Current        PnL
# NVDA   146.130786  1.268871  185.421125  39.290338
# META    92.610720  1.085222  100.503199   7.892479
# LLY     82.186791  1.052027   86.462725   4.275934
# CEG     82.339085  1.170174   96.351032  14.011947
# RCL     65.112729  1.057652   68.866617   3.753888
# Total  468.380112  1.147796  537.604698  69.224586
#
# Already Invested In : ['CEG', 'NVDA', 'RCL']
#
# Stocks To Remove : ['LLY', 'META']
#
# Investing 185.09626488287773 Equally Into : ['AVGO', 'NRG']
#
# Period Transaction Summary :
#      Transaction  Market Price  Trade Fee  Fee Price  Final Price
# LLY         Sell     86.462725       0.01   0.864627    85.598098
# META        Sell    100.503199       0.01   1.005032    99.498167
# AVGO         Buy     92.548132       0.01   0.925481    91.622651
# NRG          Buy     92.548132       0.01   0.925481    91.622651
#
# Rebalancing Stocks
#
#
# Portfolio For Next Period :
#         Invested
# NVDA  185.421125
# CEG    96.351032
# RCL    68.866617
# AVGO   91.622651
# NRG    91.622651
# Description
#          Invested
# count    5.000000
# mean   106.776815
# std     45.249599
# min     68.866617
# 25%     91.622651
# 50%     91.622651
# 75%     96.351032
# max    185.421125
#
#
#
#
# Periodic Momentum Stocks To Date 2024-05-31 : ['NVDA', 'CEG', 'NRG', 'GE', 'TT']
#
# Current Investment £ : 533.8840760589101
# Additional Contribution :  0
#
# Period Portfilio Summary :
#           Initial  Return %     Current        PnL
# NVDA   185.421125  1.126943  208.959046  23.537922
# CEG     96.351032  0.921841   88.820357  -7.530676
# RCL     68.866617  1.079564   74.345921   5.479304
# AVGO    91.622651  1.212320  111.075997  19.453346
# NRG     91.622651  0.961235   88.070864  -3.551787
# Total  533.884076  1.070030  571.272185  37.388109
#
# Already Invested In : ['NRG', 'NVDA', 'CEG']
#
# Stocks To Remove : ['AVGO', 'RCL']
#
# Investing 183.56769885896995 Equally Into : ['GE', 'TT']
#
# Period Transaction Summary :
#      Transaction  Market Price  Trade Fee  Fee Price  Final Price
# AVGO        Sell    111.075997       0.01   1.110760   109.965237
# RCL         Sell     74.345921       0.01   0.743459    73.602461
# GE           Buy     91.783849       0.01   0.917838    90.866011
# TT           Buy     91.783849       0.01   0.917838    90.866011
#
# Rebalancing Stocks
#
#
# Portfolio For Next Period :
#         Invested
# NVDA  208.959046
# CEG    88.820357
# NRG    88.070864
# GE     90.866011
# TT     90.866011
# Description
#          Invested
# count    5.000000
# mean   113.516458
# std     53.368410
# min     88.070864
# 25%     88.820357
# 50%     90.866011
# 75%     90.866011
# max    208.959046
#
#
#
#
# Periodic Momentum Stocks To Date 2024-06-30 : ['NVDA', 'CEG', 'ANET', 'NRG', 'MU']
#
# Current Investment £ : 567.5822891429225
# Additional Contribution :  0
#
# Period Portfilio Summary :
#           Initial  Return %     Current        PnL
# NVDA   208.959046  0.947224  197.930920 -11.028127
# CEG     88.820357  0.947721   84.176880  -4.643477
# NRG     88.070864  0.965451   85.028078  -3.042787
# GE      90.866011  1.072454   97.449648   6.583637
# TT      90.866011  1.016265   92.343939   1.477928
# Total  567.582289  0.981231  556.929464 -10.652825
#
# Already Invested In : ['NRG', 'NVDA', 'CEG']
#
# Stocks To Remove : ['GE', 'TT']
#
# Investing 187.8956509514532 Equally Into : ['MU', 'ANET']
#
# Period Transaction Summary :
#      Transaction  Market Price  Trade Fee  Fee Price  Final Price
# GE          Sell     97.449648       0.01   0.974496    96.475151
# TT          Sell     92.343939       0.01   0.923439    91.420500
# MU           Buy     93.947825       0.01   0.939478    93.008347
# ANET         Buy     93.947825       0.01   0.939478    93.008347
#
# Rebalancing Stocks
#
#
# Portfolio For Next Period :
#         Invested
# NVDA  197.930920
# CEG    84.176880
# NRG    85.028078
# MU     93.008347
# ANET   93.008347
# Description
#          Invested
# count    5.000000
# mean   110.630514
# std     48.983982
# min     84.176880
# 25%     85.028078
# 50%     93.008347
# 75%     93.008347
# max    197.930920
#
#
#
#
# Periodic Momentum Stocks To Date 2024-07-31 : ['NVDA', 'ANET', 'NRG', 'CEG', 'FICO']
#
# Current Investment £ : 553.1525715263464
# Additional Contribution :  0
#
# Period Portfilio Summary :
#           Initial  Return %     Current        PnL
# NVDA   197.930920  1.020082  201.905798   3.974878
# CEG     84.176880  1.038284   87.399541   3.222661
# NRG     85.028078  1.137075   96.683309  11.655231
# MU      93.008347  0.876343   81.507218 -11.501130
# ANET    93.008347  1.019709   94.841412   1.833065
# Total  553.152572  1.016604  562.337277   9.184706
#
# Already Invested In : ['CEG', 'NRG', 'NVDA', 'ANET']
#
# Stocks To Remove : ['MU']
#
# Investing 80.69214536949869 Equally Into : ['FICO']
#
# Period Transaction Summary :
#      Transaction  Market Price  Trade Fee  Fee Price  Final Price
# MU          Sell     81.507218       0.01   0.815072    80.692145
# FICO         Buy     80.692145       0.01   0.806921    79.885224
#
# Rebalancing Stocks
#
#
# Portfolio For Next Period :
#         Invested
# NVDA  201.905798
# CEG    87.399541
# NRG    96.683309
# ANET   94.841412
# FICO   79.885224
# Description
#          Invested
# count    5.000000
# mean   112.143057
# std     50.617462
# min     79.885224
# 25%     87.399541
# 50%     94.841412
# 75%     96.683309
# max    201.905798
#
#
#
#
# Periodic Momentum Stocks To Date 2024-08-31 : ['NVDA', 'NRG', 'HWM', 'GE', 'FICO']
#
# Current Investment £ : 560.7152837618781
# Additional Contribution :  0
#
# Period Portfilio Summary :
#           Initial  Return %     Current        PnL
# NVDA   201.905798  1.017428  205.424619   3.518822
# CEG     87.399541  1.321911  115.534451  28.134909
# NRG     96.683309  1.071639  103.609570   6.926262
# ANET    94.841412  1.086140  103.011011   8.169599
# FICO    79.885224  1.123247   89.730811   9.845587
# Total  560.715284  1.100934  617.310462  56.595178
#
# Already Invested In : ['FICO', 'NRG', 'NVDA']
#
# Stocks To Remove : ['CEG', 'ANET']
#
# Investing 216.36000674289266 Equally Into : ['HWM', 'GE']
#
# Period Transaction Summary :
#      Transaction  Market Price  Trade Fee  Fee Price  Final Price
# CEG         Sell    115.534451       0.01   1.155345   114.379106
# ANET        Sell    103.011011       0.01   1.030110   101.980901
# HWM          Buy    108.180003       0.01   1.081800   107.098203
# GE           Buy    108.180003       0.01   1.081800   107.098203
#
# Rebalancing Stocks
#
#
# Portfolio For Next Period :
#         Invested
# NVDA  205.424619
# NRG   103.609570
# FICO   89.730811
# HWM   107.098203
# GE    107.098203
# Description
#          Invested
# count    5.000000
# mean   122.592281
# std     46.854959
# min     89.730811
# 25%    103.609570
# 50%    107.098203
# 75%    107.098203
# max    205.424619
#
#
#
#
# Periodic Momentum Stocks To Date 2024-09-30 : ['NVDA', 'NRG', 'CEG', 'FICO', 'HWM']
#
# Current Investment £ : 612.9614073827186
# Additional Contribution :  0
#
# Period Portfilio Summary :
#           Initial  Return %     Current        PnL
# NVDA   205.424619  1.093215  224.573234  19.148614
# NRG    103.609570  0.992316  102.813457  -0.796113
# FICO    89.730811  1.025516   92.020341   2.289530
# HWM    107.098203  0.994713  106.532001  -0.566202
# GE     107.098203  0.910913   97.557158  -9.541046
# Total  612.961407  1.017187  623.496191  10.534784
#
# Already Invested In : ['FICO', 'NRG', 'NVDA', 'HWM']
#
# Stocks To Remove : ['GE']
#
# Investing 96.58158610658704 Equally Into : ['CEG']
#
# Period Transaction Summary :
#     Transaction  Market Price  Trade Fee  Fee Price  Final Price
# GE         Sell     97.557158       0.01   0.975572    96.581586
# CEG         Buy     96.581586       0.01   0.965816    95.615770
#
# Rebalancing Stocks
#
#
# Portfolio For Next Period :
#         Invested
# NVDA  224.573234
# NRG   102.813457
# FICO   92.020341
# HWM   106.532001
# CEG    95.615770
# Description
#          Invested
# count    5.000000
# mean   124.310961
# std     56.340162
# min     92.020341
# 25%     95.615770
# 50%    102.813457
# 75%    106.532001
# max    224.573234
#
#
#
#
# Periodic Momentum Stocks To Date 2024-10-31 : ['NVDA', 'RCL', 'FICO', 'CEG', 'HWM']
#
# Current Investment £ : 621.5548038399139
# Additional Contribution :  0
#
# Period Portfilio Summary :
#           Initial  Return %     Current        PnL
# NVDA   224.573234  1.041353  233.859975   9.286742
# NRG    102.813457  1.129100  116.086704  13.273246
# FICO    92.020341  1.191620  109.653293  17.632952
# HWM    106.532001  1.187978  126.557707  20.025705
# CEG     95.615770  0.977192   93.434985  -2.180786
# Total  621.554804  1.093375  679.592664  58.037860
#
# Already Invested In : ['FICO', 'NVDA', 'HWM', 'CEG']
#
# Stocks To Remove : ['NRG']
#
# Investing 114.92583670734321 Equally Into : ['RCL']
#
# Period Transaction Summary :
#     Transaction  Market Price  Trade Fee  Fee Price  Final Price
# NRG        Sell    116.086704       0.01   1.160867   114.925837
# RCL         Buy    114.925837       0.01   1.149258   113.776578
#
# Rebalancing Stocks
#
#
# Portfolio For Next Period :
#         Invested
# NVDA  233.859975
# FICO  109.653293
# HWM   126.557707
# CEG    93.434985
# RCL   113.776578
# Description
#          Invested
# count    5.000000
# mean   135.456508
# std     56.267363
# min     93.434985
# 25%    109.653293
# 50%    113.776578
# 75%    126.557707
# max    233.859975
#
#
#
#
# Periodic Momentum Stocks To Date 2024-11-30 : ['NVDA', 'AXON', 'UAL', 'TRGP', 'RCL']
#
# Current Investment £ : 677.2825382464414
# Additional Contribution :  0
#
# Period Portfilio Summary :
#           Initial  Return %     Current        PnL
# NVDA   233.859975  0.971423  227.176986  -6.682990
# FICO   109.653293  0.838276   91.919695 -17.733598
# HWM    126.557707  0.923889  116.925304  -9.632403
# CEG     93.434985  0.871960   81.471551 -11.963433
# RCL    113.776578  0.947410  107.793069  -5.983509
# Total  677.282538  0.923229  625.286606 -51.995933
#
# Already Invested In : ['NVDA', 'RCL']
#
# Stocks To Remove : ['FICO', 'HWM', 'CEG']
#
# Investing 287.4133854577574 Equally Into : ['UAL', 'AXON', 'TRGP']
#
# Period Transaction Summary :
#      Transaction  Market Price  Trade Fee  Fee Price  Final Price
# FICO        Sell     91.919695       0.01   0.919197    91.000498
# HWM         Sell    116.925304       0.01   1.169253   115.756051
# CEG         Sell     81.471551       0.01   0.814716    80.656836
# UAL          Buy     95.804462       0.01   0.958045    94.846417
# AXON         Buy     95.804462       0.01   0.958045    94.846417
# TRGP         Buy     95.804462       0.01   0.958045    94.846417
#
# Rebalancing Stocks
#
#
# Portfolio For Next Period :
#         Invested
# NVDA  227.176986
# RCL   107.793069
# UAL    94.846417
# AXON   94.846417
# TRGP   94.846417
# Description
#          Invested
# count    5.000000
# mean   123.901861
# std     58.004097
# min     94.846417
# 25%     94.846417
# 50%     94.846417
# 75%    107.793069
# max    227.176986
#
#
#
#
# Periodic Momentum Stocks To Date 2024-12-31 : ['NVDA', 'UAL', 'AXON', 'AVGO', 'TRGP']
#
# Current Investment £ : 619.5093063192966
# Additional Contribution :  0
#
# Period Portfilio Summary :
#           Initial  Return %     Current        PnL
# NVDA   227.176986  0.894110  203.121166 -24.055820
# RCL    107.793069  1.155663  124.572511  16.779442
# UAL     94.846417  1.090010  103.383570   8.537152
# AXON    94.846417  1.097355  104.080184   9.233767
# TRGP    94.846417  1.106565  104.953750  10.107332
# Total  619.509306  1.033255  640.111180  20.601874
#
# Already Invested In : ['UAL', 'NVDA', 'AXON', 'TRGP']
#
# Stocks To Remove : ['RCL']
#
# Investing 123.32678567626732 Equally Into : ['AVGO']
#
# Period Transaction Summary :
#      Transaction  Market Price  Trade Fee  Fee Price  Final Price
# RCL         Sell    124.572511       0.01   1.245725   123.326786
# AVGO         Buy    123.326786       0.01   1.233268   122.093518
#
# Rebalancing Stocks
#
#
# Portfolio For Next Period :
#         Invested
# NVDA  203.121166
# UAL   103.383570
# AXON  104.080184
# TRGP  104.953750
# AVGO  122.093518
# Description
#          Invested
# count    5.000000
# mean   127.526437
# std     42.971533
# min    103.383570
# 25%    104.080184
# 50%    104.953750
# 75%    122.093518
# max    203.121166
#
#
#
#
# Periodic Momentum Stocks To Date 2025-01-31 : ['AXON', 'UAL', 'CEG', 'TRGP', 'HWM']
#
# Current Investment £ : 637.6321871921273
# Additional Contribution :  0
#
# Period Portfilio Summary :
#           Initial  Return %     Current        PnL
# NVDA   203.121166  1.040393  211.325851   8.204685
# UAL    103.383570  0.886338   91.632773 -11.750796
# AXON   104.080184  0.810282   84.334348 -19.745836
# TRGP   104.953750  1.025000  107.577592   2.623843
# AVGO   122.093518  0.901297  110.042523 -12.050995
# Total  637.632187  0.948687  604.913087 -32.719100
#
# Already Invested In : ['UAL', 'AXON', 'TRGP']
#
# Stocks To Remove : ['AVGO', 'NVDA']
#
# Investing 318.15468971793393 Equally Into : ['HWM', 'CEG']
#
# Period Transaction Summary :
#      Transaction  Market Price  Trade Fee  Fee Price  Final Price
# AVGO        Sell    110.042523       0.01   1.100425   108.942097
# NVDA        Sell    211.325851       0.01   2.113259   209.212592
# HWM          Buy    159.077345       0.01   1.590773   157.486571
# CEG          Buy    159.077345       0.01   1.590773   157.486571
#
# Rebalancing Stocks
#
#
# Portfolio For Next Period :
#         Invested
# UAL    91.632773
# AXON   84.334348
# TRGP  107.577592
# HWM   157.486571
# CEG   157.486571
# Description
#          Invested
# count    5.000000
# mean   119.703571
# std     35.500356
# min     84.334348
# 25%     91.632773
# 50%    107.577592
# 75%    157.486571
# max    157.486571
#
#
#
#
# Periodic Momentum Stocks To Date 2025-02-28 : ['TRGP', 'UAL', 'MMM', 'HWM', 'RCL']
#
# Current Investment £ : 598.5178567402357
# Additional Contribution :  0
#
# Period Portfilio Summary :
#           Initial  Return %     Current        PnL
# UAL     91.632773  0.736062   67.447430 -24.185343
# AXON    84.334348  0.995269   83.935378  -0.398970
# TRGP   107.577592  0.993803  106.910965  -0.666627
# HWM    157.486571  0.949707  149.566115  -7.920456
# CEG    157.486571  0.806272  126.976997 -30.509575
# Total  598.517857  0.893602  534.836886 -63.680971
#
# Already Invested In : ['UAL', 'HWM', 'TRGP']
#
# Stocks To Remove : ['CEG', 'AXON']
#
# Investing 208.80325078972254 Equally Into : ['MMM', 'RCL']
#
# Period Transaction Summary :
#      Transaction  Market Price  Trade Fee  Fee Price  Final Price
# CEG         Sell    126.976997       0.01   1.269770   125.707227
# AXON        Sell     83.935378       0.01   0.839354    83.096024
# MMM          Buy    104.401625       0.01   1.044016   103.357609
# RCL          Buy    104.401625       0.01   1.044016   103.357609
#
# Rebalancing Stocks
#
#
# Portfolio For Next Period :
#         Invested
# UAL    67.447430
# TRGP  106.910965
# HWM   149.566115
# MMM   103.357609
# RCL   103.357609
# Description
#          Invested
# count    5.000000
# mean   106.127946
# std     29.150555
# min     67.447430
# 25%    103.357609
# 50%    103.357609
# 75%    106.910965
# max    149.566115
#
#
#
#
# Periodic Momentum Stocks To Date 2025-03-31 : ['GEV', 'HWM', 'TRGP', 'PM', 'T']
#
# Current Investment £ : 530.6397293332333
# Additional Contribution :  0
#
# Period Portfilio Summary :
#           Initial  Return %     Current        PnL
# UAL     67.447430  0.960174   64.761255  -2.686176
# TRGP   106.910965  0.870804   93.098458 -13.812507
# HWM    149.566115  0.949896  142.072254  -7.493861
# MMM    103.357609  0.886627   91.639622 -11.717987
# RCL    103.357609  0.937938   96.943038  -6.414571
# Total  530.639729  0.920614  488.514627 -42.125102
#
# Already Invested In : ['HWM', 'TRGP']
#
# Stocks To Remove : ['UAL', 'MMM', 'RCL']
#
# Investing 250.81047595374648 Equally Into : ['PM', 'GEV', 'T']
#
# Period Transaction Summary :
#     Transaction  Market Price  Trade Fee  Fee Price  Final Price
# UAL        Sell     64.761255       0.01   0.647613    64.113642
# MMM        Sell     91.639622       0.01   0.916396    90.723226
# RCL        Sell     96.943038       0.01   0.969430    95.973608
# PM          Buy     83.603492       0.01   0.836035    82.767457
# GEV         Buy     83.603492       0.01   0.836035    82.767457
# T           Buy     83.603492       0.01   0.836035    82.767457
#
# Rebalancing Stocks
#
#
# Portfolio For Next Period :
#         Invested
# TRGP   93.098458
# HWM   142.072254
# PM     82.767457
# GEV    82.767457
# T      82.767457
# Description
#          Invested
# count    5.000000
# mean    96.694617
# std     25.758298
# min     82.767457
# 25%     82.767457
# 50%     82.767457
# 75%     93.098458
# max    142.072254

# %%
df_invested_stocks
# Out:
#        Invested
# EW    22.502657
# LUV   19.440723
# EA    21.229234
# HBI   19.723270
# MNST  19.723270

# %%
df_invested_stocks.mean()
# Out:
# Invested    20.523831
# dtype: float64

# %%
(df_invested_stocks - df_invested_stocks.mean()) * (1 - trade_fee)
# Out:
#       Invested
# EW    1.959038
# LUV  -1.072276
# EA    0.698349
# HBI  -0.792556
# MNST -0.792556

# %%
df_invested_stocks - (((df_invested_stocks - df_invested_stocks.mean())) * (1 - trade_fee))
# Out:
#        Invested
# EW    20.543619
# LUV   20.513000
# EA    20.530885
# HBI   20.515825
# MNST  20.515825

# %%
df_stocks.loc['prev', ]
# Out:
# Empty DataFrame
# Columns: []
# Index: [prev, curr]

# %%
rolling['COV']
# Out:
# Date
# 2014-12-31    1.888889
# 2015-01-31    1.789474
# 2015-02-28         NaN
# 2015-03-31         NaN
# 2015-04-30         NaN
#                 ...
# 2024-12-31         NaN
# 2025-01-31         NaN
# 2025-02-28         NaN
# 2025-03-31         NaN
# 2025-04-30         NaN
# Freq: ME, Name: COV, Length: 125, dtype: float64

# %%
mth_ret['COV']
# Out:
# Date
# 2014-01-31    1.055556
# 2014-02-28    1.052632
# 2014-03-31    0.900000
# 2014-04-30    1.000000
# 2014-05-31    1.833333
#                 ...
# 2024-12-31         NaN
# 2025-01-31         NaN
# 2025-02-28         NaN
# 2025-03-31         NaN
# 2025-04-30         NaN
# Freq: ME, Name: COV, Length: 136, dtype: float64

# %%
removed[removed.Ticker == 'COV']
# Out:
#            Ticker  Security
# Date
# 2015-01-27    COV  Covidien

# %%
(df_test.notna().sum(axis=1) == 5).value_counts()
# Out:
# True     123
# False      1
# Name: count, dtype: int64

# %%
df_test
# Out:
#                  LUV       AAL        EA        EW  COV        KR      MNST  \
# 2015-01-31  1.067580  0.915159  1.166738  0.984063  1.0       NaN       NaN
# 2015-02-28  0.957061       NaN  1.042289  1.061189  NaN  1.033079       NaN
# 2015-03-31  1.025906       NaN  1.028681  1.070967  NaN       NaN  0.980726
# 2015-04-30  0.915576       NaN  0.987589  0.889021  NaN  0.898905  0.990679
# 2015-05-31       NaN       NaN  1.080392       NaN  NaN       NaN  0.928306
# ...              ...       ...       ...       ...  ...       ...       ...
# 2024-12-31       NaN       NaN       NaN       NaN  NaN       NaN       NaN
# 2025-01-31       NaN       NaN       NaN       NaN  NaN       NaN       NaN
# 2025-02-28       NaN       NaN       NaN       NaN  NaN       NaN       NaN
# 2025-03-31       NaN       NaN       NaN       NaN  NaN       NaN       NaN
# 2025-04-30       NaN       NaN       NaN       NaN  NaN       NaN       NaN
#
#                  HBI      VRTX       COR  ...  TT  FICO       HWM      AXON  \
# 2015-01-31       NaN       NaN       NaN  ... NaN   NaN       NaN       NaN
# 2015-02-28       NaN       NaN       NaN  ... NaN   NaN       NaN       NaN
# 2015-03-31  1.050964       NaN       NaN  ... NaN   NaN       NaN       NaN
# 2015-04-30       NaN       NaN       NaN  ... NaN   NaN       NaN       NaN
# 2015-05-31       NaN  1.040639  0.987282  ... NaN   NaN       NaN       NaN
# ...              ...       ...       ...  ...  ..   ...       ...       ...
# 2024-12-31       NaN       NaN       NaN  ... NaN   NaN       NaN  0.918635
# 2025-01-31       NaN       NaN       NaN  ... NaN   NaN       NaN  1.097355
# 2025-02-28       NaN       NaN       NaN  ... NaN   NaN  1.079997  0.810282
# 2025-03-31       NaN       NaN       NaN  ... NaN   NaN  0.949707       NaN
# 2025-04-30       NaN       NaN       NaN  ... NaN   NaN  0.949896       NaN
#
#                  UAL      TRGP       MMM       GEV        PM         T
# 2015-01-31       NaN       NaN       NaN       NaN       NaN       NaN
# 2015-02-28       NaN       NaN       NaN       NaN       NaN       NaN
# 2015-03-31       NaN       NaN       NaN       NaN       NaN       NaN
# 2015-04-30       NaN       NaN       NaN       NaN       NaN       NaN
# 2015-05-31       NaN       NaN       NaN       NaN       NaN       NaN
# ...              ...       ...       ...       ...       ...       ...
# 2024-12-31  1.002788  0.873715       NaN       NaN       NaN       NaN
# 2025-01-31  1.090010  1.106565       NaN       NaN       NaN       NaN
# 2025-02-28  0.886338  1.025000       NaN       NaN       NaN       NaN
# 2025-03-31  0.736062  0.993803  0.946751       NaN       NaN       NaN
# 2025-04-30       NaN  0.870804       NaN  1.060655  1.028224  0.970232
#
# [124 rows x 123 columns]

# %%
df_inv = pd.DataFrame()
df_inv.loc[0, ['total inv', 'inv1', 'ivn2', 'inv3', 'inv4' ,'inv5', 'fees paid']] = 0
df_inv
# Out:
#   total inv inv1 ivn2 inv3 inv4 inv5 fees paid
# 0         0    0    0    0    0    0         0

# %%
df_inv = pd.DataFrame()
df_inv.loc[0, ['total inv', 'inv1', 'ivn2', 'inv3', 'inv4' ,'inv5', 'fees paid']] = 0




for idx, row in df_test.iloc[:3].iterrows():

    print('\n')
    print(idx) 
    print(row[row.notna()])
# Out:
# 2015-01-31 00:00:00
# LUV    1.067580
# AAL    0.915159
# EA     1.166738
# EW     0.984063
# COV    1.000000
# Name: 2015-01-31 00:00:00, dtype: float64
#
#
# 2015-02-28 00:00:00
# LUV    0.957061
# EA     1.042289
# EW     1.061189
# KR     1.033079
# Name: 2015-02-28 00:00:00, dtype: float64
#
#
# 2015-03-31 00:00:00
# LUV     1.025906
# EA      1.028681
# EW      1.070967
# MNST    0.980726
# HBI     1.050964
# Name: 2015-03-31 00:00:00, dtype: float64

# %%
df_test.mean(axis=1).cumprod().plot()

# %%
sp500 = yf.download(tickers=['^GSPC'], start=start, end=end)['Close']
sp500

# %%
sp500_ret = sp500.pct_change().dropna() + 1
sp500_ret

# %%
sp500_ret = sp500_ret.resample('M').prod()
sp500_ret

# %%
sp500_ret.reindex(df_test.index).cumprod().plot()

# %%
initial_inv = 100

for date in rolling.index[:-1]:
    
    # print(sp500_ret.loc[date])
    initial_inv *= sp500_ret.loc[date]

initial_inv

# %%
sp500_ret.mean()

# %%
100*1.24**10
