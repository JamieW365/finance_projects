# %% [markdown]
# # Momentum Trading

# %% [markdown]
# ### The Strategy
# - ##### Check the past 12 month performance of all index stocks
# - ##### Buy the top performers and hold them for 1 month
#
# ### Accounting for Survivorship Bias
# - #### Ensure that stocks are added / removed in line with historical data

# %% [markdown]
# ## Imports

# %%
import yfinance as yf
import numpy as np
import pandas as pd
from datetime import datetime

# %% [markdown]
# ## Load Data

# %%
start = "2015-01-01"
end = datetime.today().strftime('%Y-%m-%d')
start, end
# Out:
# ('2015-01-01', '2025-04-06')

# %%
# Get up to date S&P500 stock information from it's wikipedia page
wiki = pd.read_html("https://en.wikipedia.org/wiki/List_of_S%26P_500_companies")

# %%
# Retrieve the current S&P500 stock list
current = wiki[0].copy()
current.sort_values('Date added', ascending=False).head()
# Out:
#     Symbol               Security             GICS Sector  \
# 151   DASH               DoorDash  Consumer Discretionary
# 446    TKO     TKO Group Holdings  Communication Services
# 492    WSM  Williams-Sonoma, Inc.  Consumer Discretionary
# 182    EXE          Expand Energy                  Energy
# 495   WDAY          Workday, Inc.  Information Technology
#
#                       GICS Sub-Industry      Headquarters Location  \
# 151       Specialized Consumer Services  San Francisco, California
# 446              Movies & Entertainment    New York City, New York
# 492               Homefurnishing Retail  San Francisco, California
# 182  Oil & Gas Exploration & Production    Oklahoma City, Oklahoma
# 495                Application Software     Pleasanton, California
#
#      Date added      CIK Founded
# 151  2025-03-24  1792789    2012
# 446  2025-03-24  1973266    2023
# 492  2025-03-24   719955    1956
# 182  2025-03-24   895126    1989
# 495  2024-12-23  1327811    2005

# %%
current.set_index(pd.to_datetime(current['Date added']), inplace=True)
current.sort_index(inplace=True)
current
# Out:
#            Symbol               Security             GICS Sector  \
# Date added
# 1957-03-04    MMM                     3M             Industrials
# 1957-03-04    BMY   Bristol Myers Squibb             Health Care
# 1957-03-04    HSY  Hershey Company (The)        Consumer Staples
# 1957-03-04    HIG         Hartford (The)              Financials
# 1957-03-04    HAL            Halliburton                  Energy
# ...           ...                    ...                     ...
# 2024-12-23   WDAY          Workday, Inc.  Information Technology
# 2025-03-24    TKO     TKO Group Holdings  Communication Services
# 2025-03-24   DASH               DoorDash  Consumer Discretionary
# 2025-03-24    WSM  Williams-Sonoma, Inc.  Consumer Discretionary
# 2025-03-24    EXE          Expand Energy                  Energy
#
#                              GICS Sub-Industry      Headquarters Location  \
# Date added
# 1957-03-04            Industrial Conglomerates      Saint Paul, Minnesota
# 1957-03-04                     Pharmaceuticals    New York City, New York
# 1957-03-04              Packaged Foods & Meats      Hershey, Pennsylvania
# 1957-03-04       Property & Casualty Insurance      Hartford, Connecticut
# 1957-03-04      Oil & Gas Equipment & Services             Houston, Texas
# ...                                        ...                        ...
# 2024-12-23                Application Software     Pleasanton, California
# 2025-03-24              Movies & Entertainment    New York City, New York
# 2025-03-24       Specialized Consumer Services  San Francisco, California
# 2025-03-24               Homefurnishing Retail  San Francisco, California
# 2025-03-24  Oil & Gas Exploration & Production    Oklahoma City, Oklahoma
#
#             Date added      CIK      Founded
# Date added
# 1957-03-04  1957-03-04    66740         1902
# 1957-03-04  1957-03-04    14272  1989 (1887)
# 1957-03-04  1957-03-04    47111         1894
# 1957-03-04  1957-03-04   874766         1810
# 1957-03-04  1957-03-04    45012         1919
# ...                ...      ...          ...
# 2024-12-23  2024-12-23  1327811         2005
# 2025-03-24  2025-03-24  1973266         2023
# 2025-03-24  2025-03-24  1792789         2012
# 2025-03-24  2025-03-24   719955         1956
# 2025-03-24  2025-03-24   895126         1989
#
# [503 rows x 8 columns]

# %%
# Add current stocks to the list of complete stocks we need to load from yfinance
stocks = current.Symbol.to_list()
stocks
# Out:
# ['MMM',
#  'BMY',
#  'HSY',
#  'HIG',
#  'HAL',
#  'GIS',
#  'GD',
#  'GE',
#  'F',
#  'XOM',
#  'ADM',
#  'EXC',
#  'ETR',
#  'IBM',
#  'EIX',
#  'DTE',
#  'DE',
#  'CVS',
#  'CSX',
#  'ED',
#  'COP',
#  'CL',
#  'KO',
#  'CMS',
#  'CVX',
#  'CAT',
#  'CPB',
#  'ETN',
#  'IP',
#  'HON',
#  'PFE',
#  'XEL',
#  'ABT',
#  'UNP',
#  'SO',
#  'SLB',
#  'SPGI',
#  'RTX',
#  'PEG',
#  'PG',
#  'PPG',
#  'PEP',
#  'OXY',
#  'NOC',
#  'BA',
#  'MSI',
#  'KMB',
#  'MRK',
#  'MO',
#  'LMT',
#  'NSC',
#  'AEP',
#  'KR',
#  'SHW',
#  'EMR',
#  'CMI',
#  'CLX',
#  'NEM',
#  'MCD',
#  'LLY',
#  'BAX',
#  'BDX',
#  'JNJ',
#  'GPC',
#  'HPQ',
#  'WMB',
#  'JPM',
#  'IFF',
#  'NEE',
#  'DIS',
#  'CI',
#  'TAP',
#  'BAC',
#  'DUK',
#  'WFC',
#  'AXP',
#  'INTC',
#  'TGT',
#  'TXT',
#  'WY',
#  'WBA',
#  'AIG',
#  'PCAR',
#  'FDX',
#  'ADP',
#  'MAS',
#  'GWW',
#  'WMT',
#  'SNA',
#  'SWK',
#  'BF.B',
#  'AAPL',
#  'CAG',
#  'VZ',
#  'T',
#  'LOW',
#  'PHM',
#  'HES',
#  'HAS',
#  'BALL',
#  'APD',
#  'NUE',
#  'RVTY',
#  'CNP',
#  'TJX',
#  'DOV',
#  'PH',
#  'ITW',
#  'MDT',
#  'SYY',
#  'MMC',
#  'AVY',
#  'HD',
#  'PNC',
#  'C',
#  'NKE',
#  'ECL',
#  'GL',
#  'ORCL',
#  'K',
#  'ADSK',
#  'AEE',
#  'AMGN',
#  'LIN',
#  'IPG',
#  'MS',
#  'COST',
#  'CSCO',
#  'EMN',
#  'KEY',
#  'MSFT',
#  'UNH',
#  'LUV',
#  'MU',
#  'PARA',
#  'BSX',
#  'GLW',
#  'AMAT',
#  'BK',
#  'L',
#  'DRI',
#  'ALL',
#  'FITB',
#  'AON',
#  'AZO',
#  'ADBE',
#  'CAH',
#  'SCHW',
#  'EFX',
#  'APA',
#  'PGR',
#  'HBAN',
#  'KLAC',
#  'YUM',
#  'FE',
#  'TFC',
#  'CINF',
#  'OMC',
#  'NTRS',
#  'BEN',
#  'MAR',
#  'MCO',
#  'COF',
#  'RF',
#  'WM',
#  'PAYX',
#  'AES',
#  'DHR',
#  'CCL',
#  'MCK',
#  'AFL',
#  'NTAP',
#  'BBY',
#  'VMC',
#  'QCOM',
#  'PNW',
#  'ADI',
#  'USB',
#  'ROK',
#  'A',
#  'SBUX',
#  'DVN',
#  'EOG',
#  'NI',
#  'INTU',
#  'MET',
#  'SYK',
#  'CTAS',
#  'TXN',
#  'FI',
#  'ZBH',
#  'COR',
#  'PPL',
#  'NVDA',
#  'EQR',
#  'WAT',
#  'SPG',
#  'UPS',
#  'PRU',
#  'PFG',
#  'GS',
#  'EBAY',
#  'EA',
#  'ELV',
#  'TRV',
#  'CMCSA',
#  'DGX',
#  'VLO',
#  'STT',
#  'MKC',
#  'GEN',
#  'PLD',
#  'BIIB',
#  'MTB',
#  'VTRS',
#  'GILD',
#  'TMO',
#  'TPR',
#  'LH',
#  'DHI',
#  'STZ',
#  'TSN',
#  'PSA',
#  'AMP',
#  'LEN',
#  'AMZN',
#  'EL',
#  'VRSN',
#  'BXP',
#  'GOOG',
#  'KIM',
#  'JNPR',
#  'CME',
#  'FIS',
#  'CBRE',
#  'CTSH',
#  'AVB',
#  'RL',
#  'CHRW',
#  'HST',
#  'AIZ',
#  'DFS',
#  'AKAM',
#  'MCHP',
#  'ICE',
#  'EXPE',
#  'EXPD',
#  'J',
#  'AMT',
#  'DOC',
#  'PM',
#  'ISRG',
#  'CTRA',
#  'MA',
#  'DVA',
#  'IVZ',
#  'CF',
#  'FAST',
#  'CRM',
#  'LHX',
#  'APH',
#  'NDAQ',
#  'WEC',
#  'SJM',
#  'WYNN',
#  'RSG',
#  'IRM',
#  'WELL',
#  'VTR',
#  'HRL',
#  'ORLY',
#  'WDC',
#  'PWR',
#  'ES',
#  'BKNG',
#  'ROST',
#  'V',
#  'ROP',
#  'NRG',
#  'BRK.B',
#  'OKE',
#  'KMX',
#  'CB',
#  'JCI',
#  'TT',
#  'FFIV',
#  'NFLX',
#  'EW',
#  'BLK',
#  'CMG',
#  'MPC',
#  'FCX',
#  'ACN',
#  'MOS',
#  'TEL',
#  'XYL',
#  'DLTR',
#  'CCI',
#  'PSX',
#  'KMI',
#  'MNST',
#  'LRCX',
#  'STX',
#  'LYB',
#  'PNR',
#  'MDLZ',
#  'DG',
#  'HUM',
#  'GRMN',
#  'APTV',
#  'ABBV',
#  'REGN',
#  'GM',
#  'ZTS',
#  'NWSA',
#  'DAL',
#  'AME',
#  'VRTX',
#  'ALLE',
#  'META',
#  'MHK',
#  'TSCO',
#  'ESS',
#  'GOOGL',
#  'AVGO',
#  'MLM',
#  'URI',
#  'UHS',
#  'RCL',
#  'HCA',
#  'SWKS',
#  'HSIC',
#  'EQIX',
#  'O',
#  'JBHT',
#  'KHC',
#  'PYPL',
#  'UAL',
#  'NWS',
#  'VRSK',
#  'HPE',
#  'SYF',
#  'CHD',
#  'WTW',
#  'EXR',
#  'CFG',
#  'FRT',
#  'AWK',
#  'UDR',
#  'HOLX',
#  'CNC',
#  'ULTA',
#  'GPN',
#  'DLR',
#  'LKQ',
#  'AJG',
#  'TDG',
#  'FTV',
#  'ALB',
#  'LNT',
#  'MTD',
#  'CHTR',
#  'COO',
#  'HWM',
#  'D',
#  'MAA',
#  'IDXX',
#  'INCY',
#  'CBOE',
#  'REG',
#  'SNPS',
#  'SRE',
#  'RJF',
#  'ARE',
#  'AMD',
#  'IT',
#  'HLT',
#  'EG',
#  'ALGN',
#  'ANSS',
#  'BKR',
#  'AOS',
#  'RMD',
#  'MGM',
#  'PKG',
#  'IQV',
#  'SBAC',
#  'CDNS',
#  'NCLH',
#  'HII',
#  'TTWO',
#  'MSCI',
#  'EVRG',
#  'BR',
#  'CPAY',
#  'CPRT',
#  'ANET',
#  'ROL',
#  'FTNT',
#  'KEYS',
#  'JKHY',
#  'FANG',
#  'LW',
#  'ATO',
#  'WAB',
#  'FOXA',
#  'FOX',
#  'DOW',
#  'CTVA',
#  'DD',
#  'AMCR',
#  'MKTX',
#  'TMUS',
#  'TROW',
#  'LDOS',
#  'IEX',
#  'CDW',
#  'NVR',
#  'LVS',
#  'NOW',
#  'WRB',
#  'ODFL',
#  'ZBRA',
#  'STE',
#  'LYV',
#  'PAYC',
#  'IR',
#  'OTIS',
#  'CARR',
#  'DPZ',
#  'DXCM',
#  'WST',
#  'TDY',
#  'TYL',
#  'TER',
#  'POOL',
#  'TSLA',
#  'ENPH',
#  'TRMB',
#  'MPWR',
#  'GNRC',
#  'CZR',
#  'NXPI',
#  'PTC',
#  'CRL',
#  'MRNA',
#  'TECH',
#  'BRO',
#  'MTCH',
#  'DAY',
#  'EPAM',
#  'FDS',
#  'CEG',
#  'NDSN',
#  'MOH',
#  'CPT',
#  'WBD',
#  'VICI',
#  'KDP',
#  'ON',
#  'CSGP',
#  'INVH',
#  'PCG',
#  'EQT',
#  'TRGP',
#  'ACGL',
#  'FSLR',
#  'STLD',
#  'GEHC',
#  'BG',
#  'PODD',
#  'FICO',
#  'AXON',
#  'PANW',
#  'KVUE',
#  'BX',
#  'ABNB',
#  'VLTO',
#  'HUBB',
#  'LULU',
#  'JBL',
#  'UBER',
#  'BLDR',
#  'SMCI',
#  'DECK',
#  'SOLV',
#  'GEV',
#  'VST',
#  'KKR',
#  'CRWD',
#  'GDDY',
#  'SW',
#  'ERIE',
#  'DELL',
#  'PLTR',
#  'TPL',
#  'LII',
#  'APO',
#  'WDAY',
#  'TKO',
#  'DASH',
#  'WSM',
#  'EXE']

# %%
# Stocks that were added after our start point will need to be filtered to account for survivorship bias
added = current[current.index >= start].copy()
added
# Out:
#            Symbol               Security             GICS Sector  \
# Date added
# 2015-01-27    HCA         HCA Healthcare             Health Care
# 2015-03-12   SWKS     Skyworks Solutions  Information Technology
# 2015-03-17   HSIC           Henry Schein             Health Care
# 2015-03-20   EQIX                Equinix             Real Estate
# 2015-04-07      O          Realty Income             Real Estate
# ...           ...                    ...                     ...
# 2024-12-23   WDAY          Workday, Inc.  Information Technology
# 2025-03-24    TKO     TKO Group Holdings  Communication Services
# 2025-03-24   DASH               DoorDash  Consumer Discretionary
# 2025-03-24    WSM  Williams-Sonoma, Inc.  Consumer Discretionary
# 2025-03-24    EXE          Expand Energy                  Energy
#
#                              GICS Sub-Industry      Headquarters Location  \
# Date added
# 2015-01-27              Health Care Facilities       Nashville, Tennessee
# 2015-03-12                      Semiconductors         Irvine, California
# 2015-03-17            Health Care Distributors         Melville, New York
# 2015-03-20                   Data Center REITs   Redwood City, California
# 2015-04-07                        Retail REITs      San Diego, California
# ...                                        ...                        ...
# 2024-12-23                Application Software     Pleasanton, California
# 2025-03-24              Movies & Entertainment    New York City, New York
# 2025-03-24       Specialized Consumer Services  San Francisco, California
# 2025-03-24               Homefurnishing Retail  San Francisco, California
# 2025-03-24  Oil & Gas Exploration & Production    Oklahoma City, Oklahoma
#
#             Date added      CIK Founded
# Date added
# 2015-01-27  2015-01-27   860730    1968
# 2015-03-12  2015-03-12     4127    2002
# 2015-03-17  2015-03-17  1000228    1932
# 2015-03-20  2015-03-20  1101239    1998
# 2015-04-07  2015-04-07   726728    1969
# ...                ...      ...     ...
# 2024-12-23  2024-12-23  1327811    2005
# 2025-03-24  2025-03-24  1973266    2023
# 2025-03-24  2025-03-24  1792789    2012
# 2025-03-24  2025-03-24   719955    1956
# 2025-03-24  2025-03-24   895126    1989
#
# [174 rows x 8 columns]

# %%
# Retrieve a list of stocks that are not currently in the S&P500 stock list
removed = wiki[1][['Date', 'Removed']].copy()
removed.head()
# Out:
#                 Date Removed
#                 Date  Ticker         Security
# 0     March 24, 2025     BWA       BorgWarner
# 1     March 24, 2025     TFX         Teleflex
# 2     March 24, 2025      CE         Celanese
# 3     March 24, 2025     FMC  FMC Corporation
# 4  December 23, 2024    QRVO            Qorvo

# %%
# Stocks that were removed after our start point will need to be included until their removal date in order to account for survivorship bias
removed.set_index(pd.to_datetime(removed.Date.Date), inplace=True)
removed.sort_index(inplace=True)
removed
# Out:
#                          Date Removed
#                          Date  Ticker         Security
# Date
# 1997-06-17      June 17, 1997     USL           USLife
# 1998-12-11  December 11, 1998      AN            Amoco
# 1998-12-11  December 11, 1998     SUN       SunAmerica
# 1998-12-11  December 11, 1998     GRN       General Re
# 1999-04-12     April 12, 1999     NaN              NaN
# ...                       ...     ...              ...
# 2024-12-23  December 23, 2024    QRVO            Qorvo
# 2025-03-24     March 24, 2025     FMC  FMC Corporation
# 2025-03-24     March 24, 2025      CE         Celanese
# 2025-03-24     March 24, 2025     TFX         Teleflex
# 2025-03-24     March 24, 2025     BWA       BorgWarner
#
# [368 rows x 3 columns]

# %%
removed = removed[removed.index >= start].Removed
removed
# Out:
#            Ticker         Security
# Date
# 2015-01-27    COV         Covidien
# 2015-01-27    SWY          Safeway
# 2015-03-12   PETM         PetSmart
# 2015-03-18    CFN       Carefusion
# 2015-03-23    AGN         Allergan
# ...           ...              ...
# 2024-12-23   QRVO            Qorvo
# 2025-03-24    FMC  FMC Corporation
# 2025-03-24     CE         Celanese
# 2025-03-24    TFX         Teleflex
# 2025-03-24    BWA       BorgWarner
#
# [235 rows x 2 columns]

# %%
# I will drop values we don't have ticker information for
removed[removed.Ticker.isna()]
# Out:
#            Ticker Security
# Date
# 2024-09-30    NaN      NaN
# 2024-04-02    NaN      NaN
# 2024-04-01    NaN      NaN
# 2023-10-02    NaN      NaN
# 2023-01-04    NaN      NaN
# 2022-12-15    NaN      NaN
# 2022-02-02    NaN      NaN
# 2021-06-03    NaN      NaN
# 2020-10-09    NaN      NaN
# 2020-04-03    NaN      NaN
# 2020-04-03    NaN      NaN
# 2016-04-08    NaN      NaN
# 2015-09-18    NaN      NaN
# 2015-09-18    NaN      NaN
# 2015-09-18    NaN      NaN

# %%
removed.dropna(inplace=True)
removed
# Out:
#            Ticker         Security
# Date
# 2015-01-27    COV         Covidien
# 2015-01-27    SWY          Safeway
# 2015-03-12   PETM         PetSmart
# 2015-03-18    CFN       Carefusion
# 2015-03-23    AGN         Allergan
# ...           ...              ...
# 2024-12-23   QRVO            Qorvo
# 2025-03-24    FMC  FMC Corporation
# 2025-03-24     CE         Celanese
# 2025-03-24    TFX         Teleflex
# 2025-03-24    BWA       BorgWarner
#
# [220 rows x 2 columns]

# %%
removed.isna().any().any()
# Out:
# np.False_

# %%
# We will also need to retrieve the removed stocks from yfinance
stocks.extend(removed.Ticker.to_list())
len(stocks)
# Out:
# 723

# %%
len(set(stocks))
# Out:
# 715

# %% [markdown]
# ## Download Stock Data From Yahoo Finance

# %%
# Load all relevent stocks from yfinance
df = yf.download(stocks, start=start, end=end)['Close']
# Out:
# YF.download() has changed argument auto_adjust default to True
# [*********************100%***********************]  715 of 715 completed
#
# 101 Failed downloads:
# ['CERN', 'FBHS', 'KSU', 'VAR', 'WIN', 'FRC', 'NBL', 'DISCK', 'HFC', 'APC', 'PXD', 'DTV', 'NLSN', 'CELG', 'BBBY', 'MON', 'ABMD', 'ALXN', 'CXO', 'ENDP', 'TSS', 'XL', 'ATVI', 'YHOO', 'XEC', 'QEP', 'CTXS', 'ADS', 'FTR', 'DISH', 'DWDP', 'MXIM', 'ARNC', 'ETFC', 'DO', 'RTN', 'BRK.B', 'SIVB', 'AGN', 'TWTR', 'DISCA', 'VIAB', 'GPS', 'DRE', 'RHT', 'ESV', 'WCG', 'MNK', 'AVP', 'CHK', 'LM', 'SWN', 'DNR', 'XLNX', 'FLIR', 'PBCT', 'TIF', 'LLL']: YFTzMissingError('possibly delisted; no timezone found')
# ['MJN', 'HSP', 'SIAL', 'BF.B', 'WYN', 'TWC', 'GMCR', 'LO', 'BCR', 'LVLT', 'LEN', 'BRCM', 'LLTC', 'RAI', 'SPLS', 'TYC', 'KRFT', 'CMCSK', 'GGP', 'HCBK', 'STJ', 'SWY', 'POM', 'SNI', 'CFN', 'DPS', 'WFM', 'BXLT', 'FDO', 'JOY', 'ARG', 'CVC', 'CAM', 'CPGX']: YFPricesMissingError('possibly delisted; no price data found  (1d 2015-01-01 -> 2025-04-06)')
# ['AET', 'TWX', 'BMS', 'CSRA', 'SCG', 'HOT', 'ANDV']: ValueError('Length mismatch: Expected axis has 2 elements, new values have 1 elements')
# ['CTLT', 'MRO']: YFPricesMissingError('possibly delisted; no price data found  (1d 2015-01-01 -> 2025-04-06) (Yahoo error = "No data found, symbol may be delisted")')

# %%
df
# Out:
# Ticker               A         AA        AAL         AAP        AAPL  \
# Date
# 2015-01-02   37.273823  35.912807  51.079914  141.844131   24.320438
# 2015-01-05   36.575386  33.832211  51.051487  139.974518   23.635283
# 2015-01-06   36.005630  34.080982  50.255596  139.876099   23.637514
# 2015-01-07   36.483501  34.962975  50.227161  142.881866   23.968960
# 2015-01-08   37.577080  35.958031  50.843040  144.134262   24.889906
# ...                ...        ...        ...         ...         ...
# 2025-03-31  116.732002  30.500000  10.550000   39.209999  222.130005
# 2025-04-01  114.050003  30.139999  10.300000   39.020000  223.190002
# 2025-04-02  115.989998  30.840000  10.590000   39.320000  223.889999
# 2025-04-03  109.669998  27.330000   9.510000   36.619999  203.190002
# 2025-04-04  103.000000  24.809999   9.460000   35.009998  188.380005
#
# Ticker            ABBV  ABMD        ABNB         ABT  ACE  ...         XOM  \
# Date                                                       ...
# 2015-01-02   43.156208   NaN         NaN   36.915031  NaN  ...   59.510231
# 2015-01-05   42.344051   NaN         NaN   36.923233  NaN  ...   57.881908
# 2015-01-06   42.134453   NaN         NaN   36.503952  NaN  ...   57.574200
# 2015-01-07   43.837383   NaN         NaN   36.799927  NaN  ...   58.157578
# 2015-01-08   44.295864   NaN         NaN   37.556309  NaN  ...   59.125603
# ...                ...   ...         ...         ...  ...  ...         ...
# 2025-03-31  209.520004   NaN  119.459999  132.649994  NaN  ...  118.930000
# 2025-04-01  206.270004   NaN  121.180000  131.690002  NaN  ...  119.040001
# 2025-04-02  205.190002   NaN  122.800003  131.929993  NaN  ...  118.669998
# 2025-04-03  201.639999   NaN  113.970001  131.630005  NaN  ...  112.430000
# 2025-04-04  186.960007   NaN  106.660004  124.440002  NaN  ...  104.339996
#
# Ticker           XRAY        XRX         XYL  YHOO         YUM         ZBH  \
# Date
# 2015-01-02  46.345871  19.412529   33.441803   NaN   42.833298  100.714760
# 2015-01-05  46.024578  18.988977   31.360487   NaN   41.963024  104.471764
# 2015-01-06  45.453403  18.734856   31.176060   NaN   41.447956  103.586182
# 2015-01-07  46.631454  18.974867   31.421959   NaN   42.821465  106.162430
# 2015-01-08  47.782749  19.497240   31.659069   NaN   43.567413  107.289520
# ...               ...        ...         ...   ...         ...         ...
# 2025-03-31  14.940000   4.830000  119.459999   NaN  157.360001  113.180000
# 2025-04-01  14.650000   4.920000  119.879997   NaN  158.919998  112.370003
# 2025-04-02  14.870000   4.910000  119.050003   NaN  158.229996  112.500000
# 2025-04-03  13.620000   4.180000  110.989998   NaN  161.449997  112.660004
# 2025-04-04  13.580000   4.000000  104.599998   NaN  147.830002  107.339996
#
# Ticker            ZBRA       ZION         ZTS
# Date
# 2015-01-02   77.430000  21.878542   40.157536
# 2015-01-05   76.339996  21.058773   39.916458
# 2015-01-06   75.790001  20.254478   39.527031
# 2015-01-07   77.720001  20.447815   40.342964
# 2015-01-08   79.379997  20.733965   40.964191
# ...                ...        ...         ...
# 2025-03-31  282.559998  49.860001  164.649994
# 2025-04-01  283.070007  49.480000  161.910004
# 2025-04-02  287.570007  50.439999  163.500000
# 2025-04-03  238.500000  43.810001  159.610001
# 2025-04-04  223.490005  41.389999  151.729996
#
# [2580 rows x 715 columns]

# %%
df.columns[df.isna().all()]
# Out:
# Index(['ABMD', 'ADS', 'AET', 'AGN', 'ALXN', 'ANDV', 'APC', 'ARG', 'ARNC',
#        'ATVI',
#        ...
#        'VAR', 'VIAB', 'WCG', 'WFM', 'WIN', 'WYN', 'XEC', 'XL', 'XLNX', 'YHOO'],
#       dtype='object', name='Ticker', length=101)

# %%
df['ACE'][df['ACE'].notna()]
# Out:
# Date
# 2018-08-28     1.46
# 2018-08-29     1.46
# 2018-08-30     1.46
# 2018-08-31     1.43
# 2018-09-04     1.43
#               ...
# 2019-06-03     1.31
# 2019-06-04     1.33
# 2019-06-06     1.38
# 2019-06-07     1.31
# 2020-01-24    33.00
# Name: ACE, Length: 195, dtype: float64

# %%
# Save the overall dataset for easy access
df.to_csv('data/sp500_historic.csv')

# %%
# Load from csv if YFinance is down
df = pd.read_csv('data/sp500_historic.csv', index_col=0, date_format = pd.to_datetime)
df.index = pd.to_datetime(df.index)
df
# Out:
#                      A         AA        AAL         AAP        AAPL  \
# Date
# 2015-01-02   37.273823  35.912807  51.079914  141.844131   24.320438
# 2015-01-05   36.575386  33.832211  51.051487  139.974518   23.635283
# 2015-01-06   36.005630  34.080982  50.255596  139.876099   23.637514
# 2015-01-07   36.483501  34.962975  50.227161  142.881866   23.968960
# 2015-01-08   37.577080  35.958031  50.843040  144.134262   24.889906
# ...                ...        ...        ...         ...         ...
# 2025-03-31  116.732002  30.500000  10.550000   39.209999  222.130005
# 2025-04-01  114.050003  30.139999  10.300000   39.020000  223.190002
# 2025-04-02  115.989998  30.840000  10.590000   39.320000  223.889999
# 2025-04-03  109.669998  27.330000   9.510000   36.619999  203.190002
# 2025-04-04  103.000000  24.809999   9.460000   35.009998  188.380005
#
#                   ABBV  ABMD        ABNB         ABT  ACE  ...         XOM  \
# Date                                                       ...
# 2015-01-02   43.156208   NaN         NaN   36.915031  NaN  ...   59.510231
# 2015-01-05   42.344051   NaN         NaN   36.923233  NaN  ...   57.881908
# 2015-01-06   42.134453   NaN         NaN   36.503952  NaN  ...   57.574200
# 2015-01-07   43.837383   NaN         NaN   36.799927  NaN  ...   58.157578
# 2015-01-08   44.295864   NaN         NaN   37.556309  NaN  ...   59.125603
# ...                ...   ...         ...         ...  ...  ...         ...
# 2025-03-31  209.520004   NaN  119.459999  132.649994  NaN  ...  118.930000
# 2025-04-01  206.270004   NaN  121.180000  131.690002  NaN  ...  119.040001
# 2025-04-02  205.190002   NaN  122.800003  131.929993  NaN  ...  118.669998
# 2025-04-03  201.639999   NaN  113.970001  131.630005  NaN  ...  112.430000
# 2025-04-04  186.960007   NaN  106.660004  124.440002  NaN  ...  104.339996
#
#                  XRAY        XRX         XYL  YHOO         YUM         ZBH  \
# Date
# 2015-01-02  46.345871  19.412529   33.441803   NaN   42.833298  100.714760
# 2015-01-05  46.024578  18.988977   31.360487   NaN   41.963024  104.471764
# 2015-01-06  45.453403  18.734856   31.176060   NaN   41.447956  103.586182
# 2015-01-07  46.631454  18.974867   31.421959   NaN   42.821465  106.162430
# 2015-01-08  47.782749  19.497240   31.659069   NaN   43.567413  107.289520
# ...               ...        ...         ...   ...         ...         ...
# 2025-03-31  14.940000   4.830000  119.459999   NaN  157.360001  113.180000
# 2025-04-01  14.650000   4.920000  119.879997   NaN  158.919998  112.370003
# 2025-04-02  14.870000   4.910000  119.050003   NaN  158.229996  112.500000
# 2025-04-03  13.620000   4.180000  110.989998   NaN  161.449997  112.660004
# 2025-04-04  13.580000   4.000000  104.599998   NaN  147.830002  107.339996
#
#                   ZBRA       ZION         ZTS
# Date
# 2015-01-02   77.430000  21.878542   40.157536
# 2015-01-05   76.339996  21.058773   39.916458
# 2015-01-06   75.790001  20.254478   39.527031
# 2015-01-07   77.720001  20.447815   40.342964
# 2015-01-08   79.379997  20.733965   40.964191
# ...                ...        ...         ...
# 2025-03-31  282.559998  49.860001  164.649994
# 2025-04-01  283.070007  49.480000  161.910004
# 2025-04-02  287.570007  50.439999  163.500000
# 2025-04-03  238.500000  43.810001  159.610001
# 2025-04-04  223.490005  41.389999  151.729996
#
# [2580 rows x 715 columns]

# %%
df.isna().all().any()
# Out:
# np.True_

# %%
# Dropping any stocks where we have completely null data
df.drop(df.columns[df.isna().all()], axis=1, inplace=True)
df.shape
# Out:
# (2580, 614)

# %% [markdown]
# ## Accounting for Survivorship Bias

# %% [markdown]
# ### Test nulling data for a single removed stock

# %%
removed
# Out:
#            Ticker         Security
# Date
# 2015-01-27    COV         Covidien
# 2015-01-27    SWY          Safeway
# 2015-03-12   PETM         PetSmart
# 2015-03-18    CFN       Carefusion
# 2015-03-23    AGN         Allergan
# ...           ...              ...
# 2024-12-23   QRVO            Qorvo
# 2025-03-24    FMC  FMC Corporation
# 2025-03-24     CE         Celanese
# 2025-03-24    TFX         Teleflex
# 2025-03-24    BWA       BorgWarner
#
# [220 rows x 2 columns]

# %%
removed[removed.Ticker == 'QRVO']
# Out:
#            Ticker Security
# Date
# 2024-12-23   QRVO    Qorvo

# %%
removed[removed.Ticker == 'QRVO'].index[0]
# Out:
# Timestamp('2024-12-23 00:00:00')

# %%
df['QRVO']
# Out:
# Date
# 2015-01-02    70.400002
# 2015-01-05    67.629997
# 2015-01-06    64.669998
# 2015-01-07    66.650002
# 2015-01-08    67.690002
#                 ...
# 2025-03-31    72.410004
# 2025-04-01    72.230003
# 2025-04-02    72.639999
# 2025-04-03    61.090000
# 2025-04-04    56.349998
# Name: QRVO, Length: 2580, dtype: float64

# %%
pd.date_range(start, removed[removed.Ticker == 'QRVO'].index[0], freq='B')
# Out:
# DatetimeIndex(['2015-01-01', '2015-01-02', '2015-01-05', '2015-01-06',
#                '2015-01-07', '2015-01-08', '2015-01-09', '2015-01-12',
#                '2015-01-13', '2015-01-14',
#                ...
#                '2024-12-10', '2024-12-11', '2024-12-12', '2024-12-13',
#                '2024-12-16', '2024-12-17', '2024-12-18', '2024-12-19',
#                '2024-12-20', '2024-12-23'],
#               dtype='datetime64[ns]', length=2603, freq='B')

# %%
df['QRVO'] = df['QRVO'].reindex(pd.date_range(start, removed[removed.Ticker == 'QRVO'].index[0], freq='B'))
df['QRVO']
# Out:
# Date
# 2015-01-02    70.400002
# 2015-01-05    67.629997
# 2015-01-06    64.669998
# 2015-01-07    66.650002
# 2015-01-08    67.690002
#                 ...
# 2025-03-31          NaN
# 2025-04-01          NaN
# 2025-04-02          NaN
# 2025-04-03          NaN
# 2025-04-04          NaN
# Name: QRVO, Length: 2580, dtype: float64

# %%
# Everything before the removal date is populated
df['QRVO'].loc[:removed[removed.Ticker == 'QRVO'].index[0]]
# Out:
# Date
# 2015-01-02    70.400002
# 2015-01-05    67.629997
# 2015-01-06    64.669998
# 2015-01-07    66.650002
# 2015-01-08    67.690002
#                 ...
# 2024-12-17    70.949997
# 2024-12-18    68.500000
# 2024-12-19    68.800003
# 2024-12-20    70.849998
# 2024-12-23    71.540001
# Name: QRVO, Length: 2511, dtype: float64

# %%
# Everything after the removal date has been nulled
df['QRVO'].loc[removed[removed.Ticker == 'QRVO'].index[0]:]
# Out:
# Date
# 2024-12-23    71.540001
# 2024-12-24          NaN
# 2024-12-26          NaN
# 2024-12-27          NaN
# 2024-12-30          NaN
#                 ...
# 2025-03-31          NaN
# 2025-04-01          NaN
# 2025-04-02          NaN
# 2025-04-03          NaN
# 2025-04-04          NaN
# Name: QRVO, Length: 70, dtype: float64

# %% [markdown]
# ### Test nulling data for a single added stock

# %%
added
# Out:
#            Symbol               Security             GICS Sector  \
# Date added
# 2015-01-27    HCA         HCA Healthcare             Health Care
# 2015-03-12   SWKS     Skyworks Solutions  Information Technology
# 2015-03-17   HSIC           Henry Schein             Health Care
# 2015-03-20   EQIX                Equinix             Real Estate
# 2015-04-07      O          Realty Income             Real Estate
# ...           ...                    ...                     ...
# 2024-12-23   WDAY          Workday, Inc.  Information Technology
# 2025-03-24    TKO     TKO Group Holdings  Communication Services
# 2025-03-24   DASH               DoorDash  Consumer Discretionary
# 2025-03-24    WSM  Williams-Sonoma, Inc.  Consumer Discretionary
# 2025-03-24    EXE          Expand Energy                  Energy
#
#                              GICS Sub-Industry      Headquarters Location  \
# Date added
# 2015-01-27              Health Care Facilities       Nashville, Tennessee
# 2015-03-12                      Semiconductors         Irvine, California
# 2015-03-17            Health Care Distributors         Melville, New York
# 2015-03-20                   Data Center REITs   Redwood City, California
# 2015-04-07                        Retail REITs      San Diego, California
# ...                                        ...                        ...
# 2024-12-23                Application Software     Pleasanton, California
# 2025-03-24              Movies & Entertainment    New York City, New York
# 2025-03-24       Specialized Consumer Services  San Francisco, California
# 2025-03-24               Homefurnishing Retail  San Francisco, California
# 2025-03-24  Oil & Gas Exploration & Production    Oklahoma City, Oklahoma
#
#             Date added      CIK Founded
# Date added
# 2015-01-27  2015-01-27   860730    1968
# 2015-03-12  2015-03-12     4127    2002
# 2015-03-17  2015-03-17  1000228    1932
# 2015-03-20  2015-03-20  1101239    1998
# 2015-04-07  2015-04-07   726728    1969
# ...                ...      ...     ...
# 2024-12-23  2024-12-23  1327811    2005
# 2025-03-24  2025-03-24  1973266    2023
# 2025-03-24  2025-03-24  1792789    2012
# 2025-03-24  2025-03-24   719955    1956
# 2025-03-24  2025-03-24   895126    1989
#
# [174 rows x 8 columns]

# %%
added[added.Symbol=='AOS'].index[0]
# Out:
# Timestamp('2017-07-26 00:00:00')

# %%
pd.date_range(added[added.Symbol=='AOS'].index[0], end, freq='B')
# Out:
# DatetimeIndex(['2017-07-26', '2017-07-27', '2017-07-28', '2017-07-31',
#                '2017-08-01', '2017-08-02', '2017-08-03', '2017-08-04',
#                '2017-08-07', '2017-08-08',
#                ...
#                '2025-03-24', '2025-03-25', '2025-03-26', '2025-03-27',
#                '2025-03-28', '2025-03-31', '2025-04-01', '2025-04-02',
#                '2025-04-03', '2025-04-04'],
#               dtype='datetime64[ns]', length=2008, freq='B')

# %%
df['AOS'] = df['AOS'].reindex(pd.date_range(added[added.Symbol=='AOS'].index[0], end, freq='B'))
df['AOS']
# Out:
# Date
# 2015-01-02          NaN
# 2015-01-05          NaN
# 2015-01-06          NaN
# 2015-01-07          NaN
# 2015-01-08          NaN
#                 ...
# 2025-03-31    65.360001
# 2025-04-01    65.599998
# 2025-04-02    66.120003
# 2025-04-03    63.660000
# 2025-04-04    61.990002
# Name: AOS, Length: 2580, dtype: float64

# %%
# Everything before the added date is null
df['AOS'].loc[:added[added.Symbol=='AOS'].index[0]]
# Out:
# Date
# 2015-01-02          NaN
# 2015-01-05          NaN
# 2015-01-06          NaN
# 2015-01-07          NaN
# 2015-01-08          NaN
#                 ...
# 2017-07-20          NaN
# 2017-07-21          NaN
# 2017-07-24          NaN
# 2017-07-25          NaN
# 2017-07-26    47.457062
# Name: AOS, Length: 646, dtype: float64

# %%
# Everything before the added date is populated
df['AOS'].loc[added[added.Symbol=='AOS'].index[0]:]
# Out:
# Date
# 2017-07-26    47.457062
# 2017-07-27    47.334145
# 2017-07-28    47.667805
# 2017-07-31    47.018066
# 2017-08-01    47.184887
#                 ...
# 2025-03-31    65.360001
# 2025-04-01    65.599998
# 2025-04-02    66.120003
# 2025-04-03    63.660000
# 2025-04-04    61.990002
# Name: AOS, Length: 1935, dtype: float64

# %% [markdown]
# ## Creating functions to account for

# %%
def pricefilter_removed(ticker):
    if ticker in df.columns:
        df[ticker] = df[ticker].reindex(pd.date_range(start, removed[removed.Ticker==ticker].index[0], freq='B'))

def pricefilter_added(ticker):
    if ticker in df.columns:
        df[ticker] = df[ticker].reindex(pd.date_range(added[added.Symbol==ticker].index[0], end, freq='B'))

# %%
for ticker in removed.Ticker:
    pricefilter_removed(ticker)

# %%
for ticker in added.Symbol:
    pricefilter_added(ticker)

# %%
df
# Out:
#                      A         AA        AAL         AAP        AAPL  \
# Date
# 2015-01-02   37.273823  35.912807  51.079914  141.844131   24.320438
# 2015-01-05   36.575386  33.832211  51.051487  139.974518   23.635283
# 2015-01-06   36.005630  34.080982  50.255596  139.876099   23.637514
# 2015-01-07   36.483501  34.962975  50.227161  142.881866   23.968960
# 2015-01-08   37.577080  35.958031  50.843040  144.134262   24.889906
# ...                ...        ...        ...         ...         ...
# 2025-03-31  116.732002        NaN        NaN         NaN  222.130005
# 2025-04-01  114.050003        NaN        NaN         NaN  223.190002
# 2025-04-02  115.989998        NaN        NaN         NaN  223.889999
# 2025-04-03  109.669998        NaN        NaN         NaN  203.190002
# 2025-04-04  103.000000        NaN        NaN         NaN  188.380005
#
#                   ABBV        ABNB         ABT  ACE       ACGL  ...  \
# Date                                                            ...
# 2015-01-02   43.156208         NaN   36.915031  NaN        NaN  ...
# 2015-01-05   42.344051         NaN   36.923233  NaN        NaN  ...
# 2015-01-06   42.134453         NaN   36.503952  NaN        NaN  ...
# 2015-01-07   43.837383         NaN   36.799927  NaN        NaN  ...
# 2015-01-08   44.295864         NaN   37.556309  NaN        NaN  ...
# ...                ...         ...         ...  ...        ...  ...
# 2025-03-31  209.520004  119.459999  132.649994  NaN  96.180000  ...
# 2025-04-01  206.270004  121.180000  131.690002  NaN  96.139999  ...
# 2025-04-02  205.190002  122.800003  131.929993  NaN  96.820000  ...
# 2025-04-03  201.639999  113.970001  131.630005  NaN  96.279999  ...
# 2025-04-04  186.960007  106.660004  124.440002  NaN  87.830002  ...
#
#                   XEL         XOM       XRAY        XRX         XYL  \
# Date
# 2015-01-02  26.153721   59.510231  46.345871  19.412529   33.441803
# 2015-01-05  25.856850   57.881908  46.024578  18.988977   31.360487
# 2015-01-06  25.994421   57.574200  45.453403  18.734856   31.176060
# 2015-01-07  26.218882   58.157578  46.631454  18.974867   31.421959
# 2015-01-08  26.523003   59.125603  47.782749  19.497240   31.659069
# ...               ...         ...        ...        ...         ...
# 2025-03-31  70.790001  118.930000        NaN        NaN  119.459999
# 2025-04-01  70.720001  119.040001        NaN        NaN  119.879997
# 2025-04-02  70.900002  118.669998        NaN        NaN  119.050003
# 2025-04-03  72.139999  112.430000        NaN        NaN  110.989998
# 2025-04-04  67.889999  104.339996        NaN        NaN  104.599998
#
#                    YUM         ZBH        ZBRA       ZION         ZTS
# Date
# 2015-01-02   42.833298  100.714760         NaN  21.878542   40.157536
# 2015-01-05   41.963024  104.471764         NaN  21.058773   39.916458
# 2015-01-06   41.447956  103.586182         NaN  20.254478   39.527031
# 2015-01-07   42.821465  106.162430         NaN  20.447815   40.342964
# 2015-01-08   43.567413  107.289520         NaN  20.733965   40.964191
# ...                ...         ...         ...        ...         ...
# 2025-03-31  157.360001  113.180000  282.559998        NaN  164.649994
# 2025-04-01  158.919998  112.370003  283.070007        NaN  161.910004
# 2025-04-02  158.229996  112.500000  287.570007        NaN  163.500000
# 2025-04-03  161.449997  112.660004  238.500000        NaN  159.610001
# 2025-04-04  147.830002  107.339996  223.490005        NaN  151.729996
#
# [2580 rows x 614 columns]

# %% [markdown]
# ## Calculate Returns

# %%
ret = df.pct_change()
ret
# Out:
# /tmp/ipykernel_34795/948626315.py:1: FutureWarning: The default fill_method='pad' in DataFrame.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   ret = df.pct_change()
#                    A        AA       AAL       AAP      AAPL      ABBV  \
# Date
# 2015-01-02       NaN       NaN       NaN       NaN       NaN       NaN
# 2015-01-05 -0.018738 -0.057935 -0.000557 -0.013181 -0.028172 -0.018819
# 2015-01-06 -0.015578  0.007353 -0.015590 -0.000703  0.000094 -0.004950
# 2015-01-07  0.013272  0.025879 -0.000566  0.021489  0.014022  0.040417
# 2015-01-08  0.029975  0.028460  0.012262  0.008765  0.038422  0.010459
# ...              ...       ...       ...       ...       ...       ...
# 2025-03-31  0.002485  0.000000  0.000000  0.000000  0.019413  0.020605
# 2025-04-01 -0.022976  0.000000  0.000000  0.000000  0.004772 -0.015512
# 2025-04-02  0.017010  0.000000  0.000000  0.000000  0.003136 -0.005236
# 2025-04-03 -0.054487  0.000000  0.000000  0.000000 -0.092456 -0.017301
# 2025-04-04 -0.060819  0.000000  0.000000  0.000000 -0.072887 -0.072803
#
#                 ABNB       ABT  ACE      ACGL  ...       XEL       XOM  \
# Date                                           ...
# 2015-01-02       NaN       NaN  NaN       NaN  ...       NaN       NaN
# 2015-01-05       NaN  0.000222  NaN       NaN  ... -0.011351 -0.027362
# 2015-01-06       NaN -0.011355  NaN       NaN  ...  0.005320 -0.005316
# 2015-01-07       NaN  0.008108  NaN       NaN  ...  0.008635  0.010133
# 2015-01-08       NaN  0.020554  NaN       NaN  ...  0.011599  0.016645
# ...              ...       ...  ...       ...  ...       ...       ...
# 2025-03-31 -0.010191  0.013989  NaN  0.011782  ...  0.015347  0.010193
# 2025-04-01  0.014398 -0.007237  NaN -0.000416  ... -0.000989  0.000925
# 2025-04-02  0.013369  0.001822  NaN  0.007073  ...  0.002545 -0.003108
# 2025-04-03 -0.071906 -0.002274  NaN -0.005577  ...  0.017489 -0.052583
# 2025-04-04 -0.064140 -0.054623  NaN -0.087765  ... -0.058913 -0.071956
#
#                 XRAY       XRX       XYL       YUM       ZBH      ZBRA  \
# Date
# 2015-01-02       NaN       NaN       NaN       NaN       NaN       NaN
# 2015-01-05 -0.006933 -0.021818 -0.062237 -0.020318  0.037303       NaN
# 2015-01-06 -0.012410 -0.013383 -0.005881 -0.012274 -0.008477       NaN
# 2015-01-07  0.025918  0.012811  0.007887  0.033138  0.024871       NaN
# 2015-01-08  0.024689  0.027530  0.007546  0.017420  0.010617       NaN
# ...              ...       ...       ...       ...       ...       ...
# 2025-03-31  0.000000  0.000000  0.000167  0.010272  0.010355  0.006304
# 2025-04-01  0.000000  0.000000  0.003516  0.009914 -0.007157  0.001805
# 2025-04-02  0.000000  0.000000 -0.006924 -0.004342  0.001157  0.015897
# 2025-04-03  0.000000  0.000000 -0.067703  0.020350  0.001422 -0.170637
# 2025-04-04  0.000000  0.000000 -0.057573 -0.084360 -0.047222 -0.062935
#
#                 ZION       ZTS
# Date
# 2015-01-02       NaN       NaN
# 2015-01-05 -0.037469 -0.006003
# 2015-01-06 -0.038193 -0.009756
# 2015-01-07  0.009545  0.020642
# 2015-01-08  0.013994  0.015399
# ...              ...       ...
# 2025-03-31  0.000000  0.009441
# 2025-04-01  0.000000 -0.016641
# 2025-04-02  0.000000  0.009820
# 2025-04-03  0.000000 -0.023792
# 2025-04-04  0.000000 -0.049370
#
# [2580 rows x 614 columns]

# %%
df.columns[df.isna().all()]
# Out:
# Index(['ACE', 'ADT', 'ALTR', 'BHI', 'CA', 'CCE', 'DD', 'DNB', 'DOW', 'EMC',
#        'EQT', 'FSLR', 'INFO', 'NE', 'PCG', 'PCP', 'PETM', 'PLL', 'SBNY', 'SE',
#        'SNDK', 'STI', 'TE', 'TEG'],
#       dtype='object')

# %%
ret.columns[ret.isna().all()]
# Out:
# Index(['ACE', 'ADT', 'ALTR', 'BHI', 'CA', 'CCE', 'DD', 'DNB', 'DOW', 'EMC',
#        'EQT', 'FSLR', 'INFO', 'NE', 'PCG', 'PCP', 'PETM', 'PLL', 'SBNY', 'SE',
#        'SNDK', 'STI', 'TE', 'TEG'],
#       dtype='object')

# %%
mth_ret = (ret + 1).resample('M').agg(pd.Series.prod, skipna=False)
mth_ret
# Out:
# /tmp/ipykernel_34795/1841358604.py:1: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   mth_ret = (ret + 1).resample('M').agg(pd.Series.prod, skipna=False)
#                    A        AA       AAL       AAP      AAPL      ABBV  \
# Date
# 2015-01-31       NaN       NaN       NaN       NaN       NaN       NaN
# 2015-02-28  1.117553  0.946758  0.977935  0.974403  1.100777  1.002486
# 2015-03-31  0.986788  0.873563  1.101879  0.966565  0.968628  0.967603
# 2015-04-30  0.995668  1.038699  0.916806  0.955308  1.005786  1.113705
# 2015-05-31  0.995649  0.933490  0.877407  1.071469  1.045339  1.029848
# ...              ...       ...       ...       ...       ...       ...
# 2024-12-31  0.975490  1.000000  1.000000  1.000000  1.055155  0.971410
# 2025-01-31  1.127885  1.000000  1.000000  1.000000  0.942417  1.044649
# 2025-02-28  0.844245  1.000000  1.000000  1.000000  1.025872  1.136650
# 2025-03-31  0.914478  1.000000  1.000000  1.000000  0.918500  1.002344
# 2025-04-30  0.882363  1.000000  1.000000  1.000000  0.848062  0.892325
#
#                 ABNB       ABT  ACE      ACGL  ...       XEL       XOM  \
# Date                                           ...
# 2015-01-31       NaN       NaN  NaN       NaN  ...       NaN       NaN
# 2015-02-28       NaN  1.058311  NaN       NaN  ...  0.940048  1.020435
# 2015-03-31       NaN  0.978045  NaN       NaN  ...  0.995929  0.960018
# 2015-04-30       NaN  1.007068  NaN       NaN  ...  0.974146  1.027882
# 2015-05-31       NaN  1.046962  NaN       NaN  ...  1.004128  0.983229
# ...              ...       ...  ...       ...  ...       ...       ...
# 2024-12-31  0.965469  0.952345  NaN  0.916898  ...  0.930540  0.911919
# 2025-01-31  0.998174  1.136958  NaN  1.007796  ...  1.003507  0.993121
# 2025-02-28  1.058702  1.078793  NaN  0.998281  ...  1.072917  1.051444
# 2025-03-31  0.860229  0.961162  NaN  1.035195  ...  0.990049  1.068266
# 2025-04-30  0.892851  0.938108  NaN  0.913184  ...  0.959034  0.877323
#
#                 XRAY       XRX       XYL       YUM       ZBH      ZBRA  \
# Date
# 2015-01-31       NaN       NaN       NaN       NaN       NaN       NaN
# 2015-02-28  1.059564  1.036447  1.051083  1.122164  1.073952       NaN
# 2015-03-31  0.961345  0.946540  0.980952  0.970534  0.977964       NaN
# 2015-04-30  1.002162  0.894942  1.057110  1.097720  0.934650       NaN
# 2015-05-31  1.020392  0.993043  0.991624  1.048278  1.040732       NaN
# ...              ...       ...       ...       ...       ...       ...
# 2024-12-31  1.000000  1.000000  0.915345  0.970276  0.944405  0.948943
# 2025-01-31  1.000000  1.000000  1.069126  0.972719  1.036448  1.014810
# 2025-02-28  1.000000  1.000000  1.058497  1.203900  0.952868  0.803822
# 2025-03-31  1.000000  1.000000  0.912675  1.006331  1.087255  0.896874
# 2025-04-30  1.000000  1.000000  0.875607  0.939438  0.948401  0.790947
#
#                 ZION       ZTS
# Date
# 2015-01-31       NaN       NaN
# 2015-02-28  1.117725  1.078633
# 2015-03-31  1.009723  1.004339
# 2015-04-30  1.049629  0.961325
# 2015-05-31  1.021155  1.120441
# ...              ...       ...
# 2024-12-31  1.000000  0.929700
# 2025-01-31  1.000000  1.052088
# 2025-02-28  1.000000  0.978584
# 2025-03-31  1.000000  0.984513
# 2025-04-30  1.000000  0.921531
#
# [124 rows x 614 columns]

# %%
rolling = mth_ret.rolling(12).apply(np.prod)#.dropna(how='all')
rolling
# Out:
#                    A   AA       AAL  AAP      AAPL      ABBV      ABNB  \
# Date
# 2015-01-31       NaN  NaN       NaN  NaN       NaN       NaN       NaN
# 2015-02-28       NaN  NaN       NaN  NaN       NaN       NaN       NaN
# 2015-03-31       NaN  NaN       NaN  NaN       NaN       NaN       NaN
# 2015-04-30       NaN  NaN       NaN  NaN       NaN       NaN       NaN
# 2015-05-31       NaN  NaN       NaN  NaN       NaN       NaN       NaN
# ...              ...  ...       ...  ...       ...       ...       ...
# 2024-12-31  0.972971  1.0  0.799127  1.0  1.307053  1.188590  0.965256
# 2025-01-31  1.172724  1.0  0.771609  1.0  1.286097  1.159362  0.910018
# 2025-02-28  0.937737  1.0  0.700255  1.0  1.344298  1.230585  0.881882
# 2025-03-31  0.809509  1.0  0.715309  1.0  1.301486  1.192489  0.724176
# 2025-04-30  0.757198  1.0  0.812731  1.0  1.111193  1.180384  0.672637
#
#                  ABT  ACE      ACGL  ...       XEL       XOM      XRAY  XRX  \
# Date                                 ...
# 2015-01-31       NaN  NaN       NaN  ...       NaN       NaN       NaN  NaN
# 2015-02-28       NaN  NaN       NaN  ...       NaN       NaN       NaN  NaN
# 2015-03-31       NaN  NaN       NaN  ...       NaN       NaN       NaN  NaN
# 2015-04-30       NaN  NaN       NaN  ...       NaN       NaN       NaN  NaN
# 2015-05-31       NaN  NaN       NaN  ...       NaN       NaN       NaN  NaN
# ...              ...  ...       ...  ...       ...       ...       ...  ...
# 2024-12-31  1.048126  NaN  1.307643  ...  1.123209  1.112616  0.899342  1.0
# 2025-01-31  1.153664  NaN  1.187381  ...  1.165554  1.074547  0.921081  1.0
# 2025-02-28  1.186973  NaN  1.115511  ...  1.420952  1.101108  0.979424  1.0
# 2025-03-31  1.190861  NaN  1.094185  ...  1.364394  1.057677  0.959626  1.0
# 2025-04-30  1.192312  NaN  0.987441  ...  1.308987  0.911997  1.000000  1.0
#
#                  XYL       YUM       ZBH      ZBRA      ZION       ZTS
# Date
# 2015-01-31       NaN       NaN       NaN       NaN       NaN       NaN
# 2015-02-28       NaN       NaN       NaN       NaN       NaN       NaN
# 2015-03-31       NaN       NaN       NaN       NaN       NaN       NaN
# 2015-04-30       NaN       NaN       NaN       NaN       NaN       NaN
# 2015-05-31       NaN       NaN       NaN       NaN       NaN       NaN
# ...              ...       ...       ...       ...       ...       ...
# 2024-12-31  1.025712  1.047221  0.875422  1.413017  0.915168  0.833681
# 2025-01-31  1.115341  1.027856  0.879156  1.636151  0.958196  0.919667
# 2025-02-28  1.041786  1.151839  0.846073  1.127272  1.007608  0.852234
# 2025-03-31  0.934700  1.157209  0.865159  0.937367  1.000000  0.983429
# 2025-04-30  0.809287  1.067115  0.900332  0.710485  1.000000  0.960262
#
# [124 rows x 614 columns]

# %%
top = rolling.iloc[0].nlargest(5)
top

# %%
top.name

# %%
invested = mth_ret[top.name:].iloc[1][top.index]
invested

# %%
invested.mean()

# %%
def top_performers(date):
    top = rolling.loc[date].nlargest(5)
    invested = mth_ret[top.name:].iloc[1][top.index]

    return invested.mean()

# %%
top_performers(rolling.iloc[0].name)

# %%
initial_inv = 100

for date in rolling.index[:-1]:
    
    initial_inv *= top_performers(date)

print(initial_inv)

# %%
sp500 = yf.download(tickers=['^GSPC'], start=start, end=end)['Close']
sp500

# %%
sp500_ret = sp500.pct_change().dropna() + 1
sp500_ret

# %%
sp500_ret = sp500_ret.resample('M').prod()
sp500_ret

# %%
initial_inv = 100

for date in rolling.index[:-1]:
    
    # print(sp500_ret.loc[date])
    initial_inv *= sp500_ret.loc[date]

initial_inv

# %%
sp500_ret.mean()

# %%
100*1.24**10
